# %% [markdown]
# ## Code

# %%
# %load_ext ipython_sparql_pandas

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from random import randint
sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q')
sparql.setReturnFormat(JSON)

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']

def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    #ret = result.queryAndConvert()
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    return(listOfObj,listOfPred)

def generateQuestion(listOfPred, listOfObj, index, subject):
    flag = True
    if ('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>') in AttrHistory:
        return generateQuestion(listOfPred, listOfObj, index+1, subject)
        
    else:
        AttrHistory.append('<' + str(listOfPred[index]['value']) +'> <'+str(listOfObj[index]['value'])+ '>')
        
    #print(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    try:
        listOfObj[index]['datatype']
    except:
        flag = False
        
    if flag is True:
        datatype = listOfObj[index]["datatype"].split("#")[-1]
        answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '"'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype)
    else:
        if len(listOfObj[index]["value"].split('/')) == 1:
            answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '"'+str(listOfObj[index]['value'])+ '"')
        else:
            answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '<'+str(listOfObj[index]['value'])+ '>')
    #print(answer)
    
    
    if answer:
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
            if len(listOfObj[index]["value"].split('/')) == 1:
                PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+ '".')  
            else:
                PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.')    
        
    elif not answer:
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
            if len(listOfObj[index]["value"].split('/')) == 1:
                NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+ '". }}') 
            else:
                NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}')   
        
    else:
        return generateQuestion(listOfPred, listOfObj, index+1)
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    return (PosFilters, NegFilters)

  
def updateQuery(left, PosFilters, NegFilters):
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            
            group by ?p ?o 
            ORDER BY ABS( {left} - ?count )
            Limit 25
            
            """) 
        
    return FilterQuestion

# %%
def pickSubject():
    #ind=randint(0,10000)
    #query = f"""
    #select distinct ?s
    #where {{
        #?s ?p ?o .
        #?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
    #}}
    #limit 10000
    #"""
    #sparql.setQuery(query)
    #sparql.setReturnFormat(JSON)
    #qres = sparql.query().convert() 
    #for r in qres["results"]["bindings"][ind:ind+1]:
        #return("<"+r["s"]["value"]+">")
    data = pd.read_csv('abstracts.csv')
    return random.sample(list(data['S']), 1000)

def findAnswer(subject,p,o):
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    #print(subject)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
def numberleft(PosFilters,NegFilters):
    sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q')
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            {PosFilters}            
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            {NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            
            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))

# %%
def popentities(PosFilters,NegFilters):
    query =  f"""
            select ?s where 
            {{
            
            {PosFilters}
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            {NegFilters} 
            
            }}
            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    return qres["results"]["bindings"]

# %%
# resets are variables
def game_reset():
    PosAttr= ['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .']
    NegAttr= ['']
    AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    left = numberleft("".join(PosAttr), "".join(NegAttr))
    FilterQuestion =  f"""
        select (count(*) as ?count) ?p ?o  where 
        {{

        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s ?p ?o .
        }} 
        group by ?p ?o 
        ORDER BY ABS( %s - ?count )
        limit 20
        """ %((left/2))
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
import random
import pandas as pd
random.seed(10)
subjects = pickSubject()
wincount = 0
subjects_lost = []
gamesplayed = 0
lostbybreak = 0
breakskip = 0
totalgames = len(subjects)

while gamesplayed < totalgames:
    # Resets all variables
    try:
        left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
        i=0
        outofguess = []
        print(gamesplayed)
        # pick subject
        subject = "<" + subjects[gamesplayed] + ">"
        print(subject)

        while i < 20:

            # list of Pred and Obj for questions
            listOfObj ,listOfPred = extractCountAndAttr(qres)

            # if only 1 popular entity is left break
            if left<=1:
                break

            # ask question and add filters to query
            #print('Question: %s' %(i+1))
            PosFilters, NegFilters = generateQuestion(listOfPred, listOfObj, 0, subject)

            # number of popular entities left
            left = numberleft(PosFilters, NegFilters)

            # run query
            sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q')
            query = updateQuery(left/2,PosFilters, NegFilters)
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)
            qres = sparql.queryAndConvert()

            i+=1

        # Prints answer
        if i != 20:
            for attr in popentities(PosFilters, NegFilters):
                for x in [attr['s']['value']][0:10]:
                    answer = (x.split("/")[-1])
            print("Your Answer is: " + answer)
            if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
                wincount += 1
                gamesplayed += 1
                print("Win!")
                print('%s/%s' %(wincount,gamesplayed))
                print()
            else:
                gamesplayed += 1
                subjects_lost.append(subject)
                print("Lose...")
                print('%s/%s' %(wincount,gamesplayed))
                print()

        # ran out of questions
        else:
            print('Final Question:')
            for j in popentities(PosFilters, NegFilters):
                    outofguess.append(f'{j["s"]["value"].split("/")[-1]}')
            guess = random.choice(outofguess)
            print("Is it " + guess + "?")
            if str(subject.split("/")[-1]) == str(guess + ">"):
                wincount += 1
                gamesplayed += 1
                print('Win!')
                print('%s/%s' %(wincount,gamesplayed))
                print()
            else:
                gamesplayed += 1
                subjects_lost.append(subject)
                print('Lose...')
                print('%s/%s' %(wincount,gamesplayed))
                print()
        breakskip = 0
    except:
        continue
            
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
# 0
# <http://yago-knowledge.org/resource/The_Namesake_(film)>
# Final Question:
# Is it Recess:_School's_Out?
# Lose...
# 0/1
#
# 1
# <http://yago-knowledge.org/resource/The_Grudge>
# Final Question:
# Is it Jackass:_The_Movie?
# Lose...
# 0/2
#
# 2
# <http://yago-knowledge.org/resource/James_Caan>
# Your Answer is: James_Caan
# Win!
# 1/3
#
# 3
# <http://yago-knowledge.org/resource/University_of_Iowa>
# Your Answer is: University_of_Iowa
# Win!
# 2/4
#
# 4
# <http://yago-knowledge.org/resource/Comoros>
# Your Answer is: Comoros
# Win!
# 3/5
#
# 5
# <http://yago-knowledge.org/resource/Star_Trek:_Deep_Space_Nine>
# Your Answer is: Star_Trek:_Deep_Space_Nine
# Win!
# 4/6
#
# 6
# <http://yago-knowledge.org/resource/Hampshire>
# Final Question:
# Is it Nottinghamshire?
# Lose...
# 4/7
#
# 7
# <http://yago-knowledge.org/resource/Get_Him_to_the_Greek>
# Final Question:
# Is it Get_Him_to_the_Greek?
# Win!
# 5/8
#
# 8
# <http://yago-knowledge.org/resource/Heavy_metal_music>
# Your Answer is: Heavy_metal_music
# Win!
# 6/9
#
# 9
# <http://yago-knowledge.org/resource/University_of_Michigan>
# Your Answer is: University_of_Michigan
# Win!
# 7/10
#
# 10
# <http://yago-knowledge.org/resource/Ninja_Tune>
# Final Question:
# Is it Ninja_Tune?
# Win!
# 8/11
#
# 11
# <http://yago-knowledge.org/resource/Herbert_Hoover>
# Your Answer is: Herbert_Hoover
# Win!
# 9/12
#
# 12
# <http://yago-knowledge.org/resource/John_Cusack>
# Your Answer is: John_Cusack
# Win!
# 10/13
#
# 13
# <http://yago-knowledge.org/resource/Brunswick,_Georgia>
# Final Question:
# Is it Utrecht?
# Lose...
# 10/14
#
# 14
# <http://yago-knowledge.org/resource/Urban_planner>
# Final Question:
# Is it Chief_technology_officer?
# Lose...
# 10/15
#
# 15
# <http://yago-knowledge.org/resource/Jesse_Metcalfe>
# Final Question:
# Is it Jello_Biafra?
# Lose...
# 10/16
#
# 16
# <http://yago-knowledge.org/resource/APOEL_FC>
# Your Answer is: APOEL_FC
# Win!
# 11/17
#
# 17
# <http://yago-knowledge.org/resource/American_Wedding>
# Final Question:
# Is it American_Wedding?
# Win!
# 12/18
#
# 18
# <http://yago-knowledge.org/resource/Luxembourg>
# Your Answer is: Luxembourg
# Win!
# 13/19
#
# 19
# <http://yago-knowledge.org/resource/Greensboro,_North_Carolina>
# Final Question:
# Is it Boulder,_Colorado?
# Lose...
# 13/20
#
# 20
# <http://yago-knowledge.org/resource/The_Lookout_(2007_film)>
# Final Question:
# Is it The_Color_Purple_(film)?
# Lose...
# 13/21
#
# 21
# <http://yago-knowledge.org/resource/Amherst,_Massachusetts>
# Your Answer is: Amherst,_Massachusetts
# Win!
# 14/22
#
# 22
# <http://yago-knowledge.org/resource/Carl_Davis>
# Your Answer is: Carl_Davis
# Win!
# 15/23
#
# 23
# <http://yago-knowledge.org/resource/MTV_Movie_Award_for_Best_Jaw_Dropping_Moment>
# Final Question:
# Is it Teen_drama?
# Lose...
# 15/24
#
# 24
# <http://yago-knowledge.org/resource/Megan_Fox>
# Final Question:
# Is it Gilbert_Gottfried?
# Lose...
# 15/25
#
# 25
# <http://yago-knowledge.org/resource/Seoul_National_University>
# Final Question:
# Is it Pasadena_City_College?
# Lose...
# 15/26
#
# 26
# <http://yago-knowledge.org/resource/I_Heart_Huckabees>
# Final Question:
# Is it I_Heart_Huckabees?
# Win!
# 16/27
#
# 27
# <http://yago-knowledge.org/resource/Tom_Morello>
# Your Answer is: Tom_Morello
# Win!
# 17/28
#
# 28
# <http://yago-knowledge.org/resource/Mehmood_(actor)>
# Your Answer is: Mehmood_(actor)
# Win!
# 18/29
#
# 29
# <http://yago-knowledge.org/resource/Masako_Nozawa>
# Your Answer is: Masako_Nozawa
# Win!
# 19/30
#
# 30
# <http://yago-knowledge.org/resource/Benjamin_Franklin>
# Your Answer is: Benjamin_Franklin
# Win!
# 20/31
#
# 31
# <http://yago-knowledge.org/resource/Hebei>
# Final Question:
# Is it Yunnan?
# Lose...
# 20/32
#
# 32
# <http://yago-knowledge.org/resource/Wall_Street_(1987_film)>
# Your Answer is: Wall_Street_(1987_film)
# Win!
# 21/33
#
# 33
# <http://yago-knowledge.org/resource/Dino_De_Laurentiis>
# Your Answer is: Dino_De_Laurentiis
# Win!
# 22/34
#
# 34
# <http://yago-knowledge.org/resource/Daytime_Emmy_Award_for_Outstanding_Children's_Animated_Program>
# Final Question:
# Is it Shooting_sports?
# Lose...
# 22/35
#
# 35
# <http://yago-knowledge.org/resource/Annette_Bening>
# Your Answer is: Annette_Bening
# Win!
# 23/36
#
# 36
# <http://yago-knowledge.org/resource/Gulliver's_Travels_(miniseries)>
# Your Answer is: Gulliver's_Travels_(miniseries)
# Win!
# 24/37
#
# 37
# <http://yago-knowledge.org/resource/Santa_Fe_Province>
# Final Question:
# Is it Wales?
# Lose...
# 24/38
#
# 38
# <http://yago-knowledge.org/resource/Amour_(2012_film)>
# Your Answer is: Amour_(2012_film)
# Win!
# 25/39
#
# 39
# <http://yago-knowledge.org/resource/BYU_Cougars_football>
# Final Question:
# Is it Jacksonville_Jaguars?
# Lose...
# 25/40
#
# 40
# <http://yago-knowledge.org/resource/Columbia_University>
# Your Answer is: Columbia_University
# Win!
# 26/41
#
# 41
# <http://yago-knowledge.org/resource/Dischord_Records>
# Final Question:
# Is it Merge_Records?
# Lose...
# 26/42
#
# 42
# <http://yago-knowledge.org/resource/32nd_United_States_Congress>
# Final Question:
# Is it Sumo?
# Lose...
# 26/43
#
# 43
# <http://yago-knowledge.org/resource/Star_Alliance>
# Final Question:
# Is it Sicilian_Mafia?
# Lose...
# 26/44
#
# 44
# <http://yago-knowledge.org/resource/Scary_Movie_4>
# Final Question:
# Is it Terror_in_the_Aisles?
# Lose...
# 26/45
#
# 45
# <http://yago-knowledge.org/resource/Chicken_Run>
# Your Answer is: Chicken_Run
# Win!
# 27/46
#
# 46
# <http://yago-knowledge.org/resource/Steubenville,_Ohio>
# Final Question:
# Is it Berkeley,_California?
# Lose...
# 27/47
#
# 47
# <http://yago-knowledge.org/resource/Mahesh_Manjrekar>
# Your Answer is: Mahesh_Manjrekar
# Win!
# 28/48
#
# 48
# <http://yago-knowledge.org/resource/Wigan>
# Your Answer is: Wigan
# Win!
# 29/49
#
# 49
# <http://yago-knowledge.org/resource/Marc_Shaiman>
# Your Answer is: Marc_Shaiman
# Win!
# 30/50
#
# 50
# <http://yago-knowledge.org/resource/David_Robb>
# Your Answer is: David_Robb
# Win!
# 31/51
#
# 51
# <http://yago-knowledge.org/resource/Edie_McClurg>
# Final Question:
# Is it Gary_Cole?
# Lose...
# 31/52
#
# 52
# <http://yago-knowledge.org/resource/Hampshire_College>
# Your Answer is: Hampshire_College
# Win!
# 32/53
#
# 53
# <http://yago-knowledge.org/resource/University_of_Massachusetts_Amherst>
# Your Answer is: University_of_Massachusetts_Amherst
# Win!
# 33/54
#
# 54
# <http://yago-knowledge.org/resource/Hagerstown,_Maryland>
# Final Question:
# Is it Danbury,_Connecticut?
# Lose...
# 33/55
#
# 55
# <http://yago-knowledge.org/resource/Pyrenees>
# Your Answer is: Pyrenees
# Win!
# 34/56
#
# 56
# <http://yago-knowledge.org/resource/Karl_Urban>
# Your Answer is: Karl_Urban
# Win!
# 35/57
#
# 57
# <http://yago-knowledge.org/resource/Barrie>
# Final Question:
# Is it Anderson,_Indiana?
# Lose...
# 35/58
#
# 58
# <http://yago-knowledge.org/resource/Sweden_national_football_team>
# Your Answer is: Sweden_national_football_team
# Win!
# 36/59
#
# 59
# <http://yago-knowledge.org/resource/Margaret_Cho>
# Final Question:
# Is it Cheryl_Hines?
# Lose...
# 36/60
#
# 60
# <http://yago-knowledge.org/resource/Executive_director>
# Final Question:
# Is it Dean_(education)?
# Lose...
# 36/61
#
# 61
# <http://yago-knowledge.org/resource/MTV_Video_Music_Award_for_Best_Editing>
# Final Question:
# Is it MTV_Video_Music_Award_for_Best_New_Artist?
# Lose...
# 36/62
#
# 62
# <http://yago-knowledge.org/resource/Pope>
# Final Question:
# Is it Pope?
# Win!
# 37/63
#
# 63
# <http://yago-knowledge.org/resource/Betty_Grable>
# Final Question:
# Is it Jeffrey_Combs?
# Lose...
# 37/64
#
# 64
# <http://yago-knowledge.org/resource/Kochi>
# Your Answer is: Kochi
# Win!
# 38/65
#
# 65
# <http://yago-knowledge.org/resource/Maharashtra>
# Your Answer is: Maharashtra
# Win!
# 39/66
#
# 66
# <http://yago-knowledge.org/resource/Heracles_Almelo>
# Final Question:
# Is it FC_St._Gallen?
# Lose...
# 39/67
#
# 67
# <http://yago-knowledge.org/resource/The_Red_Violin>
# Your Answer is: The_Red_Violin
# Win!
# 40/68
#
# 68
# <http://yago-knowledge.org/resource/Billy_Crystal>
# Your Answer is: Billy_Crystal
# Win!
# 41/69
#
# 69
# <http://yago-knowledge.org/resource/San_Pedro,_Los_Angeles>
# Your Answer is: San_Pedro,_Los_Angeles
# Win!
# 42/70
#
# 70
# <http://yago-knowledge.org/resource/Arlington_National_Cemetery>
# Your Answer is: Arlington_National_Cemetery
# Win!
# 43/71
#
# 71
# <http://yago-knowledge.org/resource/Colbie_Caillat>
# Your Answer is: Colbie_Caillat
# Win!
# 44/72
#
# 72
# <http://yago-knowledge.org/resource/Utah_County,_Utah>
# Final Question:
# Is it Kensington?
# Lose...
# 44/73
#
# 73
# <http://yago-knowledge.org/resource/Liberal_Democrats_(UK)>
# Your Answer is: Liberal_Democrats_(UK)
# Win!
# 45/74
#
# 74
# <http://yago-knowledge.org/resource/David_Hilbert>
# Your Answer is: David_Hilbert
# Win!
# 46/75
#
# 75
# <http://yago-knowledge.org/resource/Hugo_Award_for_Best_Short_Story>
# Final Question:
# Is it Hugo_Award_for_Best_Novella?
# Lose...
# 46/76
#
# 76
# <http://yago-knowledge.org/resource/Oliver_Hardy>
# Your Answer is: Oliver_Hardy
# Win!
# 47/77
#
# 77
# <http://yago-knowledge.org/resource/Bob_Geldof>
# Your Answer is: Bob_Geldof
# Win!
# 48/78
#
# 78
# <http://yago-knowledge.org/resource/Angela_Lansbury>
# Your Answer is: Angela_Lansbury
# Win!
# 49/79
#
# 79
# <http://yago-knowledge.org/resource/Glasgow_School_of_Art>
# Final Question:
# Is it California_College_of_the_Arts?
# Lose...
# 49/80
#
# 80
# <http://yago-knowledge.org/resource/Giovani_dos_Santos>
# Your Answer is: Giovani_dos_Santos
# Win!
# 50/81
#
# 81
# <http://yago-knowledge.org/resource/Tom_Jones_(1963_film)>
# Your Answer is: Tom_Jones_(1963_film)
# Win!
# 51/82
#
# 82
# <http://yago-knowledge.org/resource/Texas_Tech_University>
# Your Answer is: Texas_Tech_University
# Win!
# 52/83
#
# 83
# <http://yago-knowledge.org/resource/Riyadh>
# Final Question:
# Is it Kinshasa?
# Lose...
# 52/84
#
# 84
# <http://yago-knowledge.org/resource/Castle_Rock_Entertainment>
# Final Question:
# Is it Royal_Victorian_Order?
# Lose...
# 52/85
#
# 85
# <http://yago-knowledge.org/resource/What_Lies_Beneath>
# Final Question:
# Is it Poltergeist_(1982_film)?
# Lose...
# 52/86
#
# 86
# <http://yago-knowledge.org/resource/Jim_Broadbent>
# Your Answer is: Jim_Broadbent
# Win!
# 53/87
#
# 87
# <http://yago-knowledge.org/resource/New_Westminster>
# Final Question:
# Is it Rancho_Mirage,_California?
# Lose...
# 53/88
#
# 88
# <http://yago-knowledge.org/resource/Lucy_Lawless>
# Your Answer is: Lucy_Lawless
# Win!
# 54/89
#
# 89
# <http://yago-knowledge.org/resource/Hamlet_(1996_film)>
# Final Question:
# Is it Hannibal_(2001_film)?
# Lose...
# 54/90
#
# 90
# <http://yago-knowledge.org/resource/William_B._Davis>
# Your Answer is: William_B._Davis
# Win!
# 55/91
#
# 91
# <http://yago-knowledge.org/resource/Greater_Pittsburgh_Region>
# Final Question:
# Is it Norristown,_Pennsylvania?
# Lose...
# 55/92
#
# 92
# <http://yago-knowledge.org/resource/Bank_of_America>
# Your Answer is: Bank_of_America
# Win!
# 56/93
#
# 93
# <http://yago-knowledge.org/resource/New_Jersey>
# Final Question:
# Is it Washington_(state)?
# Lose...
# 56/94
#
# 94
# <http://yago-knowledge.org/resource/Edgar_Allan_Poe>
# Your Answer is: Edgar_Allan_Poe
# Win!
# 57/95
#
# 95
# <http://yago-knowledge.org/resource/Cayman_Islands>
# Final Question:
# Is it Clark_County,_Washington?
# Lose...
# 57/96
#
# 96
# <http://yago-knowledge.org/resource/Ludwig_von_Mises>
# Your Answer is: Ludwig_von_Mises
# Win!
# 58/97
#
# 97
# <http://yago-knowledge.org/resource/Oral_Roberts_University>
# Final Question:
# Is it Fairleigh_Dickinson_University?
# Lose...
# 58/98
#
# 98
# <http://yago-knowledge.org/resource/Czech_Republic>
# Your Answer is: Czech_Republic
# Win!
# 59/99
#
# 99
# <http://yago-knowledge.org/resource/Rick_Berman>
# Your Answer is: Rick_Berman
# Win!
# 60/100
#
# 100
# <http://yago-knowledge.org/resource/Cleveland_Browns>
# Your Answer is: Cleveland_Browns
# Win!
# 61/101
#
# 101
# <http://yago-knowledge.org/resource/Harry_Warren>
# Your Answer is: Harry_Warren
# Win!
# 62/102
#
# 102
# <http://yago-knowledge.org/resource/Johnson_County,_Iowa>
# Final Question:
# Is it Silver_Spring,_Maryland?
# Lose...
# 62/103
#
# 103
# <http://yago-knowledge.org/resource/Virginia_Beach,_Virginia>
# Final Question:
# Is it Newport_News,_Virginia?
# Lose...
# 62/104
#
# 104
# <http://yago-knowledge.org/resource/HTC>
# Your Answer is: HTC
# Win!
# 63/105
#
# 105
# <http://yago-knowledge.org/resource/1941_(film)>
# Final Question:
# Is it The_Alamo_(1960_film)?
# Lose...
# 63/106
#
# 106
# <http://yago-knowledge.org/resource/Prostate_cancer>
# Your Answer is: Prostate_cancer
# Win!
# 64/107
#
# 107
# <http://yago-knowledge.org/resource/Peter_Frampton>
# Your Answer is: Peter_Frampton
# Win!
# 65/108
#
# 108
# <http://yago-knowledge.org/resource/Cape_Fear_(1991_film)>
# Final Question:
# Is it Cape_Fear_(1991_film)?
# Win!
# 66/109
#
# 109
# <http://yago-knowledge.org/resource/St._John's_University_(New_York_City)>
# Final Question:
# Is it University_of_Dhaka?
# Lose...
# 66/110
#
# 110
# <http://yago-knowledge.org/resource/Meet_Joe_Black>
# Your Answer is: Meet_Joe_Black
# Win!
# 67/111
#
# 111
# <http://yago-knowledge.org/resource/The_Full_Monty>
# Final Question:
# Is it The_Full_Monty?
# Win!
# 68/112
#
# 112
# <http://yago-knowledge.org/resource/We_Need_to_Talk_About_Kevin_(film)>
# Your Answer is: We_Need_to_Talk_About_Kevin_(film)
# Win!
# 69/113
#
# 113
# <http://yago-knowledge.org/resource/Aarhus>
# Final Question:
# Is it Aarhus?
# Win!
# 70/114
#
# 114
# <http://yago-knowledge.org/resource/Buzz_Aldrin>
# Final Question:
# Is it Michael_Jordan?
# Lose...
# 70/115
#
# 115
# <http://yago-knowledge.org/resource/David_Byrne>
# Your Answer is: David_Byrne
# Win!
# 71/116
#
# 116
# <http://yago-knowledge.org/resource/Siouxsie_and_the_Banshees>
# Your Answer is: Siouxsie_and_the_Banshees
# Win!
# 72/117
#
# 117
# <http://yago-knowledge.org/resource/Jimmy_Buffett>
# Your Answer is: Jimmy_Buffett
# Win!
# 73/118
#
# 118
# <http://yago-knowledge.org/resource/Michelangelo>
# Final Question:
# Is it Michelangelo?
# Win!
# 74/119
#
# 119
# <http://yago-knowledge.org/resource/Luxembourg_City>
# Final Question:
# Is it Luxembourg_City?
# Win!
# 75/120
#
# 120
# <http://yago-knowledge.org/resource/St._Bonaventure_University>
# Final Question:
# Is it St._Bonaventure_University?
# Win!
# 76/121
#
# 121
# <http://yago-knowledge.org/resource/1972_Winter_Olympics>
# Your Answer is: 1972_Winter_Olympics
# Win!
# 77/122
#
# 122
# <http://yago-knowledge.org/resource/East_Sussex>
# Final Question:
# Is it Gloucestershire?
# Lose...
# 77/123
#
# 123
# <http://yago-knowledge.org/resource/France>
# Final Question:
# Is it Belgium?
# Lose...
# 77/124
#
# 124
# <http://yago-knowledge.org/resource/Somerset_County,_New_Jersey>
# Your Answer is: Somerset_County,_New_Jersey
# Win!
# 78/125
#
# 125
# <http://yago-knowledge.org/resource/Chester_City_F.C.>
# Final Question:
# Is it AS_Nancy?
# Lose...
# 78/126
#
# 126
# <http://yago-knowledge.org/resource/50th_Annual_Grammy_Awards>
# Final Question:
# Is it 50th_Annual_Grammy_Awards?
# Win!
# 79/127
#
# 127
# <http://yago-knowledge.org/resource/FreeBSD>
# Your Answer is: FreeBSD
# Win!
# 80/128
#
# 128
# <http://yago-knowledge.org/resource/Cherokee>
# Final Question:
# Is it Sri_Lankan_Tamils?
# Lose...
# 80/129
#
# 129
# <http://yago-knowledge.org/resource/John_Milton>
# Your Answer is: John_Milton
# Win!
# 81/130
#
# 130
# <http://yago-knowledge.org/resource/Albany_Devils>
# Your Answer is: Albany_Devils
# Win!
# 82/131
#
# 131
# <http://yago-knowledge.org/resource/Club_Puebla>
# Final Question:
# Is it SV_Ried?
# Lose...
# 82/132
#
# 132
# <http://yago-knowledge.org/resource/Bologna>
# Your Answer is: Bologna
# Win!
# 83/133
#
# 133
# <http://yago-knowledge.org/resource/Lee_Grant>
# Your Answer is: Lee_Grant
# Win!
# 84/134
#
# 134
# <http://yago-knowledge.org/resource/Titanic_(1997_film)>
# Your Answer is: Titanic_(1997_film)
# Win!
# 85/135
#
# 135
# <http://yago-knowledge.org/resource/Martin_Luther_King_Jr.>
# Your Answer is: Martin_Luther_King_Jr.
# Win!
# 86/136
#
# 136
# <http://yago-knowledge.org/resource/Tuskegee_University>
# Final Question:
# Is it University_of_Dhaka?
# Lose...
# 86/137
#
# 137
# <http://yago-knowledge.org/resource/1._FC_NÃ¼rnberg>
# Final Question:
# Is it Laxmikantâ€“Pyarelal?
# Lose...
# 86/138
#
# 138
# <http://yago-knowledge.org/resource/Real_Betis>
# Your Answer is: Real_Betis
# Win!
# 87/139
#
# 139
# <http://yago-knowledge.org/resource/George_V>
# Your Answer is: George_V
# Win!
# 88/140
#
# 140
# <http://yago-knowledge.org/resource/Burundi>
# Your Answer is: Burundi
# Win!
# 89/141
#
# 141
# <http://yago-knowledge.org/resource/Windsor,_Ontario>
# Your Answer is: Windsor,_Ontario
# Win!
# 90/142
#
# 142
# <http://yago-knowledge.org/resource/Spider-Man_(2002_film)>
# Your Answer is: Spider-Man_(2002_film)
# Win!
# 91/143
#
# 143
# <http://yago-knowledge.org/resource/City_of_Winchester>
# Final Question:
# Is it Greenville_County,_South_Carolina?
# Lose...
# 91/144
#
# 144
# <http://yago-knowledge.org/resource/John_Brown_&_Company>
# Final Question:
# Is it Sprint_Corporation?
# Lose...
# 91/145
#
# 145
# <http://yago-knowledge.org/resource/Robert_Towne>
# Your Answer is: Robert_Towne
# Win!
# 92/146
#
# 146
# <http://yago-knowledge.org/resource/Tarrant_County,_Texas>
# Final Question:
# Is it Tarrant_County,_Texas?
# Win!
# 93/147
#
# 147
# <http://yago-knowledge.org/resource/Shia_LaBeouf>

# %%
import random
import pandas as pd
random.seed(10)
#subjects = pickSubject()
wincount = 0
subjects_lost = []
gamesplayed = 0
lostbybreak = 0
breakskip = 0
#totalgames = len(subjects)

left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
i=0
outofguess = []
subject = "<http://yago-knowledge.org/resource/Jesse_Metcalfe>"
print(subject)

while i < 20:

    # list of Pred and Obj for questions
    listOfObj ,listOfPred = extractCountAndAttr(qres)

    # if only 1 popular entity is left break
    if left<=1:
        break

    # ask question and add filters to query
    #print('Question: %s' %(i+1))
    PosFilters, NegFilters = generateQuestion(listOfPred, listOfObj, 0, subject)

    # number of popular entities left
    left = numberleft(PosFilters, NegFilters)

    # run query
    sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q')
    query = updateQuery(left/2,PosFilters, NegFilters)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.queryAndConvert()

    i+=1

# Prints answer
if i != 20:
    for attr in popentities(PosFilters, NegFilters):
        for x in [attr['s']['value']][0:10]:
            answer = (x.split("/")[-1])
    print("Your Answer is: " + answer)
    if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
        wincount += 1
        gamesplayed += 1
        print("Win!")
        print('%s/%s' %(wincount,gamesplayed))
        print()
    else:
        gamesplayed += 1
        subjects_lost.append(subject)
        print("Lose...")
        print('%s/%s' %(wincount,gamesplayed))
        print()

# ran out of questions
else:
    print('Final Question:')
    for j in popentities(PosFilters, NegFilters):
            outofguess.append(f'{j["s"]["value"].split("/")[-1]}')
    guess = random.choice(outofguess)
    print("Is it " + guess + "?")
    if str(subject.split("/")[-1]) == str(guess + ">"):
        wincount += 1
        gamesplayed += 1
        print('Win!')
        print('%s/%s' %(wincount,gamesplayed))
        print()
    else:
        gamesplayed += 1
        subjects_lost.append(subject)
        print('Lose...')
        print('%s/%s' %(wincount,gamesplayed))
        print()
breakskip = 0
   
            
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")

# %% [markdown]
# #### Seeds used:
# - 10
# - ??
# - ??

# %% [markdown]
# #### Time started:
# - 10
#     - base model
#         - 22:50

# %%
len('ALL'.split('/'))
