# %%
import pandas as pd
stanford = pd.read_csv("Stanford-186.csv")
stanford = stanford.drop('Unnamed: 0', axis=1)
stanford
# Out:
#                                                 Entity
# 0       http://yago-knowledge.org/resource/David_Bowie  \
# 1        http://yago-knowledge.org/resource/Kanye_West
# 2            http://yago-knowledge.org/resource/Eminem
# 3    http://yago-knowledge.org/resource/Jennifer_An...
# 4    http://yago-knowledge.org/resource/George_W._Bush
# ..                                                 ...
# 179    http://yago-knowledge.org/resource/Nancy_Pelosi
# 180  http://yago-knowledge.org/resource/Andhra_Pradesh
# 181     http://yago-knowledge.org/resource/Maharashtra
# 182  http://yago-knowledge.org/resource/Paris_Saint...
# 183   http://yago-knowledge.org/resource/Uttar_Pradesh
#
#                         Label
# 0                 David Bowie  \
# 1                  Kanye West
# 2                      Eminem
# 3            Jennifer Aniston
# 4              George W. Bush
# ..                        ...
# 179              Nancy Pelosi
# 180            Andhra Pradesh
# 181               Maharashtra
# 182  Paris Saint-Germain F.C.
# 183             Uttar Pradesh
#
#                                               Abstract
# 0    David Robert Jones (8 January 1947 – 10 Januar...  \
# 1    Ye (/jeɪ/ YAY; born Kanye Omari West /ˈkɑːnjeɪ...
# 2    Marshall Bruce Mathers III (born October 17, 1...
# 3    Jennifer Joanna Aniston (born February 11, 196...
# 4    George Walker Bush (born July 6, 1946) is an A...
# ..                                                 ...
# 179  Nancy Patricia Pelosi (/pəˈloʊsi/; née D'Alesa...
# 180  Andhra Pradesh (English: /ˌɑːndrə prəˈdɛʃ/, Te...
# 181  Maharashtra (/məhɑːˈrɑːʃtrə/; Marathi: [məhara...
# 182  Paris Saint-Germain Football Club (French pron...
# 183  Uttar Pradesh (/ˌʊtər prəˈdɛʃ/; Hindi: [ˈʊtːəɾ...
#
#                                     Stanford-Trips-Raw
# 0    [['was', 'English'], ['was acclaimed by', 'cri...  \
# 1    [['is', 'American'], ['is', 'regarded'], ['is'...
# 2    [['is credited with', 'hip hop'], ['is credite...
# 3    [['is', 'American'], ['is recipient of', 'acco...
# 4    [['is', 'American'], ['served as', 'governor o...
# ..                                                 ...
# 179  [['is', 'American'], ['has represented', "Cali...
# 180  [['is', 'state'], ['is state in', 'south easte...
# 181  [['is state in', 'western region'], ['is', 'st...
# 182  [['referred to', 'to Paris Saint Germain'], ['...
# 183  [['is state in', 'India'], ['is state in', 'no...
#
#                                               Stanford
# 0    [['type', 'English'], ['for', 'critics'], ['pa...
# 1    [['workedFor', 'producer'], ['producedFor', 'R...
# 2    [['creditedWith', 'hip_hop'], ['specializesIn'...
# 3    [['awardsIncluding', 'accolades'], ['awardsInc...
# 4    [['sonOf', 'governor'], ['universityOf', 'Texa...
# ..                                                 ...
# 179  [['livesIn', "California_'s_district"], ['serv...
# 180  [['type', 'state'], ['partOf', 'south_eastern_...
# 181  [['stateIn', 'western_region'], ['isIn', 'stat...
# 182  [['referredTo', 'Paris_Saint_Germain'], ['comp...
# 183  [['stateIn', 'India'], ['isIn', 'northern_Indi...
#
# [184 rows x 5 columns]

# %%
import pandas as pd
clcy = pd.read_csv("ClCy-186.csv")
clcy = clcy.drop('Unnamed: 0', axis=1)
clcy['Abstract'][8]
# Out:
# "Heath Andrew Ledger (4 April 1979 – 22 January 2008) was an Australian actor and music video director. After playing roles in several Australian television and film productions during the 1990s, Ledger moved to the United States in 1998 to develop his film career further. His work consisted of twenty films, including 10 Things I Hate About You (1999), The Patriot (2000), A Knight's Tale (2001), Monster's Ball (2001), Lords of Dogtown (2005), Brokeback Mountain (2005), Candy (2006), I'm Not There (2007), The Dark Knight (2008), and The Imaginarium of Doctor Parnassus (2009), the latter two being posthumous releases. He also produced and directed music videos and aspired to be a film director. For his portrayal of Ennis Del Mar in Ang Lee's Brokeback Mountain he received nominations for the BAFTA Award, Screen Actors Guild Award, Golden Globe Award and the Academy Award for Best Actor, becoming the eighth-youngest nominee in the category at that time. In 2007 he played a fictional actor named Robbie Clark, one of six characters embodying aspects of Bob Dylan's life and persona in Todd Haynes' I'm Not There. He received the Independent Spirit Robert Altman Award with the rest of the ensemble cast for the film. Ledger died on 22 January 2008 as a result of an accidental overdose of medications. A few months before his death, Ledger had finished filming his role as the Joker in The Dark Knight, with his performance earning him universal acclaim and popularity, receiving numerous posthumous awards including the Academy Award for Best Supporting Actor, the Golden Globe Award for Best Supporting Actor, and the BAFTA Award for Best Supporting Actor. His final role in The Imaginarium of Doctor Parnassus was released posthumously in 2009."

# %%
import pandas as pd
gpt = pd.read_csv("chatGPT-186.csv")
gpt = gpt.drop('Unnamed: 0', axis=1)
gpt
# Out:
#                                                 Entity
# 0       http://yago-knowledge.org/resource/David_Bowie  \
# 1        http://yago-knowledge.org/resource/Kanye_West
# 2            http://yago-knowledge.org/resource/Eminem
# 3    http://yago-knowledge.org/resource/Jennifer_An...
# 4    http://yago-knowledge.org/resource/George_W._Bush
# ..                                                 ...
# 179    http://yago-knowledge.org/resource/Nancy_Pelosi
# 180  http://yago-knowledge.org/resource/Andhra_Pradesh
# 181     http://yago-knowledge.org/resource/Maharashtra
# 182  http://yago-knowledge.org/resource/Paris_Saint...
# 183   http://yago-knowledge.org/resource/Uttar_Pradesh
#
#                         Label
# 0                 David Bowie  \
# 1                  Kanye West
# 2                      Eminem
# 3            Jennifer Aniston
# 4              George W. Bush
# ..                        ...
# 179              Nancy Pelosi
# 180            Andhra Pradesh
# 181               Maharashtra
# 182  Paris Saint-Germain F.C.
# 183             Uttar Pradesh
#
#                                               Abstract
# 0    David Robert Jones (8 January 1947 – 10 Januar...  \
# 1    Ye (/jeɪ/ YAY; born Kanye Omari West /ˈkɑːnjeɪ...
# 2    Marshall Bruce Mathers III (born October 17, 1...
# 3    Jennifer Joanna Aniston (born February 11, 196...
# 4    George Walker Bush (born July 6, 1946) is an A...
# ..                                                 ...
# 179  Nancy Patricia Pelosi (/pəˈloʊsi/; née D'Alesa...
# 180  Andhra Pradesh (English: /ˌɑːndrə prəˈdɛʃ/, Te...
# 181  Maharashtra (/məhɑːˈrɑːʃtrə/; Marathi: [məhara...
# 182  Paris Saint-Germain Football Club (French pron...
# 183  Uttar Pradesh (/ˌʊtər prəˈdɛʃ/; Hindi: [ˈʊtːəɾ...
#
#                      Subjects
# 0                 David_Bowie  \
# 1                  Kanye_West
# 2                      Eminem
# 3            Jennifer_Aniston
# 4              George_W._Bush
# ..                        ...
# 179              Nancy_Pelosi
# 180            Andhra_Pradesh
# 181               Maharashtra
# 182  Paris_Saint-Germain_F.C.
# 183             Uttar_Pradesh
#
#                                        GPT-Triples-Raw
# 0    @prefix ex: <http://example.com/> .\n@prefix r...  \
# 1    @prefix ex: <http://example.com/> .\n@prefix r...
# 2    @prefix ex: <http://example.com/> .\n@prefix r...
# 3    ```\n@prefix ex: <http://example.com/> .\n@pre...
# 4    @prefix ex: <http://example.com/> .\n@prefix x...
# ..                                                 ...
# 179  @prefix ex: <http://example.com/> .\n\nex:Nanc...
# 180  @prefix ex: <http://example.com/> .\n\nex:Andh...
# 181  @prefix ex: <http://example.com/> .\n@prefix r...
# 182  @prefix ex: <http://example.com/> .\n\nex:Pari...
# 183  @prefix ex: <http://example.com/> .\n@prefix r...
#
#                                            GPT-Triples
# 0    [[rdflib.term.URIRef('http://yago-knowledge.or...  \
# 1    [[rdflib.term.URIRef('http://yago-knowledge.or...
# 2    [[rdflib.term.URIRef('http://yago-knowledge.or...
# 3    [[rdflib.term.URIRef('http://yago-knowledge.or...
# 4    [[rdflib.term.URIRef('http://yago-knowledge.or...
# ..                                                 ...
# 179  [[rdflib.term.URIRef('http://yago-knowledge.or...
# 180  [[rdflib.term.URIRef('http://yago-knowledge.or...
# 181  [[rdflib.term.URIRef('http://yago-knowledge.or...
# 182  [[rdflib.term.URIRef('http://yago-knowledge.or...
# 183  [[rdflib.term.URIRef('http://yago-knowledge.or...
#
#                                                    GPT
# 0    [['David Bowie', 'type', 'Person'], ['David Bo...
# 1    [['Kanye West', 'type', 'Person'], ['Kanye Wes...
# 2    [['Eminem', 'type', 'Person'], ['Eminem', 'nam...
# 3    [['Jennifer Aniston', 'type', 'Person'], ['Jen...
# 4    [['George W. Bush', 'type', 'Person'], ['Georg...
# ..                                                 ...
# 179  [['Nancy Pelosi', 'type', 'Person'], ['Nancy P...
# 180  [['Andhra Pradesh', 'type', 'State'], ['Andhra...
# 181  [['Maharashtra', 'type', 'State'], ['Maharasht...
# 182  [['Paris Saint-Germain F.C.', 'type', 'Footbal...
# 183  [['Uttar Pradesh', 'type', 'State'], ['Uttar P...
#
# [184 rows x 7 columns]

# %%
import random 
random.seed(10)
randomlist = random.sample(range(0, 183), 10)
randomlist
# Out:
# [146, 8, 109, 123, 147, 3, 52, 118, 125, 71]

# %%
import ast 
ast.literal_eval((gpt['GPT'][randomlist[0]]))
# Out:
# [['Philippines', 'type', 'Country'],
#  ['Philippines', 'label', 'Philippines@en'],
#  ['Philippines',
#   'comment',
#   'The_Philippines_is_an_archipelagic_country_in_Southeast_Asia.@en'],
#  ['Philippines', 'officialName', 'Republic_of_the_Philippines@en'],
#  ['Philippines', 'consistsOf', 'Luzon,'],
#  ['Philippines', 'consistsOf', 'Visayas,'],
#  ['Philippines', 'consistsOf', 'Mindanao'],
#  ['Philippines', 'boundedBy', 'SouthChinaSea,'],
#  ['Philippines', 'boundedBy', 'PhilippineSea,'],
#  ['Philippines', 'boundedBy', 'CelebesSea'],
#  ['Philippines', 'sharesMaritimeBordersWith', 'Taiwan,'],
#  ['Philippines', 'sharesMaritimeBordersWith', 'Japan,'],
#  ['Philippines', 'sharesMaritimeBordersWith', 'Palau,'],
#  ['Philippines', 'sharesMaritimeBordersWith', 'Indonesia,'],
#  ['Philippines', 'sharesMaritimeBordersWith', 'Malaysia,'],
#  ['Philippines', 'sharesMaritimeBordersWith', 'Vietnam,'],
#  ['Philippines', 'sharesMaritimeBordersWith', 'China'],
#  ['Philippines', 'capital', 'Manila'],
#  ['Philippines', 'largestCity', 'QuezonCity'],
#  ['Philippines', 'population', ['"109000000"', 'xsd:integer']],
#  ['Philippines', 'area', ['"300000"', 'xsd:integer']],
#  ['Philippines', 'ethnicities', 'Negritos,_Austronesian_peoples@en'],
#  ['Philippines', 'religions', 'Catholicism,_Animism,_Hinduism,_Islam@en'],
#  ['Philippines', 'historicalEvent', 'SpanishColonization,'],
#  ['Philippines', 'historicalEvent', 'PhilippineRevolution,'],
#  ['Philippines', 'historicalEvent', 'PhilippineAmericanWar,'],
#  ['Philippines', 'historicalEvent', 'JapaneseInvasion,'],
#  ['Philippines', 'historicalEvent', 'Independence'],
#  ['Philippines',
#   'economicStatus',
#   'Emerging_market,_Newly_industrialized_country@en'],
#  ['Philippines', 'membership', 'UnitedNations,'],
#  ['Philippines', 'membership', 'WorldTradeOrganization,'],
#  ['Philippines', 'membership', 'ASEAN,'],
#  ['Philippines', 'membership', 'AsiaPacificEconomicCooperation,'],
#  ['Philippines', 'membership', 'EastAsiaSummit'],
#  ['Philippines', 'locatedOn', 'PacificRingOfFire,'],
#  ['Philippines', 'locatedOn', 'Equator'],
#  ['Philippines', 'naturalResources', 'Biodiversity@en']]

# %%
data = []
for i in randomlist:
    data.append({'Entity': stanford['Label'][i], 'Chat-GPT':ast.literal_eval((gpt['GPT'][i])), 'Stanford': ast.literal_eval((stanford['Stanford'][i])), 'ClauCy': ast.literal_eval((clcy['ClCy'][i])) })
    
    
data = pd.DataFrame(data)
data.to_csv('TripleQuality.csv')
data
# Out:
#                 Entity                                           Chat-GPT
# 0          Philippines  [[Philippines, type, Country], [Philippines, l...  \
# 1         Heath Ledger  [[Heath Ledger, type, Actor], [Heath Ledger, n...
# 2         Olivia Wilde  [[Olivia Wilde, type, Person], [Olivia Wilde, ...
# 3  Chris Evans (actor)  [[Chris Evans (actor), type, Actor], [Chris Ev...
# 4         Chelsea F.C.  [[Chelsea F.C., type, FootballClub], [Chelsea ...
# 5     Jennifer Aniston  [[Jennifer Aniston, type, Person], [Jennifer A...
# 6        Ryan Reynolds  [[Ryan Reynolds, type, Actor], [Ryan Reynolds,...
# 7            Australia  [[Australia, type, SovereignCountry], [Austral...
# 8    Leonardo DiCaprio  [[Leonardo DiCaprio, type, foaf:Person], [Leon...
# 9       Grey's Anatomy  [[Grey's Anatomy, type, TV_Series], [Grey's An...
#
#                                             Stanford
# 0  [[countryIn, Southeast_Asia], [republicOf, Phi...  \
# 1  [[type, Australian_actor], [type, actor], [con...
# 2  [[starredOn, medical_drama_television_series],...
# 3  [[began, career], [including, appearances], [i...
# 4  [[isIn, based_Fulham], [play, their_home_games...
# 5  [[awardsIncluding, accolades], [awardsIncludin...
# 6  [[continuedIn, his_career], [starredIn, teen_s...
# 7  [[consistingOf, mainland], [mainlandOf, contin...
# 8  [[knownIn, leading_man], [knownIn, biopics], [...
# 9  [[type, American_medical_drama_television_seri...
#
#                                               ClauCy
# 0  [[isIn, western_Pacific_Ocean], [boundedBy, So...
# 1  [[april, April], [received, nominations], [pla...
# 2  [[type, /ˈkoʊbərn/_KOH-bərn], [played, Hadley]...
# 3  [[type, American_actor], [began, career], [gai...
# 4  [[type, English_professional_football_club], [...
# 5  [[type, film_producer], [type, American_actres...
# 6  [[type, Canadian-American_actor], [began, care...
# 7  [[type, officially_the_Commonwealth], [type, l...
# 8  [[mentionedIn, his_work], [actorIn, leading_ma...
# 9  [[type, American_medical_drama_television_seri...

# %%
score = 0
for e,gptt,stant,clcyt in data.values:
    print(len(gptt), len(stant), len(clcyt))
    score += len(stant)
    #for gpt,stan,clcy in zip(gptt,stant,clcyt):
        #print(gpt,stan,clcy)
#for i in data['Stanford'][1]:
    #for trip in i:
    #print(i)
print(score)
print()
for i in data['Stanford']:
    for j in i:
    #for trip in i:
        print(j)
    print()
# Out:
# 37 46 13
# 21 39 8
# 10 18 4
# 24 43 12
# 21 65 7
# 28 69 23
# 24 21 5
# 84 108 25
# 39 95 18
# 35 81 8
# 585
#
# ['countryIn', 'Southeast_Asia']
# ['republicOf', 'Philippines']
# ['type', 'country']
# ['type', 'archipelagic_country']
# ['isIn', 'Pacific_Ocean']
# ['isIn', 'western_Pacific_Ocean']
# ['consistsOf', 'around_7,641_islands']
# ['seaBy', 'South_China_Sea']
# ['seaTo', 'South_China_Sea']
# ['bordersWith', 'Taiwan']
# ['bordersTo', 'Japan']
# ['shares', 'borders']
# ['philippinesShares', 'north']
# ['philippinesShares', 'Palau']
# ['southTo', 'north']
# ['shares', 'maritime_borders']
# ['philippinesCovers', 'area']
# ['mapOf', 'area']
# ['coversOf', '300,000_km2']
# ['populationOf', 'around_109_million_people']
# ['had', 'population']
# ['makingWorld', "world_'s_thirteenth-most_country"]
# ['makingWorld', "world_'s_country"]
# ['censusOf', 'population']
# ['throughout', 'its_islands']
# ['has', 'diverse_ethnicities']
# ['has', 'ethnicities']
# ['maintainedDuring', 'invasion']
# ['maintainedDuring', 'World_War_II']
# ['maintainedDuring', 'Japanese_invasion']
# ['maintainedDuring', 'islands']
# ['maintainedUntil', 'Japanese_invasion']
# ['becauseOf', 'Japanese_invasion']
# ['listOf', 'islands']
# ['dateOf', 'invasion']
# ['maintainedUntil', 'invasion']
# ['becameFollowing', 'liberation']
# ['type', 'emerging_market']
# ['memberOf', 'World_Trade_Organization']
# ['isFounding', 'Nations']
# ['memberOf', 'ASEAN']
# ['isFounding', 'founding_member']
# ['type', 'member']
# ['memberOf', 'United_Nations']
# ['memberOf', 'Asia_Pacific_Economic_Cooperation_forum']
# ['proneTo', 'earthquakes']
#
# ['type', 'Australian_actor']
# ['type', 'actor']
# ['continuedIn', 'roles']
# ['appearedIn', 'Australian_television_productions']
# ['appearedIn', 'several_Australian_television_productions']
# ['playsIn', 'television_productions']
# ['movedTo', 'United_States']
# ['appearedIn', 'several_television_productions']
# ['movedAfter', 'roles']
# ['startedPlaying', 'roles']
# ['developDevelop', 'his_film_career']
# ['startedPlaying', 'playing_roles']
# ['produced', 'music_videos']
# ['toFilm', 'director']
# ['asAspired', 'film_director']
# ['excelledIn', 'his_portrayal']
# ['starredIn', "Ang_Lee_'s_Brokeback_Mountain"]
# ['nominatedFor', 'BAFTA_Award']
# ['approvedOf', 'his_portrayal']
# ['portrayalOf', 'Ennis_Del_Mar']
# ['received', 'nominations']
# ['awardFor', 'Actor']
# ['starredIn', 'Ennis_Del_Mar']
# ['wonFor', 'his_portrayal']
# ['wonFor', 'Best_Actor']
# ['received', 'Independent_Spirit']
# ['diedOn', '22_January']
# ['diedOf', 'result']
# ['diedOf', 'accidental_overdose']
# ['diedOf', 'overdose']
# ['overdoseOf', 'medications']
# ['filming', 'role']
# ['type', 'his_role']
# ['returnsAs', 'Joker']
# ['finishedBefore', 'months']
# ['finishedBefore', 'few_months']
# ['in', 'his_role']
# ['appearsIn', 'Joker']
# ['appearedIn', 'Dark_Knight']
#
# ['starredOn', 'medical_drama_television_series']
# ['appearedOn', 'House']
# ['on', 'drama_television_series']
# ['played', 'Remy_Thirteen_Hadley']
# ['appearedIn', 'films']
# ['made', 'Broadway_debut']
# ['playing', 'Julia']
# ['directed', 'film']
# ['awardFor', 'Best_Feature']
# ['awardFor', 'First_Feature']
# ['awardFor', 'Feature']
# ['directed', 'teen_comedy_Booksmart']
# ['filmBooksmart', 'teen_comedy_Booksmart']
# ['won', 'Independent_Spirit_Award']
# ['directed', 'first_film']
# ['awardFor', 'Best_First_Feature']
# ['as', 'second_feature']
# ['worksAs', 'director']
#
# ['began', 'career']
# ['including', 'appearances']
# ['including', 'several_teen_films']
# ['including', "2001_'s_Not_Another_Teen_Movie"]
# ['gainedFollowing', 'appearances']
# ['including', 'teen_films']
# ['gained', 'attention']
# ['becauseOf', 'his_portrayal']
# ['sonOf', 'Marvel_Comics_character']
# ['including', "2001_'s_Another_Teen_Movie"]
# ['praisedFor', 'his_portrayal']
# ['featuredIn', 'appearances']
# ['appearedIn', 'several_teen_films']
# ['appearedIn', 'teen_films']
# ['made', 'appearances']
# ['madeIn', 'further_appearances']
# ['appearedIn', 'film_adaptations']
# ['listOf', 'appearances']
# ['authorOf', 'film_adaptations']
# ['authorOf', 'books']
# ['madeOf', 'further_appearances']
# ['authorOf', 'comic_books']
# ['made', 'further_appearances']
# ['graduatedFrom', 'his_portrayal']
# ['filmsFrom', 'Steve_Rogers_Captain_America']
# ['graduatedFrom', 'Marvel']
# ['from', 'Cinematic_Universe_films']
# ['graduatedFrom', 'Captain_America']
# ['excelledIn', 'his_portrayal']
# ['appearedIn', 'Steve_Rogers_Captain_America']
# ['appearedIn', 'Marvel_Cinematic_Universe_films']
# ['voiceOf', 'Steve_Rogers_Captain_America']
# ['appearedIn', 'several_Marvel_Cinematic_Universe_films']
# ['gained', 'recognition']
# ['adaptedFrom', 'several_Marvel_Cinematic_Universe_films']
# ['gained', 'wider_recognition']
# ['from', 'Marvel_Cinematic_Universe_films']
# ['starred', 'book_roles']
# ['starred', 'comic_book_roles']
# ['starredIn', 'drama']
# ['made', 'debut']
# ['made', 'directorial_debut']
# ['made', 'Broadway_debut']
#
# ['isIn', 'based_Fulham']
# ['play', 'their_home_games']
# ['bottomOf', 'division']
# ['divisionOf', 'football']
# ['divisionIn', 'Premier_League']
# ['divisionOf', 'English_football']
# ['competes', 'top_division']
# ['competesOf', 'top_division']
# ['competes', 'division']
# ['won', 'their_honour']
# ['won', 'their_first_major_honour']
# ['won', 'their_major_honour']
# ['won', 'their_first_honour']
# ['won', 'League_championship']
# ['won', 'their_first_European_honour']
# ['wonFor', 'first_time']
# ['wonFor', 'time']
# ['won', "Cup_Winners_'_Cup"]
# ['won', 'their_European_honour']
# ['won', 'FA_Cup']
# ['won', 'six_league_titles']
# ['haveWon', 'UEFA_Europa_League']
# ['haveWon', 'UEFA_Champions_League']
# ['competesIn', 'football']
# ['competesIn', 'English_football']
# ['type', 'successful_club']
# ['type', 'club']
# ['type', 'fourth-most_successful_club']
# ['type', 'fourth-most_club']
# ['has', 'rivalries']
# ['with', 'rivalries']
# ['competesWith', 'teams_Arsenal']
# ['has', 'neighbouring_teams']
# ['has', 'Arsenal']
# ['areAre', 'terms']
# ['areAre', 'valuable_football_club']
# ['are', 'seventh_football_club']
# ['are', 'seventh_most_valuable_football_club']
# ['areIn', 'most_valuable_football_club']
# ['wonIn', 'world']
# ['areIn', 'seventh_valuable_football_club']
# ['areIn', 'terms']
# ['areIn', 'club_value_football_club']
# ['areIn', 'football_club']
# ['areIn', 'club_value_seventh_valuable_football_club']
# ['areIn', 'seventh_football_club']
# ['areIn', 'club_value_seventh_most_valuable_football_club']
# ['areIn', 'club_value_seventh_football_club']
# ['areIn', 'terms']
# ['are', 'club_value']
# ['areOf', 'terms']
# ['areOf', 'club_value_valuable_football_club']
# ['areIn', 'club_value']
# ['areOf', 'club_value_football_club']
# ['areIn', 'seventh_most_valuable_football_club']
# ['are', 'football_club']
# ['areIn', 'valuable_football_club']
# ['areOf', 'club_value_seventh_football_club']
# ['areOf', 'club_value_seventh_valuable_football_club']
# ['areTerms', 'terms']
# ['are', 'most_valuable_football_club']
# ['areIn', 'seventh_most_valuable_football_club']
# ['areOf', 'club_value_seventh_most_valuable_football_club']
# ['areIn', 'club_value_valuable_football_club']
# ['are', 'seventh_valuable_football_club']
#
# ['awardsIncluding', 'accolades']
# ['awardsIncluding', 'Primetime_Emmy_Award']
# ['recipientOf', 'various_accolades']
# ['recipientOf', 'accolades']
# ['type', 'recipient']
# ['awardsIncluding', 'various_accolades']
# ['progressed', 'career']
# ['become', "one_world_'s_highest_paid_actresses"]
# ['become', 'career']
# ['become', "one_world_'s_paid_actresses"]
# ['oneOf', "world_'s_paid_actresses"]
# ['oneOf', "world_'s_actresses"]
# ['become', "one_world_'s_actresses"]
# ['oneOf', "world_'s_highest_paid_actresses"]
# ['beganWith', 'role']
# ['asIn', 'actress']
# ['diedIn', 'age']
# ['actressIn', 'role']
# ['roleIn', '1988_film_Mac']
# ['workingAt', 'age']
# ['workedWith', 'actress']
# ['beganWith', 'early_age']
# ['debutedWith', 'uncredited_role']
# ['isIn', 'uncredited_role']
# ['diedIn', 'early_age']
# ['workingAs', 'actress']
# ['looksAt', 'actress']
# ['diedAt', 'early_age']
# ['diedWith', 'age']
# ['earned', 'Primetime_Emmy']
# ['roseOn', 'role']
# ['roseOn', 'television_sitcom']
# ['appearedOn', 'Friends']
# ['roseOn', 'Rachel_Green']
# ['roseTo', 'international_fame']
# ['roseTo', 'fame']
# ['roseFor', 'role']
# ['roseAs', 'role']
# ['roseAs', 'Rachel_Green']
# ['starredIn', 'comedy_films']
# ['starredIn', 'commercially_successful_comedy_films']
# ['starredIn', 'successful_comedy_films']
# ['starringIn', 'Apple_TV_drama_series']
# ['returnedTo', 'television']
# ['listOf', "magazines_'_lists"]
# ['listOf', "world_'s_beautiful_women"]
# ['appearsIn', "numerous_magazines_'_lists"]
# ['listOf', "world_'s_most_beautiful_women"]
# ['outOf', "numerous_magazines_'_lists"]
# ['includedIn', "magazines_'_lists"]
# ['listOf', "world_'s_women"]
# ['listOf', 'box_office_gross']
# ['oneOf', 'few_performers']
# ['as', 'box_office_gross']
# ['type', 'one_performers']
# ['with', 'box_office_gross']
# ['refersAs', 'one_few_performers']
# ['listOf', 'performers']
# ['recipientOf', 'star']
# ['memberOf', 'Hollywood_Walk']
# ['hallOf', 'Fame']
# ['isOn', 'star']
# ['starOn', 'Hollywood_Walk']
# ['recipientOf', 'recipient']
# ['founderOf', 'production_company']
# ['isOn', 'recipient']
# ['type', 'co']
# ['marriedFor', 'five_years']
# ['marriedTo', 'actor']
#
# ['continuedIn', 'his_career']
# ['starredIn', 'teen_soap_opera']
# ['starredIn', 'Hillside']
# ['had', 'minor_roles']
# ['began', 'career']
# ['had', 'roles']
# ['starredIn', 'Canadian_teen_soap_opera']
# ['performedIn', 'dramatic_roles']
# ['performedIn', 'roles']
# ['has', 'biggest_commercial_success']
# ['played', 'title_character']
# ['named', "People_'s_Sexiest_Man_Alive"]
# ['hallOf', 'star']
# ['starOf', 'Hollywood_Walk']
# ['hallOf', 'Fame']
# ['awarded', 'star']
# ['on', 'star']
# ['starOn', 'Hollywood_Walk']
# ['became', 'co']
# ['chairmanOf', 'co']
# ['ownerOf', 'Welsh_football_club_Wrexham_A.F.C.']
#
# ['consistingOf', 'mainland']
# ['mainlandOf', 'continent']
# ['australiaComprising', 'mainland']
# ['sovereign', 'comprising']
# ['mainlandOf', 'Australian_continent']
# ['commonwealthOf', 'Australia']
# ['stateOf', 'Tasmania']
# ['type', 'sovereign_country']
# ['isIn', 'area']
# ['isIn', '7,617,930_square_kilometres_country']
# ['isIn', 'Oceania']
# ['isBy', 'area']
# ['isBy', '7,617,930_kilometres_country']
# ['smallestWith', 'area']
# ['isIn', 'area_largest_country']
# ['isBy', '7,617,930_kilometres_largest_country']
# ['type', 'largest_country']
# ['isIn', 'country']
# ['isIn', '7,617,930_kilometres_country']
# ['codeOf', 'area']
# ['areaOf', '7,617,930_kilometres']
# ['isBy', 'area_largest_country']
# ['areaOf', '7,617,930_square_kilometres']
# ['isBy', '7,617,930_square_kilometres_country']
# ['isIn', 'area_country']
# ['isIn', '7,617,930_square_kilometres_largest_country']
# ['isBy', '7,617,930_square_kilometres_largest_country']
# ['isIn', '7,617,930_kilometres_largest_country']
# ['isBy', 'area_country']
# ['isWith', '2,941,300_sq_mi']
# ['isIn', 'largest_country']
# ['isWith', 'soils']
# ['isWith', 'fertile_soils']
# ['isWith', 'least_fertile_soils']
# ['type', 'megadiverse']
# ['arrivingBy', 'sea']
# ['formed', 'approximately_250_language_groups']
# ['formed', 'approximately_250_distinct_language_groups']
# ['settledSettled', 'continent']
# ['written', 'written_history']
# ['maintained', 'democratic_political_system']
# ['maintained', 'stable_system']
# ['maintained', 'system']
# ['maintained', 'stable_democratic_system']
# ['maintained', 'liberal_political_system']
# ['maintained', 'liberal_system']
# ['maintained', 'liberal_democratic_political_system']
# ['maintained', 'stable_liberal_political_system']
# ['maintained', 'stable_liberal_democratic_political_system']
# ['maintained', 'stable_democratic_political_system']
# ['maintained', 'political_system']
# ['maintained', 'democratic_system']
# ['maintained', 'liberal_democratic_system']
# ['maintained', 'stable_liberal_democratic_system']
# ['maintained', 'stable_political_system']
# ['maintained', 'stable_liberal_system']
# ['since', 'system']
# ['type', 'monarchy']
# ['type', 'federal_monarchy']
# ['type', 'federal_parliamentary_monarchy']
# ['type', 'federal_constitutional_monarchy']
# ['type', 'constitutional_monarchy']
# ['type', 'Politically_federal_parliamentary_constitutional_monarchy']
# ['type', 'parliamentary_monarchy']
# ['type', 'Politically_monarchy']
# ['type', 'Politically_parliamentary_constitutional_monarchy']
# ['type', 'federal_parliamentary_constitutional_monarchy']
# ['type', 'parliamentary_comprising']
# ['type', 'Politically_federal_monarchy']
# ['type', 'Politically_federal_constitutional_monarchy']
# ['type', 'Politically_parliamentary_monarchy']
# ['type', 'constitutional_comprising']
# ['type', 'Politically_constitutional_monarchy']
# ['type', 'parliamentary_constitutional_monarchy']
# ['type', 'Politically_federal_parliamentary_monarchy']
# ['type', 'federal_comprising']
# ['has', 'population']
# ['has', 'demography']
# ['australiaOf', 'population']
# ['australiaTo', 'economy']
# ['has', 'abundant_natural_resources']
# ['countryWith', 'income_economy']
# ['isWith', 'high_income_economy']
# ['type', 'highly_developed_country']
# ['type', 'developed_country']
# ['developed', 'economy']
# ['with', "world_'s_economy"]
# ['economyWith', 'ninth_income']
# ['type', "world_'s_fourteenth_economy"]
# ['with', "world_'s_fourteenth_economy"]
# ['economyWith', 'income']
# ['type', "world_'s_economy"]
# ['economyWith', 'ninth_per_capita_income']
# ['rankedAs', 'fifth_highest_Human_Development_Index']
# ['rankedAs', 'highest_Human_Development_Index']
# ['rankedAs', 'Human_Development_Index']
# ['has', "world_'s_thirteenth_military_expenditure"]
# ['type', 'regional_power']
# ['has', "world_'s_expenditure"]
# ['has', "world_'s_military_expenditure"]
# ['has', "world_'s_thirteenth_expenditure"]
# ['highestIn', 'world']
# ['memberOf', 'groupings']
# ['including', 'international_groupings']
# ['including', 'United_Nations']
# ['type', 'member']
# ['including', 'groupings']
# ['memberOf', 'international_groupings']
#
# ['knownIn', 'leading_man']
# ['knownIn', 'biopics']
# ['recipientOf', 'accolades']
# ['awardIncluding', 'recipient']
# ['awardsIncluding', 'accolades']
# ['awardsIncluding', 'Academy_Award']
# ['awardIncluding', 'numerous_accolades']
# ['recipientOf', 'numerous_accolades']
# ['knownFor', 'his_work']
# ['type', 'recipient']
# ['knownAs', 'leading_man']
# ['knownAs', 'man']
# ['seenIn', 'man']
# ['bornBegan', 'his_career']
# ['had', 'roles']
# ['playedIn', 'roles']
# ['appearedIn', 'television_shows']
# ['in', 'recurring_roles']
# ['appearedIn', 'various_television_shows']
# ['had', 'film_part']
# ['had', 'major_film_part']
# ['had', 'recurring_roles']
# ['had', 'first_major_film_part']
# ['hadAs', 'his_major_film_part']
# ['starredAs', 'author_Tobias_Wolff']
# ['hadAs', 'his_first_film_part']
# ['playedIn', 'early_1990s']
# ['hadAs', 'his_first_major_film_part']
# ['hadAs', 'his_film_part']
# ['had', 'first_film_part']
# ['had', '1990s']
# ['received', 'acclaim']
# ['received', 'critical_acclaim']
# ['describedAs', 'his_performance']
# ['performedAs', 'developmentally_disabled_boy']
# ['performedAs', 'disabled_boy']
# ['diedAt', 'age']
# ['type', 'boy']
# ['wonFor', 'his_performance']
# ['with', 'romances']
# ['achieved', 'international_stardom']
# ['neverAchieved', 'stardom']
# ['starredWith', 'crossed_romances']
# ['reducedFor', 'years']
# ['diedAt', 'time']
# ['reducedFor', 'few_years']
# ['reduced', 'workload']
# ['sought', 'roles']
# ['playsIn', 'genres']
# ['starredIn', 'crime_drama']
# ['starredIn', 'Catch']
# ['actedIn', 'other_genres']
# ['including', 'roles']
# ['soughtIncluding', 'other_genres']
# ['filmsIncluding', 'crime_drama']
# ['soughtIncluding', 'genres']
# ['performances', 'crime_drama']
# ['appearedIn', 'Aviator']
# ['portrayed', 'Howard_Hughes']
# ['praisedIn', 'his_performances']
# ['starredIn', 'thriller_Blood_Diamond']
# ['wonFor', 'his_performances']
# ['awardFor', 'crime_drama']
# ['starredIn', 'political_thriller_Blood_Diamond']
# ['starredIn', "high_profile_directors_'_projects"]
# ['starredIn', "several_high_profile_directors_'_projects"]
# ['starredIn', 'decade']
# ['won', 'Academy_Award']
# ['starredIncluding', "several_high_profile_directors_'_projects"]
# ['filmsIncluding', 'action_thriller_Inception']
# ['starredIncluding', "several_profile_directors_'_projects"]
# ['starredIn', 'western_Django']
# ['directedIncluding', "directors_'_projects"]
# ['starredIn', 'Django']
# ['starredIn', "directors_'_projects"]
# ['starredIncluding', "high_profile_directors_'_projects"]
# ['starredIn', 'romantic_drama']
# ['starredIn', "several_profile_directors_'_projects"]
# ['starredIn', 'drama']
# ['type', 'founder']
# ['founderOf', 'Appian_Way_Productions']
# ['founderOf', 'production_company']
# ['regularlySupports', 'charitable_causes']
# ['workedOn', 'several_documentaries']
# ['documentariesOn', 'environment']
# ['workedOn', 'documentaries']
# ['produced', 'several_documentaries']
# ['produced', 'documentaries']
# ['appearedIn', "Time_magazine_'s_100_people"]
# ['appearedIn', "Time_magazine_'s_100_most_influential_people"]
# ['appearedIn', 'world']
# ['named', 'Commander']
# ['rankOf', 'Commander']
# ['commanderOf', 'Ordre_des_Arts']
# ['appearedIn', "Time_magazine_'s_100_influential_people"]
#
# ['type', 'American_medical_drama_television_series']
# ['type', 'drama_television_series']
# ['has', 'Anatomy']
# ['type', 'medical_drama_television_series']
# ['type', 'American_drama_television_series']
# ['balancing', 'relationships']
# ['relationshipsDevelop', 'while_relationships']
# ['developInto', 'seasoned_doctors']
# ['balancing', 'personal_relationships']
# ['develop', 'personal_relationships']
# ['developInto', 'doctors']
# ['develop', 'relationships']
# ['relationshipsDevelop', 'while_personal_relationships']
# ['filmedIn', 'Seattle']
# ['isIn', 'California']
# ['studiosIn', 'Los_Angeles']
# ['boardOf', 'chief']
# ['chiefOf', 'general_surgery']
# ['chiefOf', 'surgery']
# ['laterBecomes', 'chief']
# ['isAs', 'intern']
# ['isRunning', 'primetime_show']
# ['isScripted', 'scripted_primetime_show']
# ['type', 'primetime_show']
# ['basedOn', 'scripted_primetime_show']
# ['airedOn', 'ABC']
# ['longestRunning', 'scripted_primetime_show']
# ['isRunning', 'longest_running_scripted_primetime_show']
# ['isRunning', 'longest_running_primetime_show']
# ['currentlyOn', 'primetime_show']
# ['isOn', 'longest_running_primetime_show']
# ['isOn', 'longest_running_scripted_primetime_show']
# ['wereAmong', 'five_highest_earning_television_actors']
# ['wereAmong', 'top_five_earning_television_actors']
# ['wereAmong', 'top_five_television_actors']
# ['wereAmong', 'television_actors']
# ['wereAmong', 'five_earning_television_actors']
# ['wereAmong', 'five_television_actors']
# ['wereAmong', 'top_five_highest_earning_television_actors']
# ['on', 'list']
# ['rankedIn', 'its_15th_season']
# ['rankedAs', "ABC_'s_drama"]
# ['rankedAs', "ABC_'s_rated_drama"]
# ['rankedIn', 'its_season']
# ['running', 'American_primetime_drama_series']
# ['type', 'primetime_drama_series']
# ['type', 'primetime_medical_drama_series']
# ['running', 'primetime_drama_series']
# ['running', 'longest_running_American_primetime_medical_drama_series']
# ['type', 'American_primetime_drama_series']
# ['running', 'primetime_medical_drama_series']
# ['running', 'longest_running_American_primetime_drama_series']
# ['running', 'American_primetime_medical_drama_series']
# ['type', 'American_primetime_medical_drama_series']
# ['episodeIn', 'time_character']
# ['eliminatedIn', 'show']
# ['in', 'full_time_character']
# ['type', 'time_character']
# ['justTook', 'step']
# ['type', 'full_time_character']
# ['praisedBy', 'critics']
# ['listOf', 'critics']
# ['mostOf', 'its_run']
# ['yearEnd', "critics_'_year"]
# ['yearEnd', 'top_10_lists']
# ['yearEnd', "various_critics_'_year"]
# ['hadOn', 'effect']
# ['effectOn', 'culture']
# ['hadOn', 'significant_effect']
# ['influenceOn', 'popular_culture']
# ['had', 'significant_effect']
# ['nominatedFor', 'numerous_awards']
# ['nominatedFor', 'Golden_Globe_Award']
# ['awardFor', 'Best_Television_Series']
# ['nominatedFor', 'awards']
# ['had', 'effect']
# ['received', 'numerous_awards']
# ['wonIncluding', 'awards']
# ['wonIncluding', 'Golden_Globe_Award']
# ['received', 'awards']
# ['including', 'numerous_awards']

# %% [markdown]
# 25/323 - GPT
# 130

# %% [markdown]
# bad triples are triples that either contains information that is false or triples that do not make sense (e.g. relation - finishedBefore object - months )
#
#
# ChatGPT information extracted is highly precise with many entities having no false triples created. There are still a few cases where the model gets confused and creates vaguely false triples, such as when talking about the first europeans to come to Australia creating odd triples such as mapped eastcoast and established newsouthwales. These triples are created with correct information but without context the triples do not make sense and dilute the performance of the triples performance for that entity.
#
# ClauCy created a large amount of truthfully triples, just not to the high standards of Chat-GPT, for example, ClauCy created 'Heath Ledger recieved nominations' whist GPT listed all the awards Heath Ledger won. ClauCy would also create bad triple formations such as 'relation - april object -April' which is not a relevant triple for any entity. These error occurred a lot more in Stanford.
#
# Stanford whilst was known to be the weakest of the two openIE models(link), it created triples with information that even chatGPT did not create such as, to back to the previous example, Heath Ledger was an Australian actor and moved to America, which chatgpt did not create. This advance in Information extraction was due to stanford extract usually more than double the amount of triples the other model do. With this large amount of triples created a large portion of them being inaccurate or does not convey anything, most likely leading to Stanford creating the most amount of bad triples by far.
#
# By manually viewing a random sample of entities triples created by the 3 IE models, it can be seen that GPT extracts the most information at the highest accuracy. however, ChatGT still has its own issues, mainly encircling three topics. The first being the formatting of the triples. The Chatbot struggles to create triples, for all the entites, in the same manor, for example, changing between 'work', 'career', and 'film' when talking abbout movies and shows actors have been in or swtiching between strings and links for objects (schema:Person and 'Person'@en). Due to the spontanity of chatgpts different responses and having a seperate query for each entity, GPT could not create a univeral format for the triples it created.
#
# The second issue consists of the bot creating errors. The knowledge bot would extract information but at some point the specific information would be lost and it would create a vague triple, such as Robert Downy jnr. hasWork Work1,2,3... . This creates connections between entities that should not exist, creating splits that may happen have occurred during the 20Q tournament. This tendensy in the bot creates false information in a way that the other 2 models wouldn't
#
# The final issue is the models unbound requirement to access external knowledge bases such as Dbpedia. Whilst being extremely rare in the model, it can be seen that accationaly that the model is accessing some sort of knowlegde base, it can be seen that it accesssed one for Lenonardo DiCaprio as one of the triples contains a link to his website homepage, that is not present in his wikipedia abstract. Even when specified not to access DBpedia, the model still continues to showing limited specifications that can be put on the model at the moment
