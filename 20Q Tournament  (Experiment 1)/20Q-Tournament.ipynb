# %% [markdown]
# ## Code

# %%
# %load_ext ipython_sparql_pandas

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from random import randint
sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q')
sparql.setReturnFormat(JSON)

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']

def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    #ret = result.queryAndConvert()
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    return(listOfObj,listOfPred)

def generateQuestion(listOfPred, listOfObj, index, subject):
    flag = True
    if ('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>') in AttrHistory:
        return generateQuestion(listOfPred, listOfObj, index+1, subject)
        
    else:
        AttrHistory.append('<' + str(listOfPred[index]['value']) +'> <'+str(listOfObj[index]['value'])+ '>')
        
    #print(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    try:
        listOfObj[index]['datatype']
    except:
        flag = False
        
    if flag is True:
        datatype = listOfObj[index]["datatype"].split("#")[-1]
        answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '"'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype)
    else:
        if len(listOfObj[index]["value"].split('/')) == 1:
            answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '"'+str(listOfObj[index]['value'])+ '"')
        else:
            answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '<'+str(listOfObj[index]['value'])+ '>')
    #print(answer)
    
    
    if answer:
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
            if len(listOfObj[index]["value"].split('/')) == 1:
                PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+ '".')  
            else:
                PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.')    
        
    elif not answer:
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
            if len(listOfObj[index]["value"].split('/')) == 1:
                NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+ '". }}') 
            else:
                NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}')   
        
    else:
        return generateQuestion(listOfPred, listOfObj, index+1)
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    return (PosFilters, NegFilters)

  
def updateQuery(left, PosFilters, NegFilters):
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            
            group by ?p ?o 
            ORDER BY ABS( {left} - ?count )
            Limit 10
            
            """) 
        
    return FilterQuestion

# %%
def pickSubject():
    #ind=randint(0,10000)
    entities = []
    query = f"""
    select distinct ?s
    where {{
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
    }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        entities.append(r['s']['value'])
        #return("<"+r["s"]["value"]+">")
    #data = pd.read_csv('abstracts.csv')
    return entities

def findAnswer(subject,p,o):
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    #print(subject)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
def numberleft(PosFilters,NegFilters):
    sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q')
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            {PosFilters}            
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            {NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            
            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))

# %%
def popentities(PosFilters,NegFilters):
    query =  f"""
            select ?s where 
            {{
            
            {PosFilters}
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            {NegFilters} 
            
            }}
            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    return qres["results"]["bindings"]

# %%
# resets are variables
def game_reset():
    PosAttr= ['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .']
    NegAttr= ['']
    AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    left = numberleft("".join(PosAttr), "".join(NegAttr))
    FilterQuestion =  f"""
        select (count(*) as ?count) ?p ?o  where 
        {{

        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s ?p ?o .
        }} 
        group by ?p ?o 
        ORDER BY ABS( %s - ?count )
        limit 20
        """ %((left/2))
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
import pandas as pd 
data1 = pd.read_csv('Abstracts-186.csv')
data1 = data1.drop('Unnamed: 0', axis=1)

data1
# Out:
#                                                 Entity
# 0       http://yago-knowledge.org/resource/David_Bowie  \
# 1        http://yago-knowledge.org/resource/Kanye_West
# 2            http://yago-knowledge.org/resource/Eminem
# 3    http://yago-knowledge.org/resource/Jennifer_An...
# 4    http://yago-knowledge.org/resource/George_W._Bush
# ..                                                 ...
# 179    http://yago-knowledge.org/resource/Nancy_Pelosi
# 180  http://yago-knowledge.org/resource/Andhra_Pradesh
# 181     http://yago-knowledge.org/resource/Maharashtra
# 182  http://yago-knowledge.org/resource/Paris_Saint...
# 183   http://yago-knowledge.org/resource/Uttar_Pradesh
#
#                         Label
# 0                 David Bowie  \
# 1                  Kanye West
# 2                      Eminem
# 3            Jennifer Aniston
# 4              George W. Bush
# ..                        ...
# 179              Nancy Pelosi
# 180            Andhra Pradesh
# 181               Maharashtra
# 182  Paris Saint-Germain F.C.
# 183             Uttar Pradesh
#
#                                               Abstract
# 0    David Robert Jones (8 January 1947 – 10 Januar...
# 1    Ye (/jeɪ/ YAY; born Kanye Omari West /ˈkɑːnjeɪ...
# 2    Marshall Bruce Mathers III (born October 17, 1...
# 3    Jennifer Joanna Aniston (born February 11, 196...
# 4    George Walker Bush (born July 6, 1946) is an A...
# ..                                                 ...
# 179  Nancy Patricia Pelosi (/pəˈloʊsi/; née D'Alesa...
# 180  Andhra Pradesh (English: /ˌɑːndrə prəˈdɛʃ/, Te...
# 181  Maharashtra (/məhɑːˈrɑːʃtrə/; Marathi: [məhara...
# 182  Paris Saint-Germain Football Club (French pron...
# 183  Uttar Pradesh (/ˌʊtər prəˈdɛʃ/; Hindi: [ˈʊtːəɾ...
#
# [184 rows x 3 columns]

# %%
import random
random.seed(10)
random.sample(pickSubject(), 1000)
# Out:
# ['http://yago-knowledge.org/resource/Helena_Bonham_Carter',
#  'http://yago-knowledge.org/resource/Eileen_Atkins',
#  'http://yago-knowledge.org/resource/Ellie_Kemper',
#  'http://yago-knowledge.org/resource/Youth_in_Revolt_(film)',
#  'http://yago-knowledge.org/resource/Airport_(1970_film)',
#  'http://yago-knowledge.org/resource/Mozambique',
#  'http://yago-knowledge.org/resource/Macalester_College',
#  'http://yago-knowledge.org/resource/KLM',
#  'http://yago-knowledge.org/resource/Pensacola,_Florida',
#  'http://yago-knowledge.org/resource/Telemundo',
#  'http://yago-knowledge.org/resource/Quills',
#  'http://yago-knowledge.org/resource/Bursaspor',
#  'http://yago-knowledge.org/resource/Film_noir',
#  'http://yago-knowledge.org/resource/Natchez,_Mississippi',
#  'http://yago-knowledge.org/resource/1960_Winter_Olympics',
#  'http://yago-knowledge.org/resource/Spencer_Tracy',
#  'http://yago-knowledge.org/resource/N._T._Rama_Rao',
#  'http://yago-knowledge.org/resource/Porto',
#  'http://yago-knowledge.org/resource/Peter_Capaldi',
#  'http://yago-knowledge.org/resource/Ryanair',
#  'http://yago-knowledge.org/resource/Jerry_Lewis',
#  'http://yago-knowledge.org/resource/Richard_Edlund',
#  "http://yago-knowledge.org/resource/St_Catherine's_College,_Oxford",
#  'http://yago-knowledge.org/resource/Method_Man',
#  'http://yago-knowledge.org/resource/California_State_University,_Los_Angeles',
#  'http://yago-knowledge.org/resource/Salem,_Massachusetts',
#  'http://yago-knowledge.org/resource/Sarah_McLachlan',
#  'http://yago-knowledge.org/resource/Los_Angeles_Chargers',
#  'http://yago-knowledge.org/resource/Tak_Fujimoto',
#  'http://yago-knowledge.org/resource/CD_Tenerife',
#  'http://yago-knowledge.org/resource/Windsor_Castle',
#  'http://yago-knowledge.org/resource/Chris_Noth',
#  'http://yago-knowledge.org/resource/Multi-instrumentalist',
#  'http://yago-knowledge.org/resource/Golden_Raspberry_Award_for_Worst_Screenplay',
#  'http://yago-knowledge.org/resource/2K_(company)',
#  'http://yago-knowledge.org/resource/Inter_Milan',
#  'http://yago-knowledge.org/resource/Battle_of_France',
#  'http://yago-knowledge.org/resource/Jean_Louis',
#  'http://yago-knowledge.org/resource/Storyboard_artist',
#  'http://yago-knowledge.org/resource/Cleopatra_(1963_film)',
#  'http://yago-knowledge.org/resource/Toho',
#  'http://yago-knowledge.org/resource/Dante_Spinotti',
#  'http://yago-knowledge.org/resource/Chatham_County,_Georgia',
#  'http://yago-knowledge.org/resource/F.C._Ashdod',
#  'http://yago-knowledge.org/resource/Million_Dollar_Baby',
#  'http://yago-knowledge.org/resource/Marc_Anthony',
#  'http://yago-knowledge.org/resource/Taking_Woodstock',
#  'http://yago-knowledge.org/resource/Newton,_Massachusetts',
#  'http://yago-knowledge.org/resource/Berlin',
#  'http://yago-knowledge.org/resource/Shelby_County,_Tennessee',
#  'http://yago-knowledge.org/resource/The_World_Is_Not_Enough',
#  'http://yago-knowledge.org/resource/Catholic_Church',
#  'http://yago-knowledge.org/resource/Frank_Herbert',
#  'http://yago-knowledge.org/resource/Valkyrie_(film)',
#  'http://yago-knowledge.org/resource/Will_County,_Illinois',
#  'http://yago-knowledge.org/resource/New_Delhi',
#  'http://yago-knowledge.org/resource/Macau',
#  'http://yago-knowledge.org/resource/The_Barbarian_Invasions',
#  'http://yago-knowledge.org/resource/Oberlin_College',
#  'http://yago-knowledge.org/resource/U.S._Sassuolo_Calcio',
#  'http://yago-knowledge.org/resource/Entourage_(American_TV_series)',
#  'http://yago-knowledge.org/resource/Hollywood',
#  'http://yago-knowledge.org/resource/Craig_Robinson_(actor)',
#  'http://yago-knowledge.org/resource/Kidult',
#  'http://yago-knowledge.org/resource/Jack_L._Warner',
#  'http://yago-knowledge.org/resource/David_Simon',
#  'http://yago-knowledge.org/resource/Xbox_Game_Studios',
#  'http://yago-knowledge.org/resource/Norman_Taurog',
#  'http://yago-knowledge.org/resource/Columbia_College_(New_York)',
#  'http://yago-knowledge.org/resource/Lesley_Sharp',
#  'http://yago-knowledge.org/resource/Roy_Orbison',
#  "http://yago-knowledge.org/resource/Kids'_WB",
#  'http://yago-knowledge.org/resource/Royal_Antwerp_F.C.',
#  'http://yago-knowledge.org/resource/Dionne_Warwick',
#  'http://yago-knowledge.org/resource/Armageddon_(1998_film)',
#  'http://yago-knowledge.org/resource/Tim_Blake_Nelson',
#  'http://yago-knowledge.org/resource/ESPN',
#  'http://yago-knowledge.org/resource/John_Lee_Hooker',
#  'http://yago-knowledge.org/resource/Transylvania',
#  'http://yago-knowledge.org/resource/The_Madness_of_King_George',
#  'http://yago-knowledge.org/resource/Charleston_Battery',
#  'http://yago-knowledge.org/resource/Matt_Stone',
#  'http://yago-knowledge.org/resource/Alastair_Reynolds',
#  'http://yago-knowledge.org/resource/FC_Sion',
#  'http://yago-knowledge.org/resource/Allen_Covert',
#  'http://yago-knowledge.org/resource/Rouen',
#  'http://yago-knowledge.org/resource/Pier_Paolo_Pasolini',
#  'http://yago-knowledge.org/resource/Post-punk',
#  'http://yago-knowledge.org/resource/Metalcore',
#  'http://yago-knowledge.org/resource/Anthony_Anderson',
#  'http://yago-knowledge.org/resource/Ruth_Gordon',
#  'http://yago-knowledge.org/resource/Mobile_Suit_Gundam_SEED',
#  'http://yago-knowledge.org/resource/Kristen_Stewart',
#  'http://yago-knowledge.org/resource/Nashua,_New_Hampshire',
#  'http://yago-knowledge.org/resource/Bea_Arthur',
#  'http://yago-knowledge.org/resource/Bernadette_Peters',
#  'http://yago-knowledge.org/resource/Star_Trek_(film)',
#  'http://yago-knowledge.org/resource/Ip_Man_(film)',
#  'http://yago-knowledge.org/resource/Malaysia_national_football_team',
#  'http://yago-knowledge.org/resource/New_World_Pictures',
#  'http://yago-knowledge.org/resource/Derbyshire',
#  'http://yago-knowledge.org/resource/University_of_Detroit_Mercy',
#  'http://yago-knowledge.org/resource/Beverly_Hills,_90210',
#  'http://yago-knowledge.org/resource/Girton_College,_Cambridge',
#  'http://yago-knowledge.org/resource/Sonic_X',
#  'http://yago-knowledge.org/resource/Ronald_D._Moore',
#  'http://yago-knowledge.org/resource/Moldova',
#  'http://yago-knowledge.org/resource/Jean_Passanante',
#  'http://yago-knowledge.org/resource/Edwin_B._Willis',
#  'http://yago-knowledge.org/resource/Preity_Zinta',
#  'http://yago-knowledge.org/resource/John_Legend',
#  'http://yago-knowledge.org/resource/Radiohead',
#  'http://yago-knowledge.org/resource/The_Straight_Story',
#  'http://yago-knowledge.org/resource/Martin_Donovan',
#  'http://yago-knowledge.org/resource/Hungarian_language',
#  'http://yago-knowledge.org/resource/Albert_Wolsky',
#  'http://yago-knowledge.org/resource/Indian_Rebellion_of_1857',
#  'http://yago-knowledge.org/resource/Cleveland_State_University',
#  'http://yago-knowledge.org/resource/Platoon_(film)',
#  'http://yago-knowledge.org/resource/London_School_of_Economics',
#  'http://yago-knowledge.org/resource/ER_(TV_series)',
#  'http://yago-knowledge.org/resource/Russian_Americans',
#  'http://yago-knowledge.org/resource/Palm_Desert,_California',
#  'http://yago-knowledge.org/resource/SpongeBob_SquarePants',
#  'http://yago-knowledge.org/resource/North_(1994_film)',
#  'http://yago-knowledge.org/resource/Hercules_(1997_film)',
#  'http://yago-knowledge.org/resource/Joely_Richardson',
#  'http://yago-knowledge.org/resource/Neil_Jordan',
#  'http://yago-knowledge.org/resource/David_McCallum',
#  'http://yago-knowledge.org/resource/St._Augustine,_Florida',
#  'http://yago-knowledge.org/resource/Kaneto_Shiozawa',
#  'http://yago-knowledge.org/resource/The_Monkees',
#  'http://yago-knowledge.org/resource/Ingham_County,_Michigan',
#  'http://yago-knowledge.org/resource/Skeleton_(sport)',
#  'http://yago-knowledge.org/resource/Calvin_University',
#  'http://yago-knowledge.org/resource/Martin_Heidegger',
#  'http://yago-knowledge.org/resource/Purple_Heart',
#  'http://yago-knowledge.org/resource/Internal_medicine',
#  'http://yago-knowledge.org/resource/David_Mansfield',
#  'http://yago-knowledge.org/resource/Al_Roker',
#  'http://yago-knowledge.org/resource/50th_Annual_Grammy_Awards',
#  "http://yago-knowledge.org/resource/Recess:_School's_Out",
#  'http://yago-knowledge.org/resource/Telecommunication',
#  'http://yago-knowledge.org/resource/Jaws_3-D',
#  'http://yago-knowledge.org/resource/Charlotte_Hornets',
#  'http://yago-knowledge.org/resource/Dune_(1984_film)',
#  'http://yago-knowledge.org/resource/Transformers',
#  'http://yago-knowledge.org/resource/Casey_Affleck',
#  'http://yago-knowledge.org/resource/Salma_Hayek',
#  'http://yago-knowledge.org/resource/Dutch_Americans',
#  'http://yago-knowledge.org/resource/Clive_Davis',
#  'http://yago-knowledge.org/resource/University_of_Paris',
#  'http://yago-knowledge.org/resource/Provost_(education)',
#  'http://yago-knowledge.org/resource/1904_Summer_Olympics',
#  'http://yago-knowledge.org/resource/Betty_Comden',
#  'http://yago-knowledge.org/resource/Black_Sabbath',
#  'http://yago-knowledge.org/resource/Sangju_Sangmu_FC',
#  'http://yago-knowledge.org/resource/Mogadishu',
#  'http://yago-knowledge.org/resource/Lancaster_County,_Pennsylvania',
#  'http://yago-knowledge.org/resource/Hartlepool_United_F.C.',
#  'http://yago-knowledge.org/resource/Metro_Manila',
#  'http://yago-knowledge.org/resource/Grenada',
#  'http://yago-knowledge.org/resource/Ian_Somerhalder',
#  'http://yago-knowledge.org/resource/U.C._Sampdoria',
#  'http://yago-knowledge.org/resource/Anton_Yelchin',
#  'http://yago-knowledge.org/resource/Ashlee_Simpson',
#  'http://yago-knowledge.org/resource/Hawaiian_Islands',
#  'http://yago-knowledge.org/resource/Francis_Ford_Coppola',
#  'http://yago-knowledge.org/resource/Brian_Baumgartner',
#  'http://yago-knowledge.org/resource/1982_Cannes_Film_Festival',
#  'http://yago-knowledge.org/resource/The_Spiderwick_Chronicles_(film)',
#  'http://yago-knowledge.org/resource/Disney_Channel',
#  'http://yago-knowledge.org/resource/William_Demarest',
#  'http://yago-knowledge.org/resource/Samuel_Z._Arkoff',
#  'http://yago-knowledge.org/resource/XXX_(2002_film)',
#  'http://yago-knowledge.org/resource/Blake_Lively',
#  'http://yago-knowledge.org/resource/Ludwig_van_Beethoven',
#  'http://yago-knowledge.org/resource/The_Lady_(2011_film)',
#  'http://yago-knowledge.org/resource/Swedish_Empire',
#  'http://yago-knowledge.org/resource/Molly_Parker',
#  'http://yago-knowledge.org/resource/Fernando_Trueba',
#  'http://yago-knowledge.org/resource/West_Midlands_(county)',
#  'http://yago-knowledge.org/resource/Dianne_Wiest',
#  'http://yago-knowledge.org/resource/Detroit',
#  'http://yago-knowledge.org/resource/Ohio_University',
#  'http://yago-knowledge.org/resource/Franz_Waxman',
#  'http://yago-knowledge.org/resource/Utrecht_University',
#  'http://yago-knowledge.org/resource/Ayn_Rand',
#  'http://yago-knowledge.org/resource/Siobhan_Finneran',
#  'http://yago-knowledge.org/resource/Ohio_River',
#  'http://yago-knowledge.org/resource/Xavier_University',
#  'http://yago-knowledge.org/resource/Anatole_Litvak',
#  'http://yago-knowledge.org/resource/Liza_Minnelli',
#  'http://yago-knowledge.org/resource/Toby_Keith',
#  'http://yago-knowledge.org/resource/Speed_metal',
#  'http://yago-knowledge.org/resource/Tyler,_Texas',
#  'http://yago-knowledge.org/resource/Will_Forte',
#  'http://yago-knowledge.org/resource/The_Andy_Griffith_Show',
#  'http://yago-knowledge.org/resource/The_Royal_Tenenbaums',
#  'http://yago-knowledge.org/resource/Rush_Hour_3',
#  'http://yago-knowledge.org/resource/Philippines_national_football_team',
#  'http://yago-knowledge.org/resource/Mark_Goodson',
#  'http://yago-knowledge.org/resource/A_Simple_Life',
#  'http://yago-knowledge.org/resource/Droylsden_F.C.',
#  'http://yago-knowledge.org/resource/Showtime_(film)',
#  'http://yago-knowledge.org/resource/Scarlett_(miniseries)',
#  'http://yago-knowledge.org/resource/Shriram_Lagoo',
#  'http://yago-knowledge.org/resource/First_Indochina_War',
#  'http://yago-knowledge.org/resource/Ukrainian_language',
#  'http://yago-knowledge.org/resource/Asthma',
#  'http://yago-knowledge.org/resource/Norfolk_Admirals_(AHL)',
#  'http://yago-knowledge.org/resource/Kenan_Thompson',
#  'http://yago-knowledge.org/resource/Rutina_Wesley',
#  "http://yago-knowledge.org/resource/Duke_Blue_Devils_men's_basketball",
#  'http://yago-knowledge.org/resource/John_Paul_Jones_(musician)',
#  'http://yago-knowledge.org/resource/Gene_Callahan',
#  'http://yago-knowledge.org/resource/Rochdale_A.F.C.',
#  'http://yago-knowledge.org/resource/Chiapas',
#  'http://yago-knowledge.org/resource/David_Niven',
#  'http://yago-knowledge.org/resource/Frank_Vincent',
#  'http://yago-knowledge.org/resource/Vinnie_Jones',
#  'http://yago-knowledge.org/resource/Bernie_Mac',
#  'http://yago-knowledge.org/resource/Eli_Wallach',
#  'http://yago-knowledge.org/resource/Metallica:_Some_Kind_of_Monster',
#  'http://yago-knowledge.org/resource/Ethiopia',
#  'http://yago-knowledge.org/resource/New_York_City',
#  'http://yago-knowledge.org/resource/Cumbria',
#  'http://yago-knowledge.org/resource/Basil_Poledouris',
#  'http://yago-knowledge.org/resource/Standing_in_the_Shadows_of_Motown',
#  'http://yago-knowledge.org/resource/Herkimer_County,_New_York',
#  'http://yago-knowledge.org/resource/Code_Geass',
#  'http://yago-knowledge.org/resource/Corsica',
#  'http://yago-knowledge.org/resource/Tufts_University',
#  'http://yago-knowledge.org/resource/Warwickshire',
#  'http://yago-knowledge.org/resource/Josh_Schwartz',
#  'http://yago-knowledge.org/resource/M._Emmet_Walsh',
#  'http://yago-knowledge.org/resource/Jung_Sung-ryong',
#  'http://yago-knowledge.org/resource/Peter_Fonda',
#  'http://yago-knowledge.org/resource/Jerry_Belson',
#  'http://yago-knowledge.org/resource/Christine_Lahti',
#  'http://yago-knowledge.org/resource/Julie_Walters',
#  "http://yago-knowledge.org/resource/Children's_music",
#  'http://yago-knowledge.org/resource/Cebu',
#  'http://yago-knowledge.org/resource/UEFA',
#  'http://yago-knowledge.org/resource/Costume_designer',
#  'http://yago-knowledge.org/resource/CBS_News',
#  'http://yago-knowledge.org/resource/Leaving_Las_Vegas',
#  'http://yago-knowledge.org/resource/Warren_County,_New_Jersey',
#  'http://yago-knowledge.org/resource/Bossa_nova',
#  'http://yago-knowledge.org/resource/Saturn_Award_for_Best_Writing',
#  'http://yago-knowledge.org/resource/Chess',
#  'http://yago-knowledge.org/resource/Minden,_Louisiana',
#  "http://yago-knowledge.org/resource/Pirates_of_the_Caribbean:_At_World's_End",
#  'http://yago-knowledge.org/resource/Thunder_Bay',
#  'http://yago-knowledge.org/resource/Blazing_Saddles',
#  'http://yago-knowledge.org/resource/Dilys_Award',
#  'http://yago-knowledge.org/resource/Decatur,_Alabama',
#  'http://yago-knowledge.org/resource/Quest_for_Fire_(film)',
#  'http://yago-knowledge.org/resource/YTV_(TV_channel)',
#  'http://yago-knowledge.org/resource/Staffordshire',
#  'http://yago-knowledge.org/resource/Hip_hop_soul',
#  'http://yago-knowledge.org/resource/Mario_Kassar',
#  'http://yago-knowledge.org/resource/Sissy_Spacek',
#  'http://yago-knowledge.org/resource/Jackass_3D',
#  'http://yago-knowledge.org/resource/Alan_Turing',
#  'http://yago-knowledge.org/resource/Christchurch',
#  'http://yago-knowledge.org/resource/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie',
#  'http://yago-knowledge.org/resource/Ernest_Lehman',
#  'http://yago-knowledge.org/resource/Illinois_Institute_of_Technology',
#  'http://yago-knowledge.org/resource/Delroy_Lindo',
#  'http://yago-knowledge.org/resource/Austria_national_football_team',
#  'http://yago-knowledge.org/resource/Vin_Diesel',
#  'http://yago-knowledge.org/resource/Santhanam_(actor)',
#  'http://yago-knowledge.org/resource/Drexel_University',
#  'http://yago-knowledge.org/resource/From_Here_to_Eternity',
#  'http://yago-knowledge.org/resource/Adolf_Hitler',
#  'http://yago-knowledge.org/resource/Hillsborough_County,_New_Hampshire',
#  'http://yago-knowledge.org/resource/Penelope_Wilton',
#  'http://yago-knowledge.org/resource/Bronxville,_New_York',
#  'http://yago-knowledge.org/resource/Marin_County,_California',
#  'http://yago-knowledge.org/resource/Coldplay',
#  'http://yago-knowledge.org/resource/Arsenal_F.C.',
#  'http://yago-knowledge.org/resource/Tooth_&_Nail_Records',
#  'http://yago-knowledge.org/resource/Paul_Frees',
#  'http://yago-knowledge.org/resource/Wichita,_Kansas',
#  'http://yago-knowledge.org/resource/Alan_Oppenheimer',
#  'http://yago-knowledge.org/resource/SK_Slavia_Prague',
#  'http://yago-knowledge.org/resource/Walter_Murphy',
#  'http://yago-knowledge.org/resource/Rhythm_and_blues',
#  'http://yago-knowledge.org/resource/The_Godfather_Part_II',
#  'http://yago-knowledge.org/resource/Eat_Pray_Love',
#  'http://yago-knowledge.org/resource/Matthew_McConaughey',
#  'http://yago-knowledge.org/resource/Jane_Austen',
#  'http://yago-knowledge.org/resource/David_Morse',
#  'http://yago-knowledge.org/resource/Peter_Farrelly',
#  'http://yago-knowledge.org/resource/Grammy_Award_for_Best_Rap_Solo_Performance',
#  'http://yago-knowledge.org/resource/Torrance,_California',
#  'http://yago-knowledge.org/resource/David_Angell',
#  'http://yago-knowledge.org/resource/Johnny_Depp',
#  'http://yago-knowledge.org/resource/American_Psycho_(film)',
#  'http://yago-knowledge.org/resource/Evangeline_Lilly',
#  'http://yago-knowledge.org/resource/Nordic_combined',
#  'http://yago-knowledge.org/resource/Keith_Jarrett',
#  'http://yago-knowledge.org/resource/Haiti',
#  'http://yago-knowledge.org/resource/Eau_Claire,_Wisconsin',
#  'http://yago-knowledge.org/resource/Tomokazu_Seki',
#  'http://yago-knowledge.org/resource/Richard_Linklater',
#  'http://yago-knowledge.org/resource/Dan_Aykroyd',
#  'http://yago-knowledge.org/resource/Ventura,_California',
#  'http://yago-knowledge.org/resource/Greg_Ayres',
#  'http://yago-knowledge.org/resource/Academy_Award_for_Best_Visual_Effects',
#  'http://yago-knowledge.org/resource/University_of_Dayton',
#  'http://yago-knowledge.org/resource/Thrash_metal',
#  'http://yago-knowledge.org/resource/Kalamazoo,_Michigan',
#  'http://yago-knowledge.org/resource/13th_Screen_Actors_Guild_Awards',
#  'http://yago-knowledge.org/resource/Irving_Thalberg',
#  'http://yago-knowledge.org/resource/Irish_migration_to_Great_Britain',
#  'http://yago-knowledge.org/resource/Golden_Raspberry_Award_for_Worst_Original_Song',
#  'http://yago-knowledge.org/resource/The_Grapes_of_Wrath_(film)',
#  'http://yago-knowledge.org/resource/Invercargill',
#  'http://yago-knowledge.org/resource/Gregory_Peck',
#  'http://yago-knowledge.org/resource/Dennis_Hopper',
#  'http://yago-knowledge.org/resource/Power_Rangers',
#  'http://yago-knowledge.org/resource/Tehran',
#  'http://yago-knowledge.org/resource/Soprano',
#  'http://yago-knowledge.org/resource/Oliver_Twist_(2005_film)',
#  'http://yago-knowledge.org/resource/Colm_Meaney',
#  'http://yago-knowledge.org/resource/Southeast_Asia',
#  'http://yago-knowledge.org/resource/Saint_Vincent_and_the_Grenadines',
#  'http://yago-knowledge.org/resource/Jon_Stone',
#  'http://yago-knowledge.org/resource/Yes_Man_(film)',
#  'http://yago-knowledge.org/resource/Washtenaw_County,_Michigan',
#  'http://yago-knowledge.org/resource/County_Dublin',
#  'http://yago-knowledge.org/resource/Salmon_Fishing_in_the_Yemen',
#  'http://yago-knowledge.org/resource/Daniel_Craig',
#  'http://yago-knowledge.org/resource/Juneau,_Alaska',
#  'http://yago-knowledge.org/resource/Princeton_Theological_Seminary',
#  'http://yago-knowledge.org/resource/Carl_Friedrich_Gauss',
#  'http://yago-knowledge.org/resource/Elektra_(2005_film)',
#  'http://yago-knowledge.org/resource/Lucien_Ballard',
#  'http://yago-knowledge.org/resource/Terence_Blanchard',
#  'http://yago-knowledge.org/resource/Lower_Saxony',
#  "http://yago-knowledge.org/resource/Michael_O'Neill_(footballer)",
#  'http://yago-knowledge.org/resource/Alan_Arkin',
#  'http://yago-knowledge.org/resource/Dabney_Coleman',
#  'http://yago-knowledge.org/resource/Master_of_Fine_Arts',
#  'http://yago-knowledge.org/resource/Jake_Shimabukuro',
#  'http://yago-knowledge.org/resource/Randers_FC',
#  'http://yago-knowledge.org/resource/T-Pain',
#  'http://yago-knowledge.org/resource/Barry_Corbin',
#  'http://yago-knowledge.org/resource/American_Splendor_(film)',
#  'http://yago-knowledge.org/resource/Horrible_Bosses',
#  'http://yago-knowledge.org/resource/Tori_Spelling',
#  'http://yago-knowledge.org/resource/The_Brothers_Bloom',
#  'http://yago-knowledge.org/resource/STV_(TV_channel)',
#  'http://yago-knowledge.org/resource/Gaston_County,_North_Carolina',
#  'http://yago-knowledge.org/resource/Neal_McDonough',
#  'http://yago-knowledge.org/resource/Stalag_17',
#  'http://yago-knowledge.org/resource/Prometheus_Award',
#  'http://yago-knowledge.org/resource/Drew_Barrymore',
#  'http://yago-knowledge.org/resource/The_Surreal_Life',
#  'http://yago-knowledge.org/resource/Electorate_of_Saxony',
#  'http://yago-knowledge.org/resource/Grant_Morrison',
#  'http://yago-knowledge.org/resource/Poitou-Charentes',
#  'http://yago-knowledge.org/resource/Marvin_Hamlisch',
#  'http://yago-knowledge.org/resource/John_Turturro',
#  'http://yago-knowledge.org/resource/The_Untouchables_(film)',
#  'http://yago-knowledge.org/resource/Lincoln_(film)',
#  'http://yago-knowledge.org/resource/Baroque_music',
#  'http://yago-knowledge.org/resource/Portland_metropolitan_area',
#  'http://yago-knowledge.org/resource/Macclesfield',
#  'http://yago-knowledge.org/resource/Peter_David',
#  'http://yago-knowledge.org/resource/Chelsea_F.C.',
#  'http://yago-knowledge.org/resource/Kirsten_Dunst',
#  'http://yago-knowledge.org/resource/Valencia',
#  'http://yago-knowledge.org/resource/Milan_Conservatory',
#  'http://yago-knowledge.org/resource/An_Early_Frost',
#  'http://yago-knowledge.org/resource/Clallam_County,_Washington',
#  'http://yago-knowledge.org/resource/Mandarin_Chinese',
#  'http://yago-knowledge.org/resource/Swimming_Upstream',
#  'http://yago-knowledge.org/resource/MTV2',
#  'http://yago-knowledge.org/resource/CSI:_Crime_Scene_Investigation',
#  'http://yago-knowledge.org/resource/David_Wain',
#  'http://yago-knowledge.org/resource/Imperial_Records',
#  'http://yago-knowledge.org/resource/Lois_Smith',
#  'http://yago-knowledge.org/resource/Terminator_3:_Rise_of_the_Machines',
#  'http://yago-knowledge.org/resource/Modern_Family',
#  'http://yago-knowledge.org/resource/Andrew_Lincoln',
#  'http://yago-knowledge.org/resource/J._T._Walsh',
#  'http://yago-knowledge.org/resource/Primary_Colors_(film)',
#  'http://yago-knowledge.org/resource/Babyface_(musician)',
#  'http://yago-knowledge.org/resource/Wayne_State_University',
#  'http://yago-knowledge.org/resource/Thomas_Haden_Church',
#  'http://yago-knowledge.org/resource/Broward_County,_Florida',
#  'http://yago-knowledge.org/resource/Sucrose',
#  'http://yago-knowledge.org/resource/University_of_the_Pacific_(United_States)',
#  'http://yago-knowledge.org/resource/Billy_Crudup',
#  'http://yago-knowledge.org/resource/Constantine_(film)',
#  'http://yago-knowledge.org/resource/Brisbane_Roar_FC',
#  'http://yago-knowledge.org/resource/Bluegrass_music',
#  'http://yago-knowledge.org/resource/Eriq_La_Salle',
#  'http://yago-knowledge.org/resource/Oaxaca',
#  'http://yago-knowledge.org/resource/The_Black_Eyed_Peas',
#  'http://yago-knowledge.org/resource/Will_Patton',
#  'http://yago-knowledge.org/resource/The_Wicker_Man_(2006_film)',
#  'http://yago-knowledge.org/resource/Cuba_Gooding_Jr.',
#  'http://yago-knowledge.org/resource/TV_Tokyo',
#  'http://yago-knowledge.org/resource/David_Healy_(footballer)',
#  'http://yago-knowledge.org/resource/Frank_Skinner_(composer)',
#  "http://yago-knowledge.org/resource/2004_NCAA_Division_I_Men's_Basketball_Tournament",
#  'http://yago-knowledge.org/resource/Noah_Wyle',
#  'http://yago-knowledge.org/resource/Japan',
#  'http://yago-knowledge.org/resource/Arthur_Laurents',
#  'http://yago-knowledge.org/resource/104th_United_States_Congress',
#  'http://yago-knowledge.org/resource/Muskegon,_Michigan',
#  'http://yago-knowledge.org/resource/Bridget_Fonda',
#  'http://yago-knowledge.org/resource/Maximilian_Schell',
#  'http://yago-knowledge.org/resource/Primetime_Emmy_Award_for_Outstanding_Writing_for_a_Variety_Series',
#  'http://yago-knowledge.org/resource/Vallejo,_California',
#  'http://yago-knowledge.org/resource/Dr._No_(film)',
#  'http://yago-knowledge.org/resource/F.C._Copenhagen',
#  'http://yago-knowledge.org/resource/Ben_10_(2005_TV_series)',
#  'http://yago-knowledge.org/resource/Bruce_Beresford',
#  'http://yago-knowledge.org/resource/Olivia_Williams',
#  'http://yago-knowledge.org/resource/Malcolm_David_Kelley',
#  'http://yago-knowledge.org/resource/Crossover_thrash',
#  'http://yago-knowledge.org/resource/The_Lives_of_a_Bengal_Lancer_(film)',
#  'http://yago-knowledge.org/resource/Satellite_Award_for_Best_Cinematography',
#  'http://yago-knowledge.org/resource/David_Spade',
#  'http://yago-knowledge.org/resource/Kaohsiung',
#  'http://yago-knowledge.org/resource/Grammy_Award_for_Best_Solo_Rock_Vocal_Performance',
#  'http://yago-knowledge.org/resource/Emma_Stone',
#  'http://yago-knowledge.org/resource/Jim_Broadbent',
#  'http://yago-knowledge.org/resource/The_Mission_(1986_film)',
#  'http://yago-knowledge.org/resource/Harry_Gregson-Williams',
#  'http://yago-knowledge.org/resource/Dynamo_Dresden',
#  'http://yago-knowledge.org/resource/Chris_Rock',
#  'http://yago-knowledge.org/resource/Amjad_Khan_(actor)',
#  'http://yago-knowledge.org/resource/Burnaby',
#  'http://yago-knowledge.org/resource/Annie_Lennox',
#  'http://yago-knowledge.org/resource/Minsk',
#  'http://yago-knowledge.org/resource/MTV_Movie_Award_for_Best_Villain',
#  'http://yago-knowledge.org/resource/Antarctica',
#  'http://yago-knowledge.org/resource/The_Kids_Are_All_Right_(film)',
#  'http://yago-knowledge.org/resource/Malcolm_Arnold',
#  'http://yago-knowledge.org/resource/Tennessee',
#  'http://yago-knowledge.org/resource/Dnipro',
#  'http://yago-knowledge.org/resource/Bath_Iron_Works',
#  'http://yago-knowledge.org/resource/Chevrolet',
#  'http://yago-knowledge.org/resource/William_Wyler',
#  'http://yago-knowledge.org/resource/Westminster_School',
#  'http://yago-knowledge.org/resource/Dredd',
#  'http://yago-knowledge.org/resource/Anna_Faris',
#  'http://yago-knowledge.org/resource/Elizabeth_Banks',
#  'http://yago-knowledge.org/resource/The_Pink_Panther_(2006_film)',
#  'http://yago-knowledge.org/resource/Seton_Hall_University',
#  'http://yago-knowledge.org/resource/David_Greenwalt',
#  'http://yago-knowledge.org/resource/Jay_Leno',
#  'http://yago-knowledge.org/resource/Larry_David',
#  'http://yago-knowledge.org/resource/Yakima_County,_Washington',
#  'http://yago-knowledge.org/resource/Pierre_Boulez',
#  'http://yago-knowledge.org/resource/VVV-Venlo',
#  'http://yago-knowledge.org/resource/Kazakhstan_national_football_team',
#  'http://yago-knowledge.org/resource/Jeremy_Piven',
#  'http://yago-knowledge.org/resource/Z_(1969_film)',
#  'http://yago-knowledge.org/resource/Jess_Harnell',
#  'http://yago-knowledge.org/resource/Vincente_Minnelli',
#  'http://yago-knowledge.org/resource/Falkland_Islands',
#  'http://yago-knowledge.org/resource/Ravi_Shankar',
#  'http://yago-knowledge.org/resource/The_Santa_Clause_3:_The_Escape_Clause',
#  'http://yago-knowledge.org/resource/Kate_Hudson',
#  'http://yago-knowledge.org/resource/Ann_Arbor,_Michigan',
#  'http://yago-knowledge.org/resource/Aladdin_(1992_Disney_film)',
#  'http://yago-knowledge.org/resource/Ghost_Rider:_Spirit_of_Vengeance',
#  'http://yago-knowledge.org/resource/James_Franco',
#  'http://yago-knowledge.org/resource/Mel_Brooks',
#  'http://yago-knowledge.org/resource/The_Dark_Knight_(film)',
#  'http://yago-knowledge.org/resource/Monica_Rial',
#  'http://yago-knowledge.org/resource/Sporting_CP',
#  'http://yago-knowledge.org/resource/Madagascar',
#  'http://yago-knowledge.org/resource/Georgia_national_football_team',
#  'http://yago-knowledge.org/resource/The_Walking_Dead_(TV_series)',
#  'http://yago-knowledge.org/resource/Happy_Days',
#  'http://yago-knowledge.org/resource/Crewe_Alexandra_F.C.',
#  'http://yago-knowledge.org/resource/Royal_College_of_Art',
#  'http://yago-knowledge.org/resource/Launceston,_Tasmania',
#  'http://yago-knowledge.org/resource/Mark_Ronson',
#  'http://yago-knowledge.org/resource/Todd_Haynes',
#  'http://yago-knowledge.org/resource/Aston_Villa_F.C.',
#  'http://yago-knowledge.org/resource/Mali_Finn',
#  'http://yago-knowledge.org/resource/Industrial_engineering',
#  'http://yago-knowledge.org/resource/James_Earl_Jones',
#  'http://yago-knowledge.org/resource/Matt_Damon',
#  'http://yago-knowledge.org/resource/I_Know_Who_Killed_Me',
#  "http://yago-knowledge.org/resource/Gentleman's_Agreement",
#  'http://yago-knowledge.org/resource/Into_the_Storm_(2009_film)',
#  'http://yago-knowledge.org/resource/Lowell,_Massachusetts',
#  "http://yago-knowledge.org/resource/Villanova_Wildcats_men's_basketball",
#  'http://yago-knowledge.org/resource/Warren_G._Harding',
#  'http://yago-knowledge.org/resource/Carrie_Fisher',
#  'http://yago-knowledge.org/resource/Agnes_Nixon',
#  'http://yago-knowledge.org/resource/Mobile_Suit_Gundam',
#  'http://yago-knowledge.org/resource/Billy_Bob_Thornton',
#  'http://yago-knowledge.org/resource/Indiana_State_University',
#  'http://yago-knowledge.org/resource/Hamilton_Tiger-Cats',
#  'http://yago-knowledge.org/resource/Jason_Schwartzman',
#  'http://yago-knowledge.org/resource/Volusia_County,_Florida',
#  'http://yago-knowledge.org/resource/London_Symphony_Orchestra',
#  'http://yago-knowledge.org/resource/David_Crane_(producer)',
#  'http://yago-knowledge.org/resource/Natalie_Cole',
#  'http://yago-knowledge.org/resource/AS_Nancy',
#  'http://yago-knowledge.org/resource/Grammy_Award_for_Best_Rock_Instrumental_Performance',
#  'http://yago-knowledge.org/resource/Cambridge',
#  'http://yago-knowledge.org/resource/Reggae',
#  'http://yago-knowledge.org/resource/John_Patrick_Shanley',
#  'http://yago-knowledge.org/resource/Knocked_Up',
#  'http://yago-knowledge.org/resource/Mary_Tyler_Moore',
#  'http://yago-knowledge.org/resource/1928_Summer_Olympics',
#  'http://yago-knowledge.org/resource/Wikimedia_Foundation',
#  'http://yago-knowledge.org/resource/Bruce_Dern',
#  'http://yago-knowledge.org/resource/Brian_Wilson',
#  'http://yago-knowledge.org/resource/Academy_Award_for_Best_Adapted_Screenplay',
#  'http://yago-knowledge.org/resource/W._H._Auden',
#  'http://yago-knowledge.org/resource/Kramer_vs._Kramer',
#  'http://yago-knowledge.org/resource/The_Lord_of_the_Rings:_The_Return_of_the_King',
#  'http://yago-knowledge.org/resource/Salt_Lake_City',
#  'http://yago-knowledge.org/resource/Tagalog_language',
#  'http://yago-knowledge.org/resource/Hofstra_University',
#  'http://yago-knowledge.org/resource/Oi!',
#  'http://yago-knowledge.org/resource/Lalo_Schifrin',
#  'http://yago-knowledge.org/resource/Leslie_Cheung',
#  'http://yago-knowledge.org/resource/Mira_Sorvino',
#  'http://yago-knowledge.org/resource/Oliver_Stone',
#  'http://yago-knowledge.org/resource/Jay_Chou',
#  'http://yago-knowledge.org/resource/Andy_Lau',
#  'http://yago-knowledge.org/resource/Broome_County,_New_York',
#  'http://yago-knowledge.org/resource/Missouri_Tigers_football',
#  'http://yago-knowledge.org/resource/Rick_Baker',
#  'http://yago-knowledge.org/resource/Leon_Russell',
#  'http://yago-knowledge.org/resource/Samuel_M._Comer',
#  'http://yago-knowledge.org/resource/Dave_Navarro',
#  'http://yago-knowledge.org/resource/Wall_Street_(1987_film)',
#  'http://yago-knowledge.org/resource/Systemic_lupus_erythematosus',
#  'http://yago-knowledge.org/resource/Michael_Phelps',
#  'http://yago-knowledge.org/resource/Tangerine_Dream',
#  'http://yago-knowledge.org/resource/FC_U_Craiova_1948',
#  'http://yago-knowledge.org/resource/Rosario,_Santa_Fe',
#  'http://yago-knowledge.org/resource/College_of_the_Holy_Cross',
#  'http://yago-knowledge.org/resource/University_of_Padua',
#  'http://yago-knowledge.org/resource/Fantastic_Mr._Fox_(film)',
#  'http://yago-knowledge.org/resource/Chiang_Kai-shek',
#  'http://yago-knowledge.org/resource/Lily_Tomlin',
#  'http://yago-knowledge.org/resource/Hillary_Clinton',
#  'http://yago-knowledge.org/resource/Quincy_Jones',
#  'http://yago-knowledge.org/resource/Louisiana_State_University',
#  'http://yago-knowledge.org/resource/Randy_Newman',
#  'http://yago-knowledge.org/resource/RCD_Mallorca',
#  'http://yago-knowledge.org/resource/Stockard_Channing',
#  'http://yago-knowledge.org/resource/Greystoke:_The_Legend_of_Tarzan,_Lord_of_the_Apes',
#  'http://yago-knowledge.org/resource/Jesus_Christ_Superstar_(film)',
#  'http://yago-knowledge.org/resource/PFC_Lokomotiv_Plovdiv',
#  'http://yago-knowledge.org/resource/Vanilla_Ice',
#  'http://yago-knowledge.org/resource/Murray_Rothbard',
#  'http://yago-knowledge.org/resource/Stephen_Frears',
#  "http://yago-knowledge.org/resource/That's_My_Boy_(2012_film)",
#  'http://yago-knowledge.org/resource/Rawalpindi',
#  'http://yago-knowledge.org/resource/Black_metal',
#  "http://yago-knowledge.org/resource/Wayne's_World_(film)",
#  'http://yago-knowledge.org/resource/Washington_&_Jefferson_College',
#  "http://yago-knowledge.org/resource/Ryan's_Hope",
#  'http://yago-knowledge.org/resource/Gordon_Brown',
#  'http://yago-knowledge.org/resource/Santo_Domingo',
#  'http://yago-knowledge.org/resource/Guitarist',
#  'http://yago-knowledge.org/resource/3rd_Rock_from_the_Sun',
#  'http://yago-knowledge.org/resource/Dore_Schary',
#  'http://yago-knowledge.org/resource/Space_Cowboys',
#  'http://yago-knowledge.org/resource/Matt_Dillon',
#  'http://yago-knowledge.org/resource/Rope_(film)',
#  'http://yago-knowledge.org/resource/Italy_national_football_team',
#  'http://yago-knowledge.org/resource/United_Airlines',
#  'http://yago-knowledge.org/resource/Heriot-Watt_University',
#  'http://yago-knowledge.org/resource/Shemp_Howard',
#  'http://yago-knowledge.org/resource/FC_Basel',
#  'http://yago-knowledge.org/resource/Washington_and_Lee_University',
#  'http://yago-knowledge.org/resource/University_of_New_Orleans',
#  'http://yago-knowledge.org/resource/Ames,_Iowa',
#  'http://yago-knowledge.org/resource/Sean_Penn',
#  'http://yago-knowledge.org/resource/Imogen_Heap',
#  'http://yago-knowledge.org/resource/Upper_Canada_College',
#  'http://yago-knowledge.org/resource/Fidel_Castro',
#  'http://yago-knowledge.org/resource/Jared_Leto',
#  'http://yago-knowledge.org/resource/Peter_Gallagher',
#  'http://yago-knowledge.org/resource/Singapore_national_football_team',
#  'http://yago-knowledge.org/resource/Academy_Award_for_Best_Animated_Feature',
#  'http://yago-knowledge.org/resource/Irving,_Texas',
#  'http://yago-knowledge.org/resource/The_Cars',
#  'http://yago-knowledge.org/resource/Jon_Stewart',
#  'http://yago-knowledge.org/resource/Bruce_Almighty',
#  'http://yago-knowledge.org/resource/Toni_Braxton',
#  'http://yago-knowledge.org/resource/The_Go-Between_(1971_film)',
#  'http://yago-knowledge.org/resource/Melbourne',
#  'http://yago-knowledge.org/resource/Accra',
#  'http://yago-knowledge.org/resource/Robert_Evans',
#  'http://yago-knowledge.org/resource/Catwoman_(film)',
#  'http://yago-knowledge.org/resource/The_Lord_of_the_Rings:_The_Two_Towers',
#  'http://yago-knowledge.org/resource/Gandhi_(film)',
#  'http://yago-knowledge.org/resource/Kuomintang',
#  'http://yago-knowledge.org/resource/Joan_Cusack',
#  'http://yago-knowledge.org/resource/Primetime_Emmy_Award_for_Outstanding_Supporting_Actress_in_a_Limited_Series_or_Movie',
#  'http://yago-knowledge.org/resource/Merced_County,_California',
#  'http://yago-knowledge.org/resource/Death_Row_Records',
#  'http://yago-knowledge.org/resource/Cornell_University',
#  'http://yago-knowledge.org/resource/Mad_Men',
#  'http://yago-knowledge.org/resource/Jerry_Garcia',
#  'http://yago-knowledge.org/resource/Canon_Inc.',
#  'http://yago-knowledge.org/resource/Electric_blues',
#  'http://yago-knowledge.org/resource/School_of_the_Art_Institute_of_Chicago',
#  'http://yago-knowledge.org/resource/Ayr_United_F.C.',
#  'http://yago-knowledge.org/resource/Orlando_Magic',
#  'http://yago-knowledge.org/resource/Cameroon_national_football_team',
#  'http://yago-knowledge.org/resource/Ariel_Sharon',
#  'http://yago-knowledge.org/resource/Taxi_(TV_series)',
#  'http://yago-knowledge.org/resource/Patton_(film)',
#  'http://yago-knowledge.org/resource/The_Station_Agent',
#  'http://yago-knowledge.org/resource/Richard_Thompson_(musician)',
#  'http://yago-knowledge.org/resource/Ray_Winstone',
#  'http://yago-knowledge.org/resource/Cambridge,_Massachusetts',
#  'http://yago-knowledge.org/resource/Julius_Caesar_(1953_film)',
#  'http://yago-knowledge.org/resource/Lena_Olin',
#  'http://yago-knowledge.org/resource/Sarnia',
#  'http://yago-knowledge.org/resource/Rodney_Jerkins',
#  'http://yago-knowledge.org/resource/Sean_Astin',
#  'http://yago-knowledge.org/resource/University_of_Tasmania',
#  'http://yago-knowledge.org/resource/Atticus_Ross',
#  'http://yago-knowledge.org/resource/Hamilton_College',
#  'http://yago-knowledge.org/resource/Honduras',
#  'http://yago-knowledge.org/resource/Rekha',
#  'http://yago-knowledge.org/resource/Chicago_(2002_film)',
#  'http://yago-knowledge.org/resource/Rod_Stewart',
#  'http://yago-knowledge.org/resource/Anthony_Minghella',
#  'http://yago-knowledge.org/resource/Marcia_Wallace',
#  'http://yago-knowledge.org/resource/San_Francisco_Giants',
#  'http://yago-knowledge.org/resource/BAFTA_Award_for_Best_Makeup_and_Hair',
#  'http://yago-knowledge.org/resource/University_of_California,_Irvine',
#  'http://yago-knowledge.org/resource/Steve_Hackett',
#  'http://yago-knowledge.org/resource/50_Cent',
#  'http://yago-knowledge.org/resource/Lake_Erie',
#  'http://yago-knowledge.org/resource/The_Isley_Brothers',
#  'http://yago-knowledge.org/resource/Nassar_(actor)',
#  'http://yago-knowledge.org/resource/Electro_(music)',
#  'http://yago-knowledge.org/resource/47th_Annual_Grammy_Awards',
#  'http://yago-knowledge.org/resource/Barry_Levinson',
#  'http://yago-knowledge.org/resource/Thrashcore',
#  'http://yago-knowledge.org/resource/Great_Expectations_(2012_film)',
#  'http://yago-knowledge.org/resource/Rector_(academia)',
#  "http://yago-knowledge.org/resource/St_Catharine's_College,_Cambridge",
#  'http://yago-knowledge.org/resource/Ricky_Nelson',
#  'http://yago-knowledge.org/resource/West_Yorkshire',
#  'http://yago-knowledge.org/resource/County_Waterford',
#  'http://yago-knowledge.org/resource/Glen_Ballard',
#  'http://yago-knowledge.org/resource/Raphael',
#  'http://yago-knowledge.org/resource/Rose_Byrne',
#  'http://yago-knowledge.org/resource/Cleveland_Cavaliers',
#  'http://yago-knowledge.org/resource/Chris_Penn',
#  'http://yago-knowledge.org/resource/Christopher_Sabat',
#  'http://yago-knowledge.org/resource/Richard_Sylbert',
#  'http://yago-knowledge.org/resource/Taj_Mahal_(musician)',
#  'http://yago-knowledge.org/resource/Industrial_rock',
#  'http://yago-knowledge.org/resource/Sayaji_Shinde',
#  'http://yago-knowledge.org/resource/Joseph_Conrad',
#  'http://yago-knowledge.org/resource/Francis_Bacon',
#  'http://yago-knowledge.org/resource/The_Rescuers',
#  'http://yago-knowledge.org/resource/Joan_Collins',
#  'http://yago-knowledge.org/resource/Yakima,_Washington',
#  'http://yago-knowledge.org/resource/Pyrenees',
#  'http://yago-knowledge.org/resource/Second_Boer_War',
#  'http://yago-knowledge.org/resource/Three_Kings_(1999_film)',
#  'http://yago-knowledge.org/resource/Oh!_What_a_Lovely_War',
#  'http://yago-knowledge.org/resource/13_Assassins_(2010_film)',
#  'http://yago-knowledge.org/resource/Lady_in_the_Water',
#  'http://yago-knowledge.org/resource/Arthur_Wong',
#  'http://yago-knowledge.org/resource/Billy_Joel',
#  'http://yago-knowledge.org/resource/Boman_Irani',
#  'http://yago-knowledge.org/resource/West_Germany',
#  'http://yago-knowledge.org/resource/St_Andrews',
#  'http://yago-knowledge.org/resource/Achala_Sachdev',
#  'http://yago-knowledge.org/resource/University_of_Oklahoma',
#  'http://yago-knowledge.org/resource/Illeana_Douglas',
#  'http://yago-knowledge.org/resource/Venus_Williams',
#  'http://yago-knowledge.org/resource/Brookline,_Massachusetts',
#  'http://yago-knowledge.org/resource/Sheffield_Wednesday_F.C.',
#  'http://yago-knowledge.org/resource/Ernest_Haller',
#  'http://yago-knowledge.org/resource/Evanston,_Illinois',
#  'http://yago-knowledge.org/resource/Black_Robe_(film)',
#  'http://yago-knowledge.org/resource/Dayton,_Ohio',
#  'http://yago-knowledge.org/resource/Frankie_Faison',
#  'http://yago-knowledge.org/resource/Lewiston,_Maine',
#  'http://yago-knowledge.org/resource/Kanye_West',
#  'http://yago-knowledge.org/resource/Adam_Arkin',
#  'http://yago-knowledge.org/resource/Chattanooga,_Tennessee',
#  'http://yago-knowledge.org/resource/Girish_Karnad',
#  'http://yago-knowledge.org/resource/Craig_Bellamy',
#  'http://yago-knowledge.org/resource/Danubio_F.C.',
#  'http://yago-knowledge.org/resource/Zhejiang',
#  'http://yago-knowledge.org/resource/University_of_South_Carolina',
#  'http://yago-knowledge.org/resource/Club_Brugge_KV',
#  'http://yago-knowledge.org/resource/10th_Screen_Actors_Guild_Awards',
#  'http://yago-knowledge.org/resource/Uttar_Pradesh',
#  'http://yago-knowledge.org/resource/University_of_Texas_School_of_Law',
#  'http://yago-knowledge.org/resource/Neuilly-sur-Seine',
#  'http://yago-knowledge.org/resource/Shueisha',
#  'http://yago-knowledge.org/resource/Joan_Bennett',
#  'http://yago-knowledge.org/resource/Andrew_Lloyd_Webber',
#  'http://yago-knowledge.org/resource/Sons_of_Anarchy',
#  'http://yago-knowledge.org/resource/Robert_Forster',
#  'http://yago-knowledge.org/resource/Waukesha,_Wisconsin',
#  'http://yago-knowledge.org/resource/Frank_Marshall_(producer)',
#  'http://yago-knowledge.org/resource/Delft',
#  'http://yago-knowledge.org/resource/107th_United_States_Congress',
#  'http://yago-knowledge.org/resource/Harold_Perrineau',
#  'http://yago-knowledge.org/resource/Danzig_(band)',
#  'http://yago-knowledge.org/resource/Iron_Man_3',
#  'http://yago-knowledge.org/resource/Peter_Weller',
#  'http://yago-knowledge.org/resource/Live_and_Let_Die_(film)',
#  'http://yago-knowledge.org/resource/Shattered_Glass_(film)',
#  'http://yago-knowledge.org/resource/The_Alamo_(1960_film)',
#  'http://yago-knowledge.org/resource/United_Malays_National_Organisation',
#  'http://yago-knowledge.org/resource/Ankara',
#  'http://yago-knowledge.org/resource/Western_Front_(World_War_II)',
#  'http://yago-knowledge.org/resource/Modern_rock',
#  'http://yago-knowledge.org/resource/Actor',
#  'http://yago-knowledge.org/resource/Tijuana',
#  'http://yago-knowledge.org/resource/Urdu',
#  'http://yago-knowledge.org/resource/Pearl_Jam',
#  'http://yago-knowledge.org/resource/Topeka,_Kansas',
#  'http://yago-knowledge.org/resource/Jessica_Chastain',
#  'http://yago-knowledge.org/resource/Vangelis',
#  'http://yago-knowledge.org/resource/Yvelines',
#  'http://yago-knowledge.org/resource/Cinema_Paradiso',
#  'http://yago-knowledge.org/resource/Old-time_music',
#  'http://yago-knowledge.org/resource/Gil_Kane',
#  'http://yago-knowledge.org/resource/Finance_minister',
#  'http://yago-knowledge.org/resource/Marlon_Wayans',
#  'http://yago-knowledge.org/resource/Inland_Empire_(film)',
#  'http://yago-knowledge.org/resource/King_Records_(Japan)',
#  'http://yago-knowledge.org/resource/Claremont_Graduate_University',
#  'http://yago-knowledge.org/resource/Danny_Glover',
#  'http://yago-knowledge.org/resource/House_of_Wax_(2005_film)',
#  'http://yago-knowledge.org/resource/Adrian_Grenier',
#  'http://yago-knowledge.org/resource/Bandai_Namco_Entertainment',
#  'http://yago-knowledge.org/resource/They_Might_Be_Giants',
#  'http://yago-knowledge.org/resource/Bandai',
#  'http://yago-knowledge.org/resource/Sicilian_Mafia',
#  'http://yago-knowledge.org/resource/Ben_Sahar',
#  'http://yago-knowledge.org/resource/A_History_of_Violence',
#  'http://yago-knowledge.org/resource/Apple_Inc.',
#  'http://yago-knowledge.org/resource/Waltham,_Massachusetts',
#  'http://yago-knowledge.org/resource/Drugstore_Cowboy',
#  'http://yago-knowledge.org/resource/Los_Angeles_Angels',
#  'http://yago-knowledge.org/resource/Coach_Carter',
#  'http://yago-knowledge.org/resource/Friday_Night_Lights_(film)',
#  'http://yago-knowledge.org/resource/Ray_McKinnon_(actor)',
#  'http://yago-knowledge.org/resource/Agnes_Moorehead',
#  'http://yago-knowledge.org/resource/Eliza_Dushku',
#  'http://yago-knowledge.org/resource/Michael_Bay',
#  'http://yago-knowledge.org/resource/The_Police',
#  'http://yago-knowledge.org/resource/B_movie',
#  'http://yago-knowledge.org/resource/Incheon_United_FC',
#  'http://yago-knowledge.org/resource/Prison_Break',
#  'http://yago-knowledge.org/resource/Gironde',
#  'http://yago-knowledge.org/resource/Chief_technology_officer',
#  'http://yago-knowledge.org/resource/Grammy_Award_for_Best_Instrumental_Soloist_Performance_(without_orchestra)',
#  'http://yago-knowledge.org/resource/Saw_3D',
#  'http://yago-knowledge.org/resource/Motherland_(2010_film)',
#  'http://yago-knowledge.org/resource/The_Rolling_Stones',
#  'http://yago-knowledge.org/resource/Xander_Berkeley',
#  'http://yago-knowledge.org/resource/Perth_Amboy,_New_Jersey',
#  'http://yago-knowledge.org/resource/Jim_Sheridan',
#  'http://yago-knowledge.org/resource/Ian_McShane',
#  'http://yago-knowledge.org/resource/American_International_Pictures',
#  'http://yago-knowledge.org/resource/The_Right_Stuff_(film)',
#  'http://yago-knowledge.org/resource/John_Schlesinger',
#  'http://yago-knowledge.org/resource/Benjamin_Bratt',
#  'http://yago-knowledge.org/resource/Brigitte_Nielsen',
#  'http://yago-knowledge.org/resource/Richard_Griffiths',
#  'http://yago-knowledge.org/resource/Lorimar_Television',
#  'http://yago-knowledge.org/resource/Filmmaking',
#  'http://yago-knowledge.org/resource/Kyushu',
#  'http://yago-knowledge.org/resource/Urinary_tract_infection',
#  'http://yago-knowledge.org/resource/Cars_(film)',
#  'http://yago-knowledge.org/resource/Austria-Hungary',
#  'http://yago-knowledge.org/resource/New_York_metropolitan_area',
#  'http://yago-knowledge.org/resource/Lecturer',
#  'http://yago-knowledge.org/resource/New_Orleans_Pelicans',
#  'http://yago-knowledge.org/resource/Appalachian_Mountains',
#  'http://yago-knowledge.org/resource/Gaumont_Film_Company',
#  'http://yago-knowledge.org/resource/The_Adventures_of_Tintin_(film)',
#  'http://yago-knowledge.org/resource/India',
#  'http://yago-knowledge.org/resource/Rick_Nowels',
#  'http://yago-knowledge.org/resource/Washington_County,_Maryland',
#  'http://yago-knowledge.org/resource/D._H._Lawrence',
#  "http://yago-knowledge.org/resource/I'm_Not_There",
#  'http://yago-knowledge.org/resource/Jorma_Taccone',
#  'http://yago-knowledge.org/resource/Didier_Six',
#  'http://yago-knowledge.org/resource/Guinea_national_football_team',
#  'http://yago-knowledge.org/resource/Thomas_Jane',
#  'http://yago-knowledge.org/resource/Halloween_(2007_film)',
#  'http://yago-knowledge.org/resource/Jean-Jacques_Goldman',
#  'http://yago-knowledge.org/resource/D._W._Griffith',
#  'http://yago-knowledge.org/resource/Martin_Luther_University_of_Halle-Wittenberg',
#  'http://yago-knowledge.org/resource/8_Women',
#  'http://yago-knowledge.org/resource/Pillow_Talk_(film)',
#  'http://yago-knowledge.org/resource/Ron_Paul',
#  'http://yago-knowledge.org/resource/Thomas_Mitchell_(actor)',
#  "http://yago-knowledge.org/resource/The_King's_Speech",
#  'http://yago-knowledge.org/resource/The_Flintstones_in_Viva_Rock_Vegas',
#  'http://yago-knowledge.org/resource/Allegany_County,_New_York',
#  'http://yago-knowledge.org/resource/Mobile_County,_Alabama',
#  'http://yago-knowledge.org/resource/Racing_Club_de_Avellaneda',
#  'http://yago-knowledge.org/resource/National_Board_of_Review_Award_for_Best_Cast',
#  'http://yago-knowledge.org/resource/Paul_Giamatti',
#  'http://yago-knowledge.org/resource/Ocala,_Florida',
#  "http://yago-knowledge.org/resource/Newell's_Old_Boys",
#  'http://yago-knowledge.org/resource/Frances_Marion',
#  'http://yago-knowledge.org/resource/Ted_Danson',
#  'http://yago-knowledge.org/resource/Solaris_(operating_system)',
#  'http://yago-knowledge.org/resource/Arunachal_Pradesh',
#  'http://yago-knowledge.org/resource/Colorado_Rockies',
#  'http://yago-knowledge.org/resource/Bill_Clinton',
#  'http://yago-knowledge.org/resource/Binghamton,_New_York',
#  'http://yago-knowledge.org/resource/The_Decemberists',
#  'http://yago-knowledge.org/resource/Erotica',
#  'http://yago-knowledge.org/resource/500_Days_of_Summer',
#  "http://yago-knowledge.org/resource/Nine_Years'_War",
#  'http://yago-knowledge.org/resource/Why_We_Fight_(2005_film)',
#  'http://yago-knowledge.org/resource/University_of_Nairobi',
#  'http://yago-knowledge.org/resource/Tracy_Chapman',
#  'http://yago-knowledge.org/resource/The_Pride_of_the_Yankees',
#  'http://yago-knowledge.org/resource/Shooting_guard',
#  'http://yago-knowledge.org/resource/Rabat',
#  'http://yago-knowledge.org/resource/The_Lorax_(film)',
#  'http://yago-knowledge.org/resource/Ken_Adam',
#  'http://yago-knowledge.org/resource/Academy_Award_for_Best_Original_Song',
#  'http://yago-knowledge.org/resource/Van_Nest_Polglase',
#  'http://yago-knowledge.org/resource/Bengali_language',
#  'http://yago-knowledge.org/resource/Rotherham',
#  'http://yago-knowledge.org/resource/Walmart',
#  'http://yago-knowledge.org/resource/SK_Brann',
#  'http://yago-knowledge.org/resource/Luis_Miguel',
#  'http://yago-knowledge.org/resource/Namibia',
#  'http://yago-knowledge.org/resource/Newark,_New_Jersey',
#  'http://yago-knowledge.org/resource/Katie_Couric',
#  'http://yago-knowledge.org/resource/Interscope_Records',
#  'http://yago-knowledge.org/resource/National_Assembly_(France)',
#  'http://yago-knowledge.org/resource/Oklahoma_City_Thunder',
#  'http://yago-knowledge.org/resource/Pancreatic_cancer',
#  'http://yago-knowledge.org/resource/Nickelback',
#  'http://yago-knowledge.org/resource/Karl_Urban',
#  'http://yago-knowledge.org/resource/Babylon_5:_The_Gathering',
#  'http://yago-knowledge.org/resource/Adirondack_Mountains',
#  'http://yago-knowledge.org/resource/Microsoft',
#  'http://yago-knowledge.org/resource/Fahrenheit_9%2F11',
#  'http://yago-knowledge.org/resource/Thriller_(genre)',
#  'http://yago-knowledge.org/resource/Taylor_Swift',
#  'http://yago-knowledge.org/resource/Roman_Polanski',
#  'http://yago-knowledge.org/resource/Foreigner_(band)',
#  'http://yago-knowledge.org/resource/Grammy_Award_for_Best_Dance_Recording',
#  'http://yago-knowledge.org/resource/Sardinia',
#  'http://yago-knowledge.org/resource/Resident_Evil_(film)',
#  'http://yago-knowledge.org/resource/Viacom_(2005â€“2019)',
#  'http://yago-knowledge.org/resource/Brody_Jenner',
#  'http://yago-knowledge.org/resource/Lviv',
#  'http://yago-knowledge.org/resource/Brunswick,_Georgia',
#  'http://yago-knowledge.org/resource/Purdue_University',
#  'http://yago-knowledge.org/resource/Province_of_Naples',
#  'http://yago-knowledge.org/resource/Cory_Monteith',
#  'http://yago-knowledge.org/resource/Nitty_Gritty_Dirt_Band',
#  'http://yago-knowledge.org/resource/The_Stand_(1994_miniseries)',
#  'http://yago-knowledge.org/resource/James_Horner',
#  'http://yago-knowledge.org/resource/Cattaraugus_County,_New_York',
#  'http://yago-knowledge.org/resource/Alsace',
#  'http://yago-knowledge.org/resource/The_Rocketeer_(film)',
#  'http://yago-knowledge.org/resource/The_Last_Picture_Show',
#  'http://yago-knowledge.org/resource/Quarterback',
#  'http://yago-knowledge.org/resource/Nick_Cannon',
#  'http://yago-knowledge.org/resource/Indo-Pakistani_War_of_1971',
#  'http://yago-knowledge.org/resource/113th_United_States_Congress',
#  'http://yago-knowledge.org/resource/Bugs_Bunny',
#  'http://yago-knowledge.org/resource/Procter_&_Gamble',
#  'http://yago-knowledge.org/resource/IFC_Films',
#  'http://yago-knowledge.org/resource/Made_in_Dagenham',
#  'http://yago-knowledge.org/resource/Hope_and_Glory_(film)',
#  'http://yago-knowledge.org/resource/Van_Helsing_(film)',
#  'http://yago-knowledge.org/resource/Noise_pop',
#  'http://yago-knowledge.org/resource/The_Bourne_Supremacy_(film)',
#  'http://yago-knowledge.org/resource/Indiana_University_of_Pennsylvania',
#  'http://yago-knowledge.org/resource/Ben_Stiller',
#  'http://yago-knowledge.org/resource/Lucasfilm',
#  'http://yago-knowledge.org/resource/The_Hobbit:_An_Unexpected_Journey',
#  'http://yago-knowledge.org/resource/2010_Toronto_International_Film_Festival',
#  'http://yago-knowledge.org/resource/Chris_Cooper',
#  'http://yago-knowledge.org/resource/Madurai',
#  'http://yago-knowledge.org/resource/Texas_Southern_University',
#  'http://yago-knowledge.org/resource/Appleseed_Ex_Machina',
#  'http://yago-knowledge.org/resource/New-age_music',
#  'http://yago-knowledge.org/resource/Working_Title_Films',
#  'http://yago-knowledge.org/resource/Seventh-day_Adventist_Church',
#  'http://yago-knowledge.org/resource/Kenosha,_Wisconsin',
#  'http://yago-knowledge.org/resource/Sherman_Oaks,_Los_Angeles',
#  'http://yago-knowledge.org/resource/Phil_LaMarr',
#  'http://yago-knowledge.org/resource/Fairfax,_Virginia',
#  'http://yago-knowledge.org/resource/Emir_Kusturica',
#  'http://yago-knowledge.org/resource/Monty_Python',
#  'http://yago-knowledge.org/resource/Ekta_Kapoor',
#  'http://yago-knowledge.org/resource/Humboldt_County,_California',
#  'http://yago-knowledge.org/resource/Columbia_Law_School',
#  'http://yago-knowledge.org/resource/Latin_hip_hop',
#  'http://yago-knowledge.org/resource/California_College_of_the_Arts',
#  'http://yago-knowledge.org/resource/Beat_music',
#  'http://yago-knowledge.org/resource/Ghostbusters',
#  'http://yago-knowledge.org/resource/Genesis_(band)',
#  'http://yago-knowledge.org/resource/John_Updike',
#  'http://yago-knowledge.org/resource/Al_Jourgensen',
#  'http://yago-knowledge.org/resource/Hannover_96',
#  'http://yago-knowledge.org/resource/Goddard_College',
#  'http://yago-knowledge.org/resource/Love_of_Life',
#  'http://yago-knowledge.org/resource/Young_Frankenstein',
#  'http://yago-knowledge.org/resource/Ted_Haworth',
#  'http://yago-knowledge.org/resource/Sparta_Rotterdam',
#  'http://yago-knowledge.org/resource/County_Monaghan',
#  'http://yago-knowledge.org/resource/Swamp_pop',
#  'http://yago-knowledge.org/resource/East_Coast_hip_hop',
#  'http://yago-knowledge.org/resource/Gil_Vicente_F.C.',
#  'http://yago-knowledge.org/resource/Heather_Mitts',
#  'http://yago-knowledge.org/resource/Harvey_Weinstein',
#  'http://yago-knowledge.org/resource/New_York,_I_Love_You',
#  'http://yago-knowledge.org/resource/Shortstop',
#  'http://yago-knowledge.org/resource/Tulane_University',
#  'http://yago-knowledge.org/resource/Emily_Blunt',
#  'http://yago-knowledge.org/resource/Rocky_Balboa_(film)',
#  'http://yago-knowledge.org/resource/3000_Miles_to_Graceland',
#  'http://yago-knowledge.org/resource/Russia',
#  'http://yago-knowledge.org/resource/Kellie_Martin',
#  'http://yago-knowledge.org/resource/Arnon_Milchan',
#  'http://yago-knowledge.org/resource/Annie_Hall',
#  'http://yago-knowledge.org/resource/Russell_Metty',
#  'http://yago-knowledge.org/resource/Jackass_Number_Two',
#  'http://yago-knowledge.org/resource/Josh_Homme',
#  'http://yago-knowledge.org/resource/Treasurer',
#  'http://yago-knowledge.org/resource/Golden_Screen_Award_(Canada)',
#  'http://yago-knowledge.org/resource/Bradford_City_A.F.C.',
#  'http://yago-knowledge.org/resource/Ted_(film)',
#  'http://yago-knowledge.org/resource/Joey_Fatone',
#  'http://yago-knowledge.org/resource/Keith_David',
#  'http://yago-knowledge.org/resource/Syfy',
#  'http://yago-knowledge.org/resource/Russell_Crowe',
#  'http://yago-knowledge.org/resource/Amadeus_(film)',
#  'http://yago-knowledge.org/resource/Nirvana_(band)',
#  'http://yago-knowledge.org/resource/Bertrand_Russell',
#  'http://yago-knowledge.org/resource/George_C._Scott',
#  'http://yago-knowledge.org/resource/Wisconsin',
#  'http://yago-knowledge.org/resource/Mongolia',
#  'http://yago-knowledge.org/resource/Riot_grrrl',
#  'http://yago-knowledge.org/resource/PIAS_Recordings',
#  'http://yago-knowledge.org/resource/Vassar_College',
#  'http://yago-knowledge.org/resource/Rhodes_piano',
#  'http://yago-knowledge.org/resource/Jack_Elam',
#  'http://yago-knowledge.org/resource/Hampshire_College',
#  'http://yago-knowledge.org/resource/Northwestern_University',
#  'http://yago-knowledge.org/resource/Star_Trek:_The_Next_Generation',
#  'http://yago-knowledge.org/resource/John_Cusack',
#  'http://yago-knowledge.org/resource/Power_pop',
#  'http://yago-knowledge.org/resource/Kellogg_School_of_Management',
#  'http://yago-knowledge.org/resource/Brazil',
#  'http://yago-knowledge.org/resource/David_Buttolph',
#  'http://yago-knowledge.org/resource/Bob_Marley',
#  'http://yago-knowledge.org/resource/Falls_Church,_Virginia',
#  'http://yago-knowledge.org/resource/Wanda_Sykes',
#  'http://yago-knowledge.org/resource/Water_for_Elephants_(film)',
#  'http://yago-knowledge.org/resource/Robert_Klein',
#  'http://yago-knowledge.org/resource/Ray_Allen',
#  'http://yago-knowledge.org/resource/East_Carolina_University',
#  'http://yago-knowledge.org/resource/The_Missing_(2003_film)',
#  'http://yago-knowledge.org/resource/Fergie_(singer)',
#  'http://yago-knowledge.org/resource/Shannen_Doherty',
#  'http://yago-knowledge.org/resource/Announcer',
#  'http://yago-knowledge.org/resource/The_Godfather',
#  'http://yago-knowledge.org/resource/Hyderabad',
#  'http://yago-knowledge.org/resource/Little_Nicky',
#  "http://yago-knowledge.org/resource/Shaquille_O'Neal",
#  'http://yago-knowledge.org/resource/14th_Screen_Actors_Guild_Awards',
#  'http://yago-knowledge.org/resource/Raj_Kapoor',
#  'http://yago-knowledge.org/resource/German_Americans',
#  'http://yago-knowledge.org/resource/Harry_S._Truman',
#  'http://yago-knowledge.org/resource/Teen_drama',
#  'http://yago-knowledge.org/resource/DreamWorks_Animation',
#  'http://yago-knowledge.org/resource/Greg_Kinnear',
#  'http://yago-knowledge.org/resource/Warren_Ellis',
#  'http://yago-knowledge.org/resource/Nantucket',
#  'http://yago-knowledge.org/resource/Psychiatry']

# %%
import random
import pandas as pd
random.seed(10)
wincount = 0
subjects_lost = []
gamesplayed = 0
lostbybreak = 0
breakskip = 0
subjects = random.sample(pickSubject(), 1000)
print(subjects)
totalgames = len(subjects)
results = []
questionhistory = []
# Out:
# ['http://yago-knowledge.org/resource/Helena_Bonham_Carter', 'http://yago-knowledge.org/resource/Eileen_Atkins', 'http://yago-knowledge.org/resource/Ellie_Kemper', 'http://yago-knowledge.org/resource/Youth_in_Revolt_(film)', 'http://yago-knowledge.org/resource/Airport_(1970_film)', 'http://yago-knowledge.org/resource/Mozambique', 'http://yago-knowledge.org/resource/Macalester_College', 'http://yago-knowledge.org/resource/KLM', 'http://yago-knowledge.org/resource/Pensacola,_Florida', 'http://yago-knowledge.org/resource/Telemundo', 'http://yago-knowledge.org/resource/Quills', 'http://yago-knowledge.org/resource/Bursaspor', 'http://yago-knowledge.org/resource/Film_noir', 'http://yago-knowledge.org/resource/Natchez,_Mississippi', 'http://yago-knowledge.org/resource/1960_Winter_Olympics', 'http://yago-knowledge.org/resource/Spencer_Tracy', 'http://yago-knowledge.org/resource/N._T._Rama_Rao', 'http://yago-knowledge.org/resource/Porto', 'http://yago-knowledge.org/resource/Peter_Capaldi', 'http://yago-knowledge.org/resource/Ryanair', 'http://yago-knowledge.org/resource/Jerry_Lewis', 'http://yago-knowledge.org/resource/Richard_Edlund', "http://yago-knowledge.org/resource/St_Catherine's_College,_Oxford", 'http://yago-knowledge.org/resource/Method_Man', 'http://yago-knowledge.org/resource/California_State_University,_Los_Angeles', 'http://yago-knowledge.org/resource/Salem,_Massachusetts', 'http://yago-knowledge.org/resource/Sarah_McLachlan', 'http://yago-knowledge.org/resource/Los_Angeles_Chargers', 'http://yago-knowledge.org/resource/Tak_Fujimoto', 'http://yago-knowledge.org/resource/CD_Tenerife', 'http://yago-knowledge.org/resource/Windsor_Castle', 'http://yago-knowledge.org/resource/Chris_Noth', 'http://yago-knowledge.org/resource/Multi-instrumentalist', 'http://yago-knowledge.org/resource/Golden_Raspberry_Award_for_Worst_Screenplay', 'http://yago-knowledge.org/resource/2K_(company)', 'http://yago-knowledge.org/resource/Inter_Milan', 'http://yago-knowledge.org/resource/Battle_of_France', 'http://yago-knowledge.org/resource/Jean_Louis', 'http://yago-knowledge.org/resource/Storyboard_artist', 'http://yago-knowledge.org/resource/Cleopatra_(1963_film)', 'http://yago-knowledge.org/resource/Toho', 'http://yago-knowledge.org/resource/Dante_Spinotti', 'http://yago-knowledge.org/resource/Chatham_County,_Georgia', 'http://yago-knowledge.org/resource/F.C._Ashdod', 'http://yago-knowledge.org/resource/Million_Dollar_Baby', 'http://yago-knowledge.org/resource/Marc_Anthony', 'http://yago-knowledge.org/resource/Taking_Woodstock', 'http://yago-knowledge.org/resource/Newton,_Massachusetts', 'http://yago-knowledge.org/resource/Berlin', 'http://yago-knowledge.org/resource/Shelby_County,_Tennessee', 'http://yago-knowledge.org/resource/The_World_Is_Not_Enough', 'http://yago-knowledge.org/resource/Catholic_Church', 'http://yago-knowledge.org/resource/Frank_Herbert', 'http://yago-knowledge.org/resource/Valkyrie_(film)', 'http://yago-knowledge.org/resource/Will_County,_Illinois', 'http://yago-knowledge.org/resource/New_Delhi', 'http://yago-knowledge.org/resource/Macau', 'http://yago-knowledge.org/resource/The_Barbarian_Invasions', 'http://yago-knowledge.org/resource/Oberlin_College', 'http://yago-knowledge.org/resource/U.S._Sassuolo_Calcio', 'http://yago-knowledge.org/resource/Entourage_(American_TV_series)', 'http://yago-knowledge.org/resource/Hollywood', 'http://yago-knowledge.org/resource/Craig_Robinson_(actor)', 'http://yago-knowledge.org/resource/Kidult', 'http://yago-knowledge.org/resource/Jack_L._Warner', 'http://yago-knowledge.org/resource/David_Simon', 'http://yago-knowledge.org/resource/Xbox_Game_Studios', 'http://yago-knowledge.org/resource/Norman_Taurog', 'http://yago-knowledge.org/resource/Columbia_College_(New_York)', 'http://yago-knowledge.org/resource/Lesley_Sharp', 'http://yago-knowledge.org/resource/Roy_Orbison', "http://yago-knowledge.org/resource/Kids'_WB", 'http://yago-knowledge.org/resource/Royal_Antwerp_F.C.', 'http://yago-knowledge.org/ ...

# %%
while gamesplayed < totalgames:
    # Resets all variables
    try:
        left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
        i=0
        outofguess = []
        #print(gamesplayed)
        # pick subject
        subject = "<" + subjects[gamesplayed] + ">"
        #print(subject)

        while i < 20:

            # list of Pred and Obj for questions
            listOfObj ,listOfPred = extractCountAndAttr(qres)

            # if only 1 popular entity is left break
            if left<=1:
                break

            # ask question and add filters to query
            #print('Question: %s' %(i+1))
            PosFilters, NegFilters = generateQuestion(listOfPred, listOfObj, 0, subject)

            # number of popular entities left
            left = numberleft(PosFilters, NegFilters)
            #print('left -',left)

            # run query
            sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q')
            query = updateQuery(left/2,PosFilters, NegFilters)
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)
            qres = sparql.queryAndConvert()

            i+=1

        # Prints answer
        if i != 20:
            for attr in popentities(PosFilters, NegFilters):
                for x in [attr['s']['value']][0:10]:
                    answer = (x.split("/")[-1])
            #print("Your Answer is: " + answer)
            if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
                wincount += 1
                gamesplayed += 1
                results.append(i)
                #results.append({'Subject': subject.split("/")[-1].split('>')[0], 'Questions-C': i})
                print(gamesplayed,{'Subject': subject.split("/")[-1].split('>')[0], 'Guessed': 'Yes', 'Questions-B': i})
                print('%s/%s' %(wincount,gamesplayed))
                print()
            else:
                gamesplayed += 1
                subjects_lost.append(subject)
                results.append(i)
                #results.append({'Subject': subject.split("/")[-1].split('>')[0], 'Questions-C': i})
                print(gamesplayed,{'Subject': subject.split("/")[-1].split('>')[0], 'Guessed': 'No', 'Questions-B': i})
                print('%s/%s' %(wincount,gamesplayed))
                print()

        # ran out of questions
        else:
            #print('Final Question:')
            for j in popentities(PosFilters, NegFilters):
                    outofguess.append(f'{j["s"]["value"].split("/")[-1]}')
            guess = random.choice(outofguess)
            #print("Is it " + guess + "?")
            if str(subject.split("/")[-1]) == str(guess + ">"):
                wincount += 1
                gamesplayed += 1
                #results.append({'Subject': subject.split("/")[-1].split('>')[0], 'Questions-C': 20})
                results.append(20)
                print(gamesplayed,{'Subject': subject.split("/")[-1].split('>')[0], 'Guessed': 'Yes', 'Questions-B': 20})
                print('%s/%s' %(wincount,gamesplayed))
                print()
            else:
                gamesplayed += 1
                subjects_lost.append(subject)
                #results.append({'Subject': subject.split("/")[-1].split('>')[0], 'Questions-C': 20})
                results.append(20)
                print(gamesplayed, {'Subject': subject.split("/")[-1].split('>')[0],'Guessed': 'No', 'Questions-B': 20})
                print('%s/%s' %(wincount,gamesplayed))
                print()
        breakskip = 0
        #print(AttrHistory)
        questionhistory.append(AttrHistory)
    except KeyboardInterrupt:
        breakf
    except:
        continue
            
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
# 1 {'Subject': 'Helena_Bonham_Carter', 'Questions-C': 16}
# 1/1
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Guitarist>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Laurence_Olivier_Award>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Academy_Award_for_Best_Actor>', '<http://schema.org/givenName> <http://yago-knowledge.org/resource/Charlotte_(given_name)>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Character_actor>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Tony_Award_for_Best_Actor_in_a_Play>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Television_producer>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/Westminster_School>']
# 2 {'Subject': 'Eileen_Atkins', 'Questions-C': 11}
# 2/2
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Laurence_Olivier_Award>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/Guildhall_School_of_Music_and_Drama>']
# 3 {'Subject': 'Ellie_Kemper', 'Questions-C': 20}
# 2/3
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Singer-songwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Songwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Character_actor>', '<http://schema.org/homeLocation> <http://yago-knowledge.org/resource/Los_Angeles>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/New_York_City>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/Los_Angeles>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Dancer>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/New_York_University_Tisch_School_of_the_Arts>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/Chicago>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_an_Ensemble_in_a_Drama_Series>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/American_Academy_of_Dramatic_Arts>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/Fashion_Institute_of_Design_&_Merchandising>']
# 4 {'Subject': 'Youth_in_Revolt_(film)', 'Questions-C': 18}
# 3/4
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Action_film>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/New_York_City>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWorkSeries>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://schema.org/award> <http://yago-knowledge.org/resource/National_Film_Registry>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Fantasy_film>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Biographical_film>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Romantic_comedy>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Comedy-drama>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/Los_Angeles>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Coming-of-age_story>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/California>', '<http://schema.org/productionCompany> <http://yago-knowledge.org/resource/DreamWorks_Pictures>', '<http://schema.org/productionCompany> <http://yago-knowledge.org/resource/Searchlight_Pictures>']
# 5 {'Subject': 'Airport_(1970_film)', 'Questions-C': 20}
# 3/5
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Action_film>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/New_York_City>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWorkSeries>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://schema.org/award> <http://yago-knowledge.org/resource/National_Film_Registry>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Fantasy_film>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Biographical_film>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Romantic_comedy>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Crime_film>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Romance_film>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/Los_Angeles>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Musical_film>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Horror_film>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Science_fiction_film>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Comedy-drama>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/War_film>']
# 6 {'Subject': 'Mozambique', 'Questions-C': 14}
# 4/6
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Corporation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CollegeOrUniversity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Country>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/International_Centre_for_Settlement_of_Investment_Disputes>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/African_Development_Bank>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/African,_Caribbean_and_Pacific_Group_of_States>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Organisation_of_Islamic_Cooperation>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/West_Africa>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Republic>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Commonwealth_of_Nations>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Chicamba%20Dam.jpg>']
# 7 {'Subject': 'Macalester_College', 'Questions-C': 14}
# 5/7
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Corporation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CollegeOrUniversity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/University>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Coalition_for_Networked_Information>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Association_of_Research_Libraries>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Center_for_Research_Libraries>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Private_university>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Scholarly_Publishing_and_Academic_Resources_Coalition>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/MetaArchive_Cooperative>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Digital_Library_Federation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Liberal_arts_colleges_in_the_United_States>']
# 8 {'Subject': 'KLM', 'Questions-C': 16}
# 6/8
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/NGO>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/MusicGroup>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Record_label>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Business>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SportsTeam>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Video_game_developer>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/EducationalOrganization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/GovernmentOrganization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Film_distributor>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Airline>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Airlines_for_Europe>', '<http://schema.org/icaoCode> <AAL>', '<http://schema.org/icaoCode> <KLM>']
# 9 {'Subject': 'Pensacola,_Florida', 'Questions-C': 20}
# 6/9
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Corporation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/County_seat>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/City>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Climate_Alliance>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Capital_city>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Comune>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Independent_city_(United_States)>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Los_Angeles_County,_California>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Border_town>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Communes_of_France>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/City_(New_Jersey)>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Consolidated_city-county>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Orange_County,_California>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Middlesex_County,_Massachusetts>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Essex_County,_Massachusetts>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Santa_Clara_County,_California>', '<http://schema.org/foundingDate> <1849>']
# 10 {'Subject': 'Telemundo', 'Questions-C': 20}
# 7/10
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Event>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Occupation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/MedicalCondition>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Product>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Award>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Ethnic_group>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Discipline_(academia)>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Literary_award>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/War>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Grammy_Award>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Academy_Awards>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Thing>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Service>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Television_network>', '<http://schema.org/url> <http://www.eonline.com/>', '<http://schema.org/url> <http://www.cwtv.com/>']
# 11 {'Subject': 'Quills', 'Questions-C': 14}
# 8/11
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Action_film>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/New_York_City>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWorkSeries>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/London>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Biographical_film>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/France>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Romance_film>', '<http://schema.org/actor> <http://yago-knowledge.org/resource/Kate_Winslet>', '<http://schema.org/productionCompany> <http://yago-knowledge.org/resource/Searchlight_Pictures>']
# 12 {'Subject': 'Bursaspor', 'Questions-C': 20}
# 8/12
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/NGO>', '<http://schema.org/sport> <http://yago-knowledge.org/resource/Association_football>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SportsTeam>', '<http://schema.org/foundingDate> <1923>', '<http://schema.org/foundingDate> <1912>', '<http://schema.org/foundingDate> <1905>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Sports_club>', '<http://schema.org/foundingDate> <1904>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Cyprus_Football_Association>', '<http://schema.org/foundingDate> <1910>', '<http://schema.org/foundingDate> <1995>', '<http://schema.org/foundingDate> <1899>', '<http://schema.org/foundingDate> <1893>', '<http://schema.org/foundingDate> <2004>', '<http://schema.org/foundingDate> <1919>', '<http://schema.org/foundingDate> <1908>', '<http://schema.org/foundingDate> <1909>']
# 13 {'Subject': 'Film_noir', 'Questions-C': 11}
# 9/13
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_States>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Music_genre>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Movie>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWorkSeries>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Film_genre>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Literary_genre>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/BigComboTrailer.jpg>']
# 14 {'Subject': 'Natchez,_Mississippi', 'Questions-C': 20}
# 9/14
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Corporation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/County_seat>', '<http://schema.org/foundingDate> <1854>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Georgia_(U.S._state)>', '<http://schema.org/foundingDate> <1849>', '<http://schema.org/foundingDate> <1730>', '<http://schema.org/foundingDate> <1856>', '<http://schema.org/foundingDate> <1786>', '<http://schema.org/elevation> <http://www.wikidata.org/value/11c101dbb93933a01360127a6ab755e5>', '<http://schema.org/foundingDate> <1865>', '<http://schema.org/foundingDate> <1889>', '<http://schema.org/foundingDate> <1824>', '<http://schema.org/foundingDate> <1787>', '<http://schema.org/foundingDate> <1884>', '<http://schema.org/foundingDate> <1821>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Midland_County,_Texas>', '<http://schema.org/foundingDate> <1842>']
# 15 {'Subject': '1960_Winter_Olympics', 'Questions-C': 12}
# 10/15
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Event>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/EventSeries>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Awards_ceremony>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Summer_Olympic_Games>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Winter_Olympic_Games>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Olympic%20rings%20with%20white%20rims.svg>', '<http://schema.org/endDate> <1948-02-08>', '<http://schema.org/endDate> <1960-02-28>']
# 16 {'Subject': 'Spencer_Tracy', 'Questions-C': 12}
# 11/16
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Theatre_World_Award>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Democratic_Party_(United_States)>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Character_actor>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Kennedy_Center_Honors>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/University_of_California,_Berkeley>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Cannes_Film_Festival_Award_for_Best_Actor>']
# 17 {'Subject': 'N._T._Rama_Rao', 'Questions-C': 10}
# 12/17
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://schema.org/award> <http://yago-knowledge.org/resource/European_Film_Academy_Lifetime_Achievement_Award>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Filmfare_Award_for_Best_Actor_–_Telugu>']
# 18 {'Subject': 'Porto', 'Questions-C': 20}
# 12/18
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Corporation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/County_seat>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/City>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Climate_Alliance>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Capital_city>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Comune>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Independent_city_(United_States)>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Los_Angeles_County,_California>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Border_town>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Communes_of_France>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/City_(New_Jersey)>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Consolidated_city-county>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Orange_County,_California>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Middlesex_County,_Massachusetts>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Essex_County,_Massachusetts>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Santa_Clara_County,_California>', '<http://schema.org/foundingDate> <1849>']
# 19 {'Subject': 'Peter_Capaldi', 'Questions-C': 12}
# 13/19
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Television_director>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Directors_Guild_of_America_Award>']
# 20 {'Subject': 'Ryanair', 'Questions-C': 16}
# 14/20
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/NGO>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/MusicGroup>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Record_label>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Business>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SportsTeam>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Video_game_developer>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/EducationalOrganization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/GovernmentOrganization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Film_distributor>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Airline>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Airlines_for_Europe>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Low-cost_carrier>', '<http://schema.org/icaoCode> <EZY>']
# 21 {'Subject': 'Jerry_Lewis', 'Questions-C': 11}
# 15/21
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Comedian>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Democratic_Party_(United_States)>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Jean_Hersholt_Humanitarian_Award>']
# 22 {'Subject': 'Richard_Edlund', 'Questions-C': 19}
# 16/22
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Guitarist>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Songwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Scenographer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Cinematographer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Academy_Award_for_Best_Cinematography>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/Los_Angeles>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/New_York_City>', '<http://schema.org/deathPlace> <http://yago-knowledge.org/resource/Hollywood>', '<http://schema.org/deathPlace> <http://yago-knowledge.org/resource/Woodland_Hills,_Los_Angeles>', '<http://schema.org/givenName> <http://yago-knowledge.org/resource/George_(given_name)>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Academy_Award_for_Best_Visual_Effects>']
# 23 {'Subject': "St_Catherine's_College,_Oxford", 'Questions-C': 16}
# 17/23
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Corporation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CollegeOrUniversity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/University>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Coalition_for_Networked_Information>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/School>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Public_university>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Colleges_of_the_University_of_Oxford>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Oxford>', '<http://schema.org/logo> <http://commons.wikimedia.org/wiki/Special:FilePath/Lincoln%20College%20Oxford%20Coat%20Of%20Arms.svg>', '<http://schema.org/logo> <http://commons.wikimedia.org/wiki/Special:FilePath/Magdalen%20College%20Oxford%20Coat%20Of%20Arms%20%28Motto%29.svg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Oxford%20-%20Jesus%20College%20Library%20-%200473.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Wadham.jpg>', '<http://schema.org/logo> <http://commons.wikimedia.org/wiki/Special:FilePath/St-Catherines%20College%20Oxford%20Coat%20Of%20Arms%20%28Motto%29.svg>']
# 24 {'Subject': 'Method_Man', 'Questions-C': 14}
# 18/24
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Inkpot_Award>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Songwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Lyricist>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Disney_Legends>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Kennedy_Center_Honors>']
# 25 {'Subject': 'California_State_University,_Los_Angeles', 'Questions-C': 15}
# 19/25
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Corporation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CollegeOrUniversity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/University>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Coalition_for_Networked_Information>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/European_University_Association>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Scholarly_Publishing_and_Academic_Resources_Coalition>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Association_of_Jesuit_Colleges_and_Universities>', '<http://schema.org/parentOrganization> <http://yago-knowledge.org/resource/California_State_University>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/California>', '<http://schema.org/foundingDate> <1949>', '<http://schema.org/foundingDate> <1947>', '<http://schema.org/logo> <http://commons.wikimedia.org/wiki/Special:FilePath/CalStateLA%20Logo.svg>']
# 26 {'Subject': 'Salem,_Massachusetts', 'Questions-C': 20}
# 20/26
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Corporation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/County_seat>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/City>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Climate_Alliance>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Capital_city>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Comune>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Independent_city_(United_States)>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Los_Angeles_County,_California>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Border_town>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Communes_of_France>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/City_(New_Jersey)>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Consolidated_city-county>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Orange_County,_California>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Middlesex_County,_Massachusetts>', '<http://schema.org/containedInPlace> <http://yago-knowledge.org/resource/Essex_County,_Massachusetts>', '<http://schema.org/foundingDate> <1626>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Beverly%20Main%20Post%20Office%2C%20Beverly%2C%20MA.jpg>']
# 27 {'Subject': 'Sarah_McLachlan', 'Questions-C': 11}
# 21/27
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/India>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/Canada>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Robert%20Lantos.jpg>']
# 28 {'Subject': 'Los_Angeles_Chargers', 'Questions-C': 12}
# 22/28
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/NGO>', '<http://schema.org/sport> <http://yago-knowledge.org/resource/Association_football>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SportsTeam>', '<http://schema.org/sport> <http://yago-knowledge.org/resource/American_football>', '<http://schema.org/foundingDate> <1960>', '<http://schema.org/url> <http://www.denverbroncos.com/>', '<http://schema.org/url> <http://www.chiefs.com/>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Cowboys%20Stadium%20field.jpg>', '<http://schema.org/url> <http://www.chargers.com/>']
# 29 {'Subject': 'Tak_Fujimoto', 'Questions-C': 14}
# 23/29
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Guitarist>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Songwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Scenographer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Cinematographer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Camera_operator>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/The%20Alaskan%20%281924%29%201.jpg>']
# 30 {'Subject': 'CD_Tenerife', 'Questions-C': 20}
# 23/30
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/NGO>', '<http://schema.org/sport> <http://yago-knowledge.org/resource/Association_football>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SportsTeam>', '<http://schema.org/foundingDate> <1923>', '<http://schema.org/foundingDate> <1912>', '<http://schema.org/foundingDate> <1905>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Sports_club>', '<http://schema.org/foundingDate> <1904>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Cyprus_Football_Association>', '<http://schema.org/foundingDate> <1910>', '<http://schema.org/foundingDate> <1995>', '<http://schema.org/foundingDate> <1899>', '<http://schema.org/foundingDate> <1893>', '<http://schema.org/foundingDate> <2004>', '<http://schema.org/foundingDate> <1919>', '<http://schema.org/foundingDate> <1908>', '<http://schema.org/foundingDate> <1909>']
# 31 {'Subject': 'Windsor_Castle', 'Questions-C': 12}
# 24/31
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/City>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/AdministrativeArea>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Landform>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CivicStructure>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Museum>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Art_museum>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/TouristAttraction>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Monument>']
# 32 {'Subject': 'Chris_Noth', 'Questions-C': 20}
# 24/32
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Comedian>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Businessperson>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Democratic_Party_(United_States)>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Republican_Party_(United_States)>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Academy_Award_for_Best_Actor>', '<http://schema.org/homeLocation> <http://yago-knowledge.org/resource/New_York_City>', '<http://schema.org/award> <http://yago-knowledge.org/resource/MTV_Movie_Award_for_Best_Fight>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/Los_Angeles>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/Ward_Melville_High_School>', '<http://schema.org/award> <http://yago-knowledge.org/resource/Academy_Award_for_Best_Picture>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/New_York_University_Tisch_School_of_the_Arts>']
# 33 {'Subject': 'Multi-instrumentalist', 'Questions-C': 20}
# 24/33
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Event>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Occupation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Profession>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/American_football_positions>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Baseball_positions>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Corporate_title>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Basketball_positions>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Association_football_positions>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Legal_profession>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Position_(team_sports)>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Role>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Paco%20de%20Luc%C3%ADa%204.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Norman%20McLaren%20drawing%20on%20film%20-%201944.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Charlie%20Baker%20official%20photo%20%28cropped%29.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Organist%20at%20Lausanne%20Cathedral.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Pope%20Francis%20in%20March%202013.jpg>']
# 34 {'Subject': 'Golden_Raspberry_Award_for_Worst_Screenplay', 'Questions-C': 20}
# 24/34
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Event>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Occupation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/MedicalCondition>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Product>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Award>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Ethnic_group>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Discipline_(academia)>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Literary_award>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/War>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Grammy_Award>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Academy_Awards>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Thing>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Service>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/MTV_Video_Music_Award>', '<http://schema.org/url> <http://www.tonyawards.com/en_US/index.html>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Primetime_Emmy_Award>']
# 35 {'Subject': '2K_(company)', 'Questions-C': 20}
# 25/35
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/NGO>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/MusicGroup>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Record_label>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Business>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SportsTeam>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Video_game_developer>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Video_game_publisher>', '<http://schema.org/parentOrganization> <http://yago-knowledge.org/resource/Electronic_Arts>', '<http://schema.org/foundingDate> <1986>', '<http://schema.org/foundingDate> <1993>', '<http://schema.org/parentOrganization> <http://yago-knowledge.org/resource/Microsoft>', '<http://schema.org/foundingLocation> <http://yago-knowledge.org/resource/Tokyo>', '<http://schema.org/url> <http://www.square-enix.com/>', '<http://schema.org/logo> <http://commons.wikimedia.org/wiki/Special:FilePath/THQ%20logo%202011.svg>', '<http://schema.org/logo> <http://commons.wikimedia.org/wiki/Special:FilePath/Sunsoft%20logo.svg>', '<http://schema.org/logo> <http://commons.wikimedia.org/wiki/Special:FilePath/Irem%20Logo.png>', '<http://schema.org/logo> <http://commons.wikimedia.org/wiki/Special:FilePath/Interplay%20Entertainment%20logo%20colored.png>']
# 36 {'Subject': 'Inter_Milan', 'Questions-C': 20}
# 25/36
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/NGO>', '<http://schema.org/sport> <http://yago-knowledge.org/resource/Association_football>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/SportsTeam>', '<http://schema.org/foundingDate> <1923>', '<http://schema.org/foundingDate> <1912>', '<http://schema.org/foundingDate> <1905>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Sports_club>', '<http://schema.org/foundingDate> <1904>', '<http://schema.org/memberOf> <http://yago-knowledge.org/resource/Cyprus_Football_Association>', '<http://schema.org/foundingDate> <1910>', '<http://schema.org/foundingDate> <1995>', '<http://schema.org/foundingDate> <1899>', '<http://schema.org/foundingDate> <1893>', '<http://schema.org/foundingDate> <2004>', '<http://schema.org/foundingDate> <1919>', '<http://schema.org/foundingDate> <1908>', '<http://schema.org/foundingDate> <1909>']
# 37 {'Subject': 'Battle_of_France', 'Questions-C': 13}
# 26/37
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Event>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/EventSeries>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Awards_ceremony>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Summer_Olympic_Games>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Winter_Olympic_Games>', '<http://schema.org/location> <http://yago-knowledge.org/resource/Berlin>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Olympic_sports>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Battle>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/French%20troops%20barricades2%20paris%201940.png>']
# 38 {'Subject': 'Jean_Louis', 'Questions-C': 20}
# 27/38
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor>', '<http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Guitarist>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/New_York_City>', '<http://schema.org/deathPlace> <http://yago-knowledge.org/resource/Los_Angeles>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Television_producer>', '<http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Comedian>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/Chicago>', '<http://schema.org/alumniOf> <http://yago-knowledge.org/resource/Harvard_University>', '<http://schema.org/deathPlace> <http://yago-knowledge.org/resource/Beverly_Hills,_California>', '<http://schema.org/birthPlace> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/givenName> <http://yago-knowledge.org/resource/Robert>', '<http://schema.org/givenName> <http://yago-knowledge.org/resource/Justin_(name)>']
# 39 {'Subject': 'Storyboard_artist', 'Questions-C': 20}
# 27/39
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Place>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Event>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Occupation>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Profession>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Corporate_title>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Voice_type>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Discipline_(academia)>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Burattini%20ca%201770.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Mati%20catradio%200042%20resize.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Dance%20band%20drummer%20at%20Mark%20Foy%27s%20Empress%20Ballroom%20from%20The%20Powerhouse%20Museum.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Charles%20Willson%20Peale%20-%20David%20Rittenhouse%20-%20Google%20Art%20Project.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/The%20Strong%20Man%20of%20the%20Police%20School%20%281906%29%20-%20TIMEA.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Marcelo%20Baumbach.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/SarDrama%20%D0%A3%D1%80%D0%BE%D0%B4%20%D1%80%D0%B5%D0%BF%D0%B5%D1%82%D0%B8%D1%86%D0%B8%D0%B8%2001.JPG>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Archives%20of%20American%20Art%20-%20Richard%20H.%20Jansen%20-%202178.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/Ram%C3%B3n%20Columba%20y%20Siulnas.jpg>', '<http://schema.org/image> <http://commons.wikimedia.org/wiki/Special:FilePath/CF46618267%20109996904033.gif>']
# 40 {'Subject': 'Cleopatra_(1963_film)', 'Questions-C': 14}
# 28/40
#
# ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Person>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/Organization>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWork>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_States>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Action_film>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/New_York_City>', '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://schema.org/CreativeWorkSeries>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/United_Kingdom>', '<http://schema.org/contentLocation> <http://yago-knowledge.org/resource/London>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Biographical_film>', '<http://schema.org/countryOfOrigin> <http://yago-knowledge.org/resource/France>', '<http://schema.org/genre> <http://yago-knowledge.org/resource/Romance_film>', '<http://schema.org/actor> <http://yago-knowledge.org/resource/Kate_Winslet>', '<http://schema.org/productionCompany> <http://yago-knowledge.org/resource/20th_Century_Studios>']

# %% [markdown]
# # Result Analysis

# %% [markdown]
# ## Top 10 Questions

# %%
questions = []
for subject in questionhistory:
    for question in subject:
        questions.append(question)

# %%
from collections import Counter
c=Counter(questions)
#print(c.most_common(11))
mostcommon = []
for i in c.most_common(11)[1:]:
    mostcommon.append(i[0])

# %%
#topquestions = pd.DataFrame({'None IE': mostcommon})
import pandas as pd 
topquestions = pd.read_csv('TopQuestions.csv')
topquestions = topquestions.drop('Unnamed: 0', axis=1)

#topquestions['Chat GPT'] = mostcommon

#topquestions.to_csv('TopQuestions.csv')

# %%
gpt = 0
stan = 0
clcy = 0

for b,c,s,g in topquestions.values:
    if b == c:
        clcy += 1
    if b == s:
        stan += 1
    if b == g:
        gpt += 1
gpt,stan,clcy
for i in topquestions['Chat GPT']:
    i = i.split(' ')
    j = i[1].split('<')[-1]
    i = i[0].split('<')[-1]
    i = i.split('/')[-1]
    i = i.split('#')[-1]
    j = j.split('/')[-1]
    j = j.split('>')[0]
    i = i.split('>')[0]
    i = " ".join(i.split('_'))
    j = " ".join(j.split('_'))
    print(i,j)
# Out:
# nationality United States
# hasOccupation Actor
# type Person
# hasOccupation Film producer
# hasOccupation Film director
# type Country
# type Actor
# hasOccupation Stage actor
# memberOf Democratic Party (United States)
# nationality United Kingdom

# %% [markdown]
# ## Number of Questions asked

# %%
# if literal is less than 2-3 words make a link version
import pandas as pd 
thesis_results = pd.read_csv('ThesisResults.csv')
thesis_results = thesis_results.drop('Unnamed: 0', axis=1)

thesis_results
# Out:
#                       Subject  Questions-C  Questions-Base  Questions-S
# 0                 David_Bowie            7               7            7  \
# 1                  Kanye_West            6               6            7
# 2                      Eminem            7               8            8
# 3            Jennifer_Aniston            7               7            7
# 4              George_W._Bush            7               7            7
# ..                        ...          ...             ...          ...
# 179              Nancy_Pelosi            8               8            8
# 180            Andhra_Pradesh            8               8            8
# 181               Maharashtra            8               8            7
# 182  Paris_Saint-Germain_F.C.            9               9            8
# 183             Uttar_Pradesh            8               8            8
#
#      Questions-GPT
# 0                7
# 1                7
# 2                9
# 3                7
# 4                7
# ..             ...
# 179              8
# 180              8
# 181              8
# 182              9
# 183              8
#
# [184 rows x 5 columns]

# %%
#9/21 - ClauCy
#11/21 - Stanford
#thesis_results = pd.DataFrame(results)
thesis_results['Questions-GPT2'] = results
thesis_results
#thesis_results.to_csv('ThesisResults.csv')

# %%
import pandas as pd 
data1 = pd.read_csv('ThesisResults.csv')
data1 = data1.drop('Unnamed: 0', axis=1)
#data1 = data1.drop('Questions-GPT2', axis=1)
#data1.to_csv('betterThesisResults.csv')
data1
#data1.T.to_csv('flippedata.csv')

# %%
datas = []
for s,c,b,st,g in data1.values:
    datas.append({'Model': 'Base', 'Subject': s, 'Questions': b})
    datas.append({'Model': 'ClauCy', 'Subject': s, 'Questions': c})
    datas.append({'Model': 'Stanford', 'Subject': s, 'Questions': st})
    datas.append({'Model': 'GPT', 'Subject': s, 'Questions': g})
    
d = pd.DataFrame(datas)
d.to_csv('thesisdata3.csv')

# %%
clcy = 0
stan = 0
gpt = 0
base = 0

for _,c,b,s,g in data1.values:
    clcy += c
    stan += s
    gpt += g
    base += b

base,clcy,stan,gpt

# %%
def results( results1, results2, label1, label2 ):
    score1 = 0
    score2 = 0
    tie = 0
    for res1,res2 in zip( results1, results2 ):
        if res1 == res2:
            tie += 1
        elif res1 > res2:
            score2 += 1
        else:
            score1 += 1
    
    print( '%s-%s:' %( label1.upper(), label2.upper() ) )
    print( '%s score:' %( label1 ), score1, '-%s score:' %( label2 ), score2, '-tie score:', tie ) 
    print( '%s:' %(label1), round( ( score1/( score1+score2+tie ) ) *100,2 ) )
    print( '%s:' %(label2), round( ( score2/( score1+score2+tie ) ) *100,2 ) )
    print( 'tie %:', round( ( tie/( score1+score2+tie ) ) *100,2 ) )
    if score1 > score2:
        print( '%s best' %( label1.upper() ) )
    else:
        print( '%s best' %( label2.upper() ) )
    #return [score1,score2,tie]
    return

results( thesis_results['Questions-GPT'], thesis_results['Questions-Base'], 'gpt', 'base' )
print()
results( thesis_results['Questions-GPT'], thesis_results['Questions-C'], 'gpt', 'clcy' ) 
print()
results( thesis_results['Questions-GPT'], thesis_results['Questions-S'], 'gpt', 'stan' )
print()
results( thesis_results['Questions-C'], thesis_results['Questions-Base'], 'clcy', 'base' )
print()
results( thesis_results['Questions-S'], thesis_results['Questions-Base'], 'stan', 'base' )
print()
results( thesis_results['Questions-S'], thesis_results['Questions-C'], 'stan', 'clcy' )
# Out:
# GPT-BASE:
# gpt score: 49 -base score: 39 -tie score: 96
# gpt: 26.63
# base: 21.2
# tie %: 52.17
# GPT best
#
# GPT-CLCY:
# gpt score: 52 -clcy score: 46 -tie score: 86
# gpt: 28.26
# clcy: 25.0
# tie %: 46.74
# GPT best
#
# GPT-STAN:
# gpt score: 50 -stan score: 45 -tie score: 89
# gpt: 27.17
# stan: 24.46
# tie %: 48.37
# GPT best
#
# CLCY-BASE:
# clcy score: 20 -base score: 22 -tie score: 142
# clcy: 10.87
# base: 11.96
# tie %: 77.17
# BASE best
#
# STAN-BASE:
# stan score: 29 -base score: 26 -tie score: 129
# stan: 15.76
# base: 14.13
# tie %: 70.11
# STAN best
#
# STAN-CLCY:
# stan score: 36 -clcy score: 33 -tie score: 115
# stan: 19.57
# clcy: 17.93
# tie %: 62.5
# STAN best

# %%
s = 0
g = 0
c = 0
tie = 0
gs_tie = 0
gc_tie = 0
sc_tie = 0

for _,clcy,base,stan,gpt in thesis_results.values:
    if stan == gpt and gpt == clcy:
        #s += 1
        #g += 1
        #c += 1
        tie += 1 
    elif stan == gpt and stan < clcy:
        #s += 1
        #g += 1
        gs_tie += 1 
    elif stan == clcy and gpt > clcy:
        #s += 1
        #c += 1
        #print(stan,clcy,gpt)
        sc_tie += 1
    elif gpt == clcy and gpt < stan:
        #g += 1
        #c += 1
        gc_tie += 1
    elif gpt < stan and gpt < clcy:
        g += 1
    elif stan < gpt and stan < clcy:
        s += 1 
    elif clcy < gpt and clcy < stan:
        c += 1 
print('clcy:',c,'- Stan:',s,'- GPT:',g,'- tie:',tie,'- gptstan-tie:',gs_tie,'- gptclcy-tie:',gc_tie,'- stanclcy:',sc_tie) 
print(c+tie+gc_tie+sc_tie)
print(s+tie+gs_tie+sc_tie)
print(g+tie+gs_tie+gc_tie)
print()
print(round(20/(20+18+35+62+13+12+24)*100,1))
print(round(18/(20+18+35+62+13+12+24)*100,1))
print(round(35/(20+18+35+62+13+12+24)*100,1))
# Out:
# clcy: 20 - Stan: 18 - GPT: 35 - tie: 62 - gptstan-tie: 13 - gptclcy-tie: 12 - stanclcy: 24
# 118
# 117
# 122
#
# 10.9
# 9.8
# 19.0

# %%
# Difference in questions asked

# %%
def results( results1, results2, label1, label2 ):
    diff = 0
    abdiff = 0
    for res1,res2 in zip( results1, results2 ):
        diff += (res2 - res1)
        abdiff += abs(res2 - res1)
    diff = round(diff/len(results1),2)
    abdiff = round(abdiff/len(results1),2)
    
    print( '%s-%s:' %( label1.upper(), label2.upper() ) )
    print('diff:',diff)
    print('abs diff:', abdiff)
    return 

results( thesis_results['Questions-GPT'], thesis_results['Questions-Base'], 'gpt', 'base' )
print()
results( thesis_results['Questions-C'], thesis_results['Questions-Base'], 'clcy', 'base' )
print()
results( thesis_results['Questions-S'], thesis_results['Questions-Base'], 'stan', 'base' )
# Out:
# GPT-BASE:
# diff: 0.11
# abs diff: 0.66
#
# CLCY-BASE:
# diff: 0.08
# abs diff: 0.34
#
# STAN-BASE:
# diff: 0.11
# abs diff: 0.42

# %%
sub = []
for i in subjects_lost:
    i = i.split('<')[1]
    i = i.split('>')[0]
    sub.append("%s" %(i))
sub

# %% [markdown]
# #### Seeds used:
# - 10
# - ??
# - ??

# %% [markdown]
# #### Time started:
# - 10
#     - base model
#         - 22:50

# %%
len('ALL'.split('/'))
