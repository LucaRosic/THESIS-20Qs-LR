# %% [markdown]
# ## Code

# %%
# %load_ext ipython_sparql_pandas

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from random import randint
sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q-Stanford-186')
sparql.setReturnFormat(JSON)

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']

def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    return(listOfObj,listOfPred)

def generateQuestion(listOfPred, listOfObj, index, subject):
    flag = True
    # Checks if question has been asked before
    if ('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>') in AttrHistory:
        # Goes to next question
        return generateQuestion(listOfPred, listOfObj, index+1, subject)
        
    else:
        # Stores question
        AttrHistory.append('<' + str(listOfPred[index]['value']) +'> <'+str(listOfObj[index]['value'])+ '>')
    
    
    # Prints question    
    #print(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    # Checks if object has data values, such as 'gYear' or 'age'
    try:
        listOfObj[index]['datatype']
    except:
        flag = False
        
    if flag is True:
        # Looks up question in knowledge graph
        datatype = listOfObj[index]["datatype"].split("#")[-1]
        answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '"'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype)
    else:
        # Looks up question in knowledge graph
        if len(listOfObj[index]["value"].split('/')) == 1:
            answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '"'+str(listOfObj[index]['value'])+ '"')
        else:
            answer = findAnswer(subject, '<' + str(listOfPred[index]['value']) +'>', '<'+str(listOfObj[index]['value'])+ '>')
    
    # Prints answer to question
    #print(answer)
    
    
    # Answer is "yes" or starts with 'y', adds positive filter to PosAttr 
    if answer:
        # Object has data type
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
            if len(listOfObj[index]["value"].split('/')) == 1:
                PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+ '".')  
            else:
                PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.')    
    
    # Answer is "no" or starts with 'n', adds negative filter to NegAttr
    elif not answer:
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
            if len(listOfObj[index]["value"].split('/')) == 1:
                NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+ '". }}') 
            else:
                NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}')   
    
    # The answer is unknown, goes to next question
    else:
        return generateQuestion(listOfPred, listOfObj, index+1)
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    # Returns filters
    return (PosFilters, NegFilters)

  
def updateQuery(left, PosFilters, NegFilters):
    # Find 10 ten attributes that occurr closest to half the entities left
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            
            group by ?p ?o 
            ORDER BY ABS( {left} - ?count )
            Limit 10
            
            """) 
        
    return FilterQuestion

# %%
def pickSubject():
    # Adds all "popular" entities (with an abstract) to a list
    data = pd.read_csv('~/Desktop/GitHub/THESIS-20Qs-LR/data/abstract data/Abstracts-186.csv')
    data = data.drop('Unnamed: 0', axis=1)
    return (list(data['Entity']))
     

def findAnswer(subject,p,o):
    # Finds answer to question
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
def numberleft(PosFilters,NegFilters):
    # Find out how many entities left
    sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q-Stanford-186')
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            {PosFilters}            
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            {NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            
            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))

# %%
def popentities(PosFilters,NegFilters):
    # Find 
    query =  f"""
            select ?s where 
            {{
            
            {PosFilters}
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            {NegFilters} 
            
            }}
            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    return qres["results"]["bindings"]

# %%
# Resets variables for game 
def game_reset():
    PosAttr= ['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .']
    NegAttr= ['']
    AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    left = numberleft("".join(PosAttr), "".join(NegAttr))
    FilterQuestion =  f"""
        select (count(*) as ?count) ?p ?o  where 
        {{

        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s ?p ?o .
        }} 
        group by ?p ?o 
        ORDER BY ABS( %s - ?count )
        limit 20
        """ %((left/2))
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
import random
import pandas as pd
random.seed(10)
wincount = 0
subjects_lost = []
gamesplayed = 0
lostbybreak = 0
breakskip = 0
subjects = pickSubject()
#print(subjects)
totalgames = len(subjects)
results = []
questionhistory = []

# %%
# Plays games until the amount of games played equals to the number of subjects
while gamesplayed < totalgames:
    # Resets all variables
    try:
        left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
        i=0
        outofguess = []
        # Pick subject
        subject = "<" + subjects[gamesplayed] + ">"
        
        # Whilst less than 20 questions asked
        while i < 20:

            # List of Pred and Obj for questions
            listOfObj ,listOfPred = extractCountAndAttr(qres)

            # If only 1 popular entity is left break
            if left<=1:
                break

            # Ask question and add filters to query
            PosFilters, NegFilters = generateQuestion(listOfPred, listOfObj, 0, subject)

            # Number of popular entities left
            left = numberleft(PosFilters, NegFilters)
            #print('left -',left)

            # Run query
            sparql = SPARQLWrapper('http://localhost:7200/repositories/20Q-Stanford-186')
            query = updateQuery(left/2,PosFilters, NegFilters)
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)
            qres = sparql.queryAndConvert()

            i+=1

        # Guesses the entity that fits the questions asked
        if i != 20:
            for attr in popentities(PosFilters, NegFilters):
                for x in [attr['s']['value']][0:10]:
                    answer = (x.split("/")[-1])
                    
            # Guessed correctly 
            if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
                wincount += 1
                gamesplayed += 1
                results.append(i)
                
                print(gamesplayed,{'Subject': subject.split("/")[-1].split('>')[0], 'Guessed': 'Yes', 'Questions-B': i})
                print('%s/%s' %(wincount,gamesplayed))
                print()
            
            # Guessed incorrectly 
            else:
                gamesplayed += 1
                subjects_lost.append(subject)
                results.append(i)
                print(gamesplayed,{'Subject': subject.split("/")[-1].split('>')[0], 'Guessed': 'No', 'Questions-B': i})
                print('%s/%s' %(wincount,gamesplayed))
                print()

        # ran out of questions
        else:
            # Randomly guess an entity that matchs the questions asked
            for j in popentities(PosFilters, NegFilters):
                    outofguess.append(f'{j["s"]["value"].split("/")[-1]}')
            guess = random.choice(outofguess)
            
            # Guessed correctly
            if str(subject.split("/")[-1]) == str(guess + ">"):
                wincount += 1
                gamesplayed += 1
                results.append(20)
                print(gamesplayed,{'Subject': subject.split("/")[-1].split('>')[0], 'Guessed': 'Yes', 'Questions-B': 20})
                print('%s/%s' %(wincount,gamesplayed))
                print()
                
            # Guessed incorrectly 
            else:
                gamesplayed += 1
                subjects_lost.append(subject)
                #results.append({'Subject': subject.split("/")[-1].split('>')[0], 'Questions-C': 20})
                results.append(20)
                print(gamesplayed, {'Subject': subject.split("/")[-1].split('>')[0],'Guessed': 'No', 'Questions-B': 20})
                print('%s/%s' %(wincount,gamesplayed))
                print()
        breakskip = 0
        #print(AttrHistory)
        questionhistory.append(AttrHistory)
    
    # If game is interrupted, stop
    except KeyboardInterrupt:
        breakf
    # If query breaks, retry entity game
    except:
        continue

# When tournament ends prints the amount of entities guessed correctly
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
# 1 {'Subject': 'David_Bowie', 'Guessed': 'Yes', 'Questions-B': 7}
# 1/1
#
# 2 {'Subject': 'Kanye_West', 'Guessed': 'Yes', 'Questions-B': 7}
# 2/2
#
# 3 {'Subject': 'Eminem', 'Guessed': 'Yes', 'Questions-B': 8}
# 3/3
#
# 4 {'Subject': 'Jennifer_Aniston', 'Guessed': 'Yes', 'Questions-B': 7}
# 4/4
#
# 5 {'Subject': 'George_W._Bush', 'Guessed': 'Yes', 'Questions-B': 7}
# 5/5
#
# 6 {'Subject': 'Prince_(musician)', 'Guessed': 'Yes', 'Questions-B': 7}
# 6/6
#
# 7 {'Subject': 'Justin_Bieber', 'Guessed': 'Yes', 'Questions-B': 7}
# 7/7
#
# 8 {'Subject': 'Drake_(musician)', 'Guessed': 'Yes', 'Questions-B': 8}
# 8/8
#
# 9 {'Subject': 'Heath_Ledger', 'Guessed': 'Yes', 'Questions-B': 7}
# 9/9
#
# 10 {'Subject': 'John_Krasinski', 'Guessed': 'Yes', 'Questions-B': 7}
# 10/10
#
# 11 {'Subject': 'Val_Kilmer', 'Guessed': 'Yes', 'Questions-B': 6}
# 11/11
#
# 12 {'Subject': 'American_Horror_Story', 'Guessed': 'Yes', 'Questions-B': 7}
# 12/12
#
# 13 {'Subject': 'Brad_Pitt', 'Guessed': 'Yes', 'Questions-B': 7}
# 13/13
#
# 14 {'Subject': 'Japan', 'Guessed': 'Yes', 'Questions-B': 7}
# 14/14
#
# 15 {'Subject': 'Barack_Obama', 'Guessed': 'Yes', 'Questions-B': 8}
# 15/15
#
# 16 {'Subject': 'Bill_Clinton', 'Guessed': 'Yes', 'Questions-B': 8}
# 16/16
#
# 17 {'Subject': 'Donald_Trump', 'Guessed': 'Yes', 'Questions-B': 7}
# 17/17
#
# 18 {'Subject': 'Jimmy_Carter', 'Guessed': 'Yes', 'Questions-B': 8}
# 18/18
#
# 19 {'Subject': 'Martin_Luther_King_Jr.', 'Guessed': 'Yes', 'Questions-B': 8}
# 19/19
#
# 20 {'Subject': 'Ronald_Reagan', 'Guessed': 'Yes', 'Questions-B': 9}
# 20/20
#
# 21 {'Subject': 'Germany', 'Guessed': 'Yes', 'Questions-B': 8}
# 21/21
#
# 22 {'Subject': 'Matthew_Perry', 'Guessed': 'Yes', 'Questions-B': 7}
# 22/22
#
# 23 {'Subject': 'Vietnam_War', 'Guessed': 'Yes', 'Questions-B': 6}
# 23/23
#
# 24 {'Subject': 'The_Walking_Dead_(TV_series)', 'Guessed': 'Yes', 'Questions-B': 7}
# 24/24
#
# 25 {'Subject': 'London', 'Guessed': 'Yes', 'Questions-B': 8}
# 25/25
#
# 26 {'Subject': 'World_War_I', 'Guessed': 'Yes', 'Questions-B': 7}
# 26/26
#
# 27 {'Subject': 'California', 'Guessed': 'Yes', 'Questions-B': 8}
# 27/27
#
# 28 {'Subject': 'The_Beatles', 'Guessed': 'Yes', 'Questions-B': 8}
# 28/28
#
# 29 {'Subject': 'Robert_Downey_Jr.', 'Guessed': 'Yes', 'Questions-B': 8}
# 29/29
#
# 30 {'Subject': 'Roger_Federer', 'Guessed': 'Yes', 'Questions-B': 8}
# 30/30
#
# 31 {'Subject': 'Marilyn_Manson', 'Guessed': 'Yes', 'Questions-B': 7}
# 31/31
#
# 32 {'Subject': 'Ben_Affleck', 'Guessed': 'Yes', 'Questions-B': 6}
# 32/32
#
# 33 {'Subject': 'India', 'Guessed': 'Yes', 'Questions-B': 7}
# 33/33
#
# 34 {'Subject': 'Serena_Williams', 'Guessed': 'Yes', 'Questions-B': 7}
# 34/34
#
# 35 {'Subject': 'Novak_Djokovic', 'Guessed': 'Yes', 'Questions-B': 7}
# 35/35
#
# 36 {'Subject': 'China', 'Guessed': 'Yes', 'Questions-B': 8}
# 36/36
#
# 37 {'Subject': 'France', 'Guessed': 'Yes', 'Questions-B': 7}
# 37/37
#
# 38 {'Subject': 'Michael_Jackson', 'Guessed': 'Yes', 'Questions-B': 8}
# 38/38
#
# 39 {'Subject': 'Nicolas_Cage', 'Guessed': 'Yes', 'Questions-B': 7}
# 39/39
#
# 40 {'Subject': 'Johnny_Depp', 'Guessed': 'Yes', 'Questions-B': 7}
# 40/40
#
# 41 {'Subject': 'South_Africa', 'Guessed': 'Yes', 'Questions-B': 8}
# 41/41
#
# 42 {'Subject': 'Tobey_Maguire', 'Guessed': 'Yes', 'Questions-B': 9}
# 42/42
#
# 43 {'Subject': 'Sandra_Bullock', 'Guessed': 'Yes', 'Questions-B': 7}
# 43/43
#
# 44 {'Subject': 'Paul_Walker', 'Guessed': 'Yes', 'Questions-B': 7}
# 44/44
#
# 45 {'Subject': 'Mark_Wahlberg', 'Guessed': 'Yes', 'Questions-B': 8}
# 45/45
#
# 46 {'Subject': 'New_Zealand', 'Guessed': 'Yes', 'Questions-B': 8}
# 46/46
#
# 47 {'Subject': 'Alec_Baldwin', 'Guessed': 'Yes', 'Questions-B': 7}
# 47/47
#
# 48 {'Subject': 'Rachel_Weisz', 'Guessed': 'Yes', 'Questions-B': 7}
# 48/48
#
# 49 {'Subject': 'Stanley_Tucci', 'Guessed': 'Yes', 'Questions-B': 8}
# 49/49
#
# 50 {'Subject': 'Keanu_Reeves', 'Guessed': 'Yes', 'Questions-B': 8}
# 50/50
#
# 51 {'Subject': 'Frank_Sinatra', 'Guessed': 'Yes', 'Questions-B': 7}
# 51/51
#
# 52 {'Subject': 'Salma_Hayek', 'Guessed': 'Yes', 'Questions-B': 8}
# 52/52
#
# 53 {'Subject': 'Ryan_Reynolds', 'Guessed': 'Yes', 'Questions-B': 8}
# 53/53
#
# 54 {'Subject': 'Snoop_Dogg', 'Guessed': 'Yes', 'Questions-B': 8}
# 54/54
#
# 55 {'Subject': 'Priyanka_Chopra', 'Guessed': 'Yes', 'Questions-B': 8}
# 55/55
#
# 56 {'Subject': 'Ernest_Hemingway', 'Guessed': 'Yes', 'Questions-B': 8}
# 56/56
#
# 57 {'Subject': 'Brittany_Murphy', 'Guessed': 'Yes', 'Questions-B': 7}
# 57/57
#
# 58 {'Subject': 'Lady_Gaga', 'Guessed': 'Yes', 'Questions-B': 7}
# 58/58
#
# 59 {'Subject': 'Robin_Williams', 'Guessed': 'Yes', 'Questions-B': 7}
# 59/59
#
# 60 {'Subject': 'Will_Smith', 'Guessed': 'Yes', 'Questions-B': 8}
# 60/60
#
# 61 {'Subject': 'Mila_Kunis', 'Guessed': 'Yes', 'Questions-B': 10}
# 61/61
#
# 62 {'Subject': 'Quentin_Tarantino', 'Guessed': 'Yes', 'Questions-B': 9}
# 62/62
#
# 63 {'Subject': 'Tom_Hanks', 'Guessed': 'Yes', 'Questions-B': 7}
# 63/63
#
# 64 {'Subject': 'American_Civil_War', 'Guessed': 'Yes', 'Questions-B': 9}
# 64/64
#
# 65 {'Subject': 'Winston_Churchill', 'Guessed': 'Yes', 'Questions-B': 8}
# 65/65
#
# 66 {'Subject': 'Netherlands', 'Guessed': 'Yes', 'Questions-B': 7}
# 66/66
#
# 67 {'Subject': 'Stephen_Hawking', 'Guessed': 'Yes', 'Questions-B': 7}
# 67/67
#
# 68 {'Subject': 'Arnold_Schwarzenegger', 'Guessed': 'Yes', 'Questions-B': 9}
# 68/68
#
# 69 {'Subject': 'Clint_Eastwood', 'Guessed': 'Yes', 'Questions-B': 9}
# 69/69
#
# 70 {'Subject': 'Julia_Roberts', 'Guessed': 'Yes', 'Questions-B': 8}
# 70/70
#
# 71 {'Subject': 'Sylvester_Stallone', 'Guessed': 'Yes', 'Questions-B': 7}
# 71/71
#
# 72 {'Subject': "Grey's_Anatomy", 'Guessed': 'Yes', 'Questions-B': 7}
# 72/72
#
# 73 {'Subject': 'Judy_Garland', 'Guessed': 'Yes', 'Questions-B': 7}
# 73/73
#
# 74 {'Subject': 'Canada', 'Guessed': 'Yes', 'Questions-B': 8}
# 74/74
#
# 75 {'Subject': 'Jake_Gyllenhaal', 'Guessed': 'Yes', 'Questions-B': 7}
# 75/75
#
# 76 {'Subject': 'Betty_White', 'Guessed': 'Yes', 'Questions-B': 8}
# 76/76
#
# 77 {'Subject': 'Tom_Cruise', 'Guessed': 'Yes', 'Questions-B': 8}
# 77/77
#
# 78 {'Subject': 'Game_of_Thrones', 'Guessed': 'Yes', 'Questions-B': 8}
# 78/78
#
# 79 {'Subject': 'Jason_Sudeikis', 'Guessed': 'Yes', 'Questions-B': 9}
# 79/79
#
# 80 {'Subject': 'Scarlett_Johansson', 'Guessed': 'Yes', 'Questions-B': 8}
# 80/80
#
# 81 {'Subject': 'George_Harrison', 'Guessed': 'Yes', 'Questions-B': 8}
# 81/81
#
# 82 {'Subject': 'Daniel_Craig', 'Guessed': 'Yes', 'Questions-B': 7}
# 82/82
#
# 83 {'Subject': 'Kate_Winslet', 'Guessed': 'Yes', 'Questions-B': 7}
# 83/83
#
# 84 {'Subject': 'Elvis_Presley', 'Guessed': 'Yes', 'Questions-B': 7}
# 84/84
#
# 85 {'Subject': 'William_Shakespeare', 'Guessed': 'Yes', 'Questions-B': 8}
# 85/85
#
# 86 {'Subject': 'Vin_Diesel', 'Guessed': 'Yes', 'Questions-B': 8}
# 86/86
#
# 87 {'Subject': 'Angelina_Jolie', 'Guessed': 'Yes', 'Questions-B': 8}
# 87/87
#
# 88 {'Subject': 'Britney_Spears', 'Guessed': 'Yes', 'Questions-B': 8}
# 88/88
#
# 89 {'Subject': 'Emily_Blunt', 'Guessed': 'Yes', 'Questions-B': 9}
# 89/89
#
# 90 {'Subject': 'Selena_Gomez', 'Guessed': 'Yes', 'Questions-B': 7}
# 90/90
#
# 91 {'Subject': 'Blake_Lively', 'Guessed': 'Yes', 'Questions-B': 11}
# 91/91
#
# 92 {'Subject': 'Marilyn_Monroe', 'Guessed': 'Yes', 'Questions-B': 8}
# 92/92
#
# 93 {'Subject': 'Matthew_McConaughey', 'Guessed': 'Yes', 'Questions-B': 8}
# 93/93
#
# 94 {'Subject': 'Dwayne_Johnson', 'Guessed': 'Yes', 'Questions-B': 9}
# 94/94
#
# 95 {'Subject': 'Freddie_Mercury', 'Guessed': 'Yes', 'Questions-B': 8}
# 95/95
#
# 96 {'Subject': 'Tom_Hardy', 'Guessed': 'Yes', 'Questions-B': 7}
# 96/96
#
# 97 {'Subject': 'Dilip_Kumar', 'Guessed': 'Yes', 'Questions-B': 7}
# 97/97
#
# 98 {'Subject': 'Queen_Victoria', 'Guessed': 'Yes', 'Questions-B': 8}
# 98/98
#
# 99 {'Subject': 'Tupac_Shakur', 'Guessed': 'Yes', 'Questions-B': 9}
# 99/99
#
# 100 {'Subject': 'Abraham_Lincoln', 'Guessed': 'Yes', 'Questions-B': 7}
# 100/100
#
# 101 {'Subject': 'Macaulay_Culkin', 'Guessed': 'Yes', 'Questions-B': 9}
# 101/101
#
# 102 {'Subject': 'Alexander_the_Great', 'Guessed': 'Yes', 'Questions-B': 7}
# 102/102
#
# 103 {'Subject': 'Kristen_Stewart', 'Guessed': 'Yes', 'Questions-B': 7}
# 103/103
#
# 104 {'Subject': 'Google', 'Guessed': 'Yes', 'Questions-B': 9}
# 104/104
#
# 105 {'Subject': 'Albert_Einstein', 'Guessed': 'Yes', 'Questions-B': 8}
# 105/105
#
# 106 {'Subject': 'President_of_the_United_States', 'Guessed': 'Yes', 'Questions-B': 10}
# 106/106
#
# 107 {'Subject': 'Adele', 'Guessed': 'Yes', 'Questions-B': 7}
# 107/107
#
# 108 {'Subject': 'Nicki_Minaj', 'Guessed': 'Yes', 'Questions-B': 7}
# 108/108
#
# 109 {'Subject': 'Emma_Stone', 'Guessed': 'Yes', 'Questions-B': 8}
# 109/109
#
# 110 {'Subject': 'Olivia_Wilde', 'Guessed': 'Yes', 'Questions-B': 8}
# 110/110
#
# 111 {'Subject': 'Audrey_Hepburn', 'Guessed': 'Yes', 'Questions-B': 7}
# 111/111
#
# 112 {'Subject': 'Aretha_Franklin', 'Guessed': 'Yes', 'Questions-B': 8}
# 112/112
#
# 113 {'Subject': 'Jennifer_Lawrence', 'Guessed': 'Yes', 'Questions-B': 8}
# 113/113
#
# 114 {'Subject': 'Adolf_Hitler', 'Guessed': 'Yes', 'Questions-B': 6}
# 114/114
#
# 115 {'Subject': 'Rihanna', 'Guessed': 'Yes', 'Questions-B': 8}
# 115/115
#
# 116 {'Subject': 'Carey_Mulligan', 'Guessed': 'Yes', 'Questions-B': 7}
# 116/116
#
# 117 {'Subject': 'Bruce_Lee', 'Guessed': 'Yes', 'Questions-B': 9}
# 117/117
#
# 118 {'Subject': 'Jennifer_Lopez', 'Guessed': 'Yes', 'Questions-B': 8}
# 118/118
#
# 119 {'Subject': 'Australia', 'Guessed': 'Yes', 'Questions-B': 8}
# 119/119
#
# 120 {'Subject': 'Soviet_Union', 'Guessed': 'Yes', 'Questions-B': 8}
# 120/120
#
# 121 {'Subject': 'Android_(operating_system)', 'Guessed': 'Yes', 'Questions-B': 7}
# 121/121
#
# 122 {'Subject': 'Taiwan', 'Guessed': 'Yes', 'Questions-B': 7}
# 122/122
#
# 123 {'Subject': 'Aaliyah', 'Guessed': 'Yes', 'Questions-B': 6}
# 123/123
#
# 124 {'Subject': 'Chris_Evans_(actor)', 'Guessed': 'Yes', 'Questions-B': 8}
# 124/124
#
# 125 {'Subject': 'John_F._Kennedy', 'Guessed': 'Yes', 'Questions-B': 8}
# 125/125
#
# 126 {'Subject': 'Leonardo_DiCaprio', 'Guessed': 'Yes', 'Questions-B': 7}
# 126/126
#
# 127 {'Subject': 'Jason_Momoa', 'Guessed': 'Yes', 'Questions-B': 8}
# 127/127
#
# 128 {'Subject': 'Nicole_Kidman', 'Guessed': 'Yes', 'Questions-B': 7}
# 128/128
#
# 129 {'Subject': 'Israel', 'Guessed': 'Yes', 'Questions-B': 8}
# 129/129
#
# 130 {'Subject': 'Turkey', 'Guessed': 'Yes', 'Questions-B': 8}
# 130/130
#
# 131 {'Subject': 'Elton_John', 'Guessed': 'Yes', 'Questions-B': 8}
# 131/131
#
# 132 {'Subject': 'George_Washington', 'Guessed': 'Yes', 'Questions-B': 7}
# 132/132
#
# 133 {'Subject': 'Microsoft_Windows', 'Guessed': 'Yes', 'Questions-B': 8}
# 133/133
#
# 134 {'Subject': 'Taylor_Swift', 'Guessed': 'Yes', 'Questions-B': 8}
# 134/134
#
# 135 {'Subject': 'Nelson_Mandela', 'Guessed': 'Yes', 'Questions-B': 8}
# 135/135
#
# 136 {'Subject': 'Megan_Fox', 'Guessed': 'Yes', 'Questions-B': 12}
# 136/136
#
# 137 {'Subject': 'Emma_Watson', 'Guessed': 'Yes', 'Questions-B': 7}
# 137/137
#
# 138 {'Subject': 'Tina_Turner', 'Guessed': 'Yes', 'Questions-B': 8}
# 138/138
#
# 139 {'Subject': 'Margaret_Thatcher', 'Guessed': 'Yes', 'Questions-B': 8}
# 139/139
#
# 140 {'Subject': 'Napoleon', 'Guessed': 'Yes', 'Questions-B': 8}
# 140/140
#
# 141 {'Subject': "Shaquille_O'Neal", 'Guessed': 'Yes', 'Questions-B': 8}
# 141/141
#
# 142 {'Subject': 'Franklin_D._Roosevelt', 'Guessed': 'Yes', 'Questions-B': 7}
# 142/142
#
# 143 {'Subject': 'Afghanistan', 'Guessed': 'Yes', 'Questions-B': 8}
# 143/143
#
# 144 {'Subject': 'Demi_Lovato', 'Guessed': 'Yes', 'Questions-B': 8}
# 144/144
#
# 145 {'Subject': 'Joseph_Stalin', 'Guessed': 'Yes', 'Questions-B': 8}
# 145/145
#
# 146 {'Subject': 'Russia', 'Guessed': 'Yes', 'Questions-B': 8}
# 146/146
#
# 147 {'Subject': 'Philippines', 'Guessed': 'Yes', 'Questions-B': 9}
# 147/147
#
# 148 {'Subject': 'Chelsea_F.C.', 'Guessed': 'Yes', 'Questions-B': 8}
# 148/148
#
# 149 {'Subject': 'Tamil_Nadu', 'Guessed': 'Yes', 'Questions-B': 8}
# 149/149
#
# 150 {'Subject': 'Elizabeth_II', 'Guessed': 'Yes', 'Questions-B': 8}
# 150/150
#
# 151 {'Subject': 'Mahatma_Gandhi', 'Guessed': 'Yes', 'Questions-B': 7}
# 151/151
#
# 152 {'Subject': 'MacOS', 'Guessed': 'Yes', 'Questions-B': 8}
# 152/152
#
# 153 {'Subject': 'Kobe_Bryant', 'Guessed': 'Yes', 'Questions-B': 8}
# 153/153
#
# 154 {'Subject': 'Kim_Kardashian', 'Guessed': 'Yes', 'Questions-B': 7}
# 154/154
#
# 155 {'Subject': 'Ottoman_Empire', 'Guessed': 'Yes', 'Questions-B': 8}
# 155/155
#
# 156 {'Subject': 'England_national_football_team', 'Guessed': 'Yes', 'Questions-B': 9}
# 156/156
#
# 157 {'Subject': 'Tom_Brady', 'Guessed': 'Yes', 'Questions-B': 8}
# 157/157
#
# 158 {'Subject': 'Travis_Barker', 'Guessed': 'Yes', 'Questions-B': 6}
# 158/158
#
# 159 {'Subject': 'George_V', 'Guessed': 'Yes', 'Questions-B': 8}
# 159/159
#
# 160 {'Subject': 'Michael_Jordan', 'Guessed': 'Yes', 'Questions-B': 9}
# 160/160
#
# 161 {'Subject': 'Pakistan', 'Guessed': 'Yes', 'Questions-B': 8}
# 161/161
#
# 162 {'Subject': 'Steve_Jobs', 'Guessed': 'Yes', 'Questions-B': 8}
# 162/162
#
# 163 {'Subject': 'LeBron_James', 'Guessed': 'Yes', 'Questions-B': 9}
# 163/163
#
# 164 {'Subject': 'Singapore', 'Guessed': 'Yes', 'Questions-B': 8}
# 164/164
#
# 165 {'Subject': 'Friends', 'Guessed': 'Yes', 'Questions-B': 8}
# 165/165
#
# 166 {'Subject': 'Joe_Biden', 'Guessed': 'Yes', 'Questions-B': 8}
# 166/166
#
# 167 {'Subject': 'John_Lennon', 'Guessed': 'Yes', 'Questions-B': 7}
# 167/167
#
# 168 {'Subject': 'New_York_City', 'Guessed': 'Yes', 'Questions-B': 8}
# 168/168
#
# 169 {'Subject': 'English_language', 'Guessed': 'Yes', 'Questions-B': 10}
# 169/169
#
# 170 {'Subject': 'United_Kingdom', 'Guessed': 'Yes', 'Questions-B': 8}
# 170/170
#
# 171 {'Subject': 'Manchester_City_F.C.', 'Guessed': 'Yes', 'Questions-B': 8}
# 171/171
#
# 172 {'Subject': 'Manchester_United_F.C.', 'Guessed': 'Yes', 'Questions-B': 8}
# 172/172
#
# 173 {'Subject': 'Lionel_Messi', 'Guessed': 'Yes', 'Questions-B': 7}
# 173/173
#
# 174 {'Subject': 'Myanmar', 'Guessed': 'Yes', 'Questions-B': 9}
# 174/174
#
# 175 {'Subject': 'Paul_McCartney', 'Guessed': 'Yes', 'Questions-B': 8}
# 175/175
#
# 176 {'Subject': 'The_Matrix', 'Guessed': 'Yes', 'Questions-B': 7}
# 176/176
#
# 177 {'Subject': 'Neymar', 'Guessed': 'Yes', 'Questions-B': 7}
# 177/177
#
# 178 {'Subject': 'XXX_(2002_film)', 'Guessed': 'Yes', 'Questions-B': 7}
# 178/178
#
# 179 {'Subject': 'United_States', 'Guessed': 'Yes', 'Questions-B': 8}
# 179/179
#
# 180 {'Subject': 'Nancy_Pelosi', 'Guessed': 'Yes', 'Questions-B': 8}
# 180/180
#
# 181 {'Subject': 'Andhra_Pradesh', 'Guessed': 'Yes', 'Questions-B': 8}
# 181/181
#
# 182 {'Subject': 'Maharashtra', 'Guessed': 'Yes', 'Questions-B': 7}
# 182/182
#
# 183 {'Subject': 'Paris_Saint-Germain_F.C.', 'Guessed': 'Yes', 'Questions-B': 8}
# 183/183
#
# 184 {'Subject': 'Uttar_Pradesh', 'Guessed': 'Yes', 'Questions-B': 8}
# 184/184
#
#
# Tournament ended! I have guessed 184 out of 184 things correctly.

# %% [markdown]
# # Result Analysis

# %% [markdown]
# ## Top 10 Questions

# %%
questions = []
for subject in questionhistory:
    for question in subject:
        questions.append(question)

# %%
from collections import Counter
c=Counter(questions)
#print(c.most_common(11))
mostcommon = []
for i in c.most_common(11)[1:]:
    mostcommon.append(i[0])

# %%
#topquestions = pd.DataFrame({'None IE': mostcommon})
import pandas as pd 
topquestions = pd.read_csv('TopQuestions.csv')
topquestions = topquestions.drop('Unnamed: 0', axis=1)

#topquestions['Chat GPT'] = mostcommon

#topquestions.to_csv('TopQuestions.csv')

# %%
gpt = 0
stan = 0
clcy = 0

for b,c,s,g in topquestions.values:
    if b == c:
        clcy += 1
    if b == s:
        stan += 1
    if b == g:
        gpt += 1
gpt,stan,clcy
for i in topquestions['Chat GPT']:
    i = i.split(' ')
    j = i[1].split('<')[-1]
    i = i[0].split('<')[-1]
    i = i.split('/')[-1]
    i = i.split('#')[-1]
    j = j.split('/')[-1]
    j = j.split('>')[0]
    i = i.split('>')[0]
    i = " ".join(i.split('_'))
    j = " ".join(j.split('_'))
    print(i,j)

# %% [markdown]
# ## Number of Questions asked

# %%
# if literal is less than 2-3 words make a link version
import pandas as pd 
thesis_results = pd.read_csv('ThesisResults.csv')
thesis_results = thesis_results.drop('Unnamed: 0', axis=1)

thesis_results

# %%
#thesis_results = pd.DataFrame(results)
thesis_results['Questions-GPT2'] = results
thesis_results
#thesis_results.to_csv('ThesisResults.csv')

# %%
import pandas as pd 
data1 = pd.read_csv('ThesisResults.csv')
data1 = data1.drop('Unnamed: 0', axis=1)
#data1 = data1.drop('Questions-GPT2', axis=1)
#data1.to_csv('betterThesisResults.csv')
data1
#data1.T.to_csv('flippedata.csv')

# %% [markdown]
# ### Model compared to another

# %%
def results( results1, results2, label1, label2 ):
    score1 = 0
    score2 = 0
    tie = 0
    for res1,res2 in zip( results1, results2 ):
        if res1 == res2:
            tie += 1
        elif res1 > res2:
            score2 += 1
        else:
            score1 += 1
    
    print( '%s-%s:' %( label1.upper(), label2.upper() ) )
    print( '%s score:' %( label1 ), score1, '-%s score:' %( label2 ), score2, '-tie score:', tie ) 
    print( '%s:' %(label1), round( ( score1/( score1+score2+tie ) ) *100,2 ) )
    print( '%s:' %(label2), round( ( score2/( score1+score2+tie ) ) *100,2 ) )
    print( 'tie %:', round( ( tie/( score1+score2+tie ) ) *100,2 ) )
    if score1 > score2:
        print( '%s best' %( label1.upper() ) )
    else:
        print( '%s best' %( label2.upper() ) )
    #return [score1,score2,tie]
    return

results( thesis_results['Questions-GPT'], thesis_results['Questions-Base'], 'gpt', 'base' )
print()
results( thesis_results['Questions-GPT'], thesis_results['Questions-C'], 'gpt', 'clcy' ) 
print()
results( thesis_results['Questions-GPT'], thesis_results['Questions-S'], 'gpt', 'stan' )
print()
results( thesis_results['Questions-C'], thesis_results['Questions-Base'], 'clcy', 'base' )
print()
results( thesis_results['Questions-S'], thesis_results['Questions-Base'], 'stan', 'base' )
print()
results( thesis_results['Questions-S'], thesis_results['Questions-C'], 'stan', 'clcy' )

# %% [markdown]
# ### IE models compared

# %%
s = 0
g = 0
c = 0
tie = 0
gs_tie = 0
gc_tie = 0
sc_tie = 0

for _,clcy,base,stan,gpt in thesis_results.values:
    if stan == gpt and gpt == clcy:
        #s += 1
        #g += 1
        #c += 1
        tie += 1 
    elif stan == gpt and stan < clcy:
        #s += 1
        #g += 1
        gs_tie += 1 
    elif stan == clcy and gpt > clcy:
        #s += 1
        #c += 1
        #print(stan,clcy,gpt)
        sc_tie += 1
    elif gpt == clcy and gpt < stan:
        #g += 1
        #c += 1
        gc_tie += 1
    elif gpt < stan and gpt < clcy:
        g += 1
    elif stan < gpt and stan < clcy:
        s += 1 
    elif clcy < gpt and clcy < stan:
        c += 1 
print('clcy:',c,'- Stan:',s,'- GPT:',g,'- tie:',tie,'- gptstan-tie:',gs_tie,'- gptclcy-tie:',gc_tie,'- stanclcy:',sc_tie) 
print(c+tie+gc_tie+sc_tie)
print(s+tie+gs_tie+sc_tie)
print(g+tie+gs_tie+gc_tie)
print()
print(round(20/(20+18+35+62+13+12+24)*100,1))
print(round(18/(20+18+35+62+13+12+24)*100,1))
print(round(35/(20+18+35+62+13+12+24)*100,1))

# %% [markdown]
# ## Difference in amount questions asked

# %%
def results( results1, results2, label1, label2 ):
    diff = 0
    abdiff = 0
    for res1,res2 in zip( results1, results2 ):
        diff += (res2 - res1)
        abdiff += abs(res2 - res1)
    diff = round(diff/len(results1),2)
    abdiff = round(abdiff/len(results1),2)
    
    print( '%s-%s:' %( label1.upper(), label2.upper() ) )
    print('diff:',diff)
    print('abs diff:', abdiff)
    return 

results( thesis_results['Questions-GPT'], thesis_results['Questions-Base'], 'gpt', 'base' )
print()
results( thesis_results['Questions-C'], thesis_results['Questions-Base'], 'clcy', 'base' )
print()
results( thesis_results['Questions-S'], thesis_results['Questions-Base'], 'stan', 'base' )
