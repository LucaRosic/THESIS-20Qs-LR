# %%
import pandas as pd
data = pd.read_csv("Abstracts-186.csv")
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#                                                 Entity
# 0       http://yago-knowledge.org/resource/David_Bowie  \
# 1        http://yago-knowledge.org/resource/Kanye_West
# 2            http://yago-knowledge.org/resource/Eminem
# 3    http://yago-knowledge.org/resource/Jennifer_An...
# 4    http://yago-knowledge.org/resource/George_W._Bush
# ..                                                 ...
# 179    http://yago-knowledge.org/resource/Nancy_Pelosi
# 180  http://yago-knowledge.org/resource/Andhra_Pradesh
# 181     http://yago-knowledge.org/resource/Maharashtra
# 182  http://yago-knowledge.org/resource/Paris_Saint...
# 183   http://yago-knowledge.org/resource/Uttar_Pradesh
#
#                         Label
# 0                 David Bowie  \
# 1                  Kanye West
# 2                      Eminem
# 3            Jennifer Aniston
# 4              George W. Bush
# ..                        ...
# 179              Nancy Pelosi
# 180            Andhra Pradesh
# 181               Maharashtra
# 182  Paris Saint-Germain F.C.
# 183             Uttar Pradesh
#
#                                               Abstract
# 0    David Robert Jones (8 January 1947 – 10 Januar...
# 1    Ye (/jeɪ/ YAY; born Kanye Omari West /ˈkɑːnjeɪ...
# 2    Marshall Bruce Mathers III (born October 17, 1...
# 3    Jennifer Joanna Aniston (born February 11, 196...
# 4    George Walker Bush (born July 6, 1946) is an A...
# ..                                                 ...
# 179  Nancy Patricia Pelosi (/pəˈloʊsi/; née D'Alesa...
# 180  Andhra Pradesh (English: /ˌɑːndrə prəˈdɛʃ/, Te...
# 181  Maharashtra (/məhɑːˈrɑːʃtrə/; Marathi: [məhara...
# 182  Paris Saint-Germain Football Club (French pron...
# 183  Uttar Pradesh (/ˌʊtər prəˈdɛʃ/; Hindi: [ˈʊtːəɾ...
#
# [184 rows x 3 columns]

# %%
#subs = []
#for e,_,_ in data.values:
    #s = e.split('/')[-1]
    #subs.append(s)
#data['Subjects'] = subs
data
# Out:
#                                                 Entity
# 0       http://yago-knowledge.org/resource/David_Bowie  \
# 1        http://yago-knowledge.org/resource/Kanye_West
# 2            http://yago-knowledge.org/resource/Eminem
# 3    http://yago-knowledge.org/resource/Jennifer_An...
# 4    http://yago-knowledge.org/resource/George_W._Bush
# ..                                                 ...
# 179    http://yago-knowledge.org/resource/Nancy_Pelosi
# 180  http://yago-knowledge.org/resource/Andhra_Pradesh
# 181     http://yago-knowledge.org/resource/Maharashtra
# 182  http://yago-knowledge.org/resource/Paris_Saint...
# 183   http://yago-knowledge.org/resource/Uttar_Pradesh
#
#                         Label
# 0                 David Bowie  \
# 1                  Kanye West
# 2                      Eminem
# 3            Jennifer Aniston
# 4              George W. Bush
# ..                        ...
# 179              Nancy Pelosi
# 180            Andhra Pradesh
# 181               Maharashtra
# 182  Paris Saint-Germain F.C.
# 183             Uttar Pradesh
#
#                                               Abstract
# 0    David Robert Jones (8 January 1947 – 10 Januar...  \
# 1    Ye (/jeɪ/ YAY; born Kanye Omari West /ˈkɑːnjeɪ...
# 2    Marshall Bruce Mathers III (born October 17, 1...
# 3    Jennifer Joanna Aniston (born February 11, 196...
# 4    George Walker Bush (born July 6, 1946) is an A...
# ..                                                 ...
# 179  Nancy Patricia Pelosi (/pəˈloʊsi/; née D'Alesa...
# 180  Andhra Pradesh (English: /ˌɑːndrə prəˈdɛʃ/, Te...
# 181  Maharashtra (/məhɑːˈrɑːʃtrə/; Marathi: [məhara...
# 182  Paris Saint-Germain Football Club (French pron...
# 183  Uttar Pradesh (/ˌʊtər prəˈdɛʃ/; Hindi: [ˈʊtːəɾ...
#
#                      Subjects
# 0                 David_Bowie
# 1                  Kanye_West
# 2                      Eminem
# 3            Jennifer_Aniston
# 4              George_W._Bush
# ..                        ...
# 179              Nancy_Pelosi
# 180            Andhra_Pradesh
# 181               Maharashtra
# 182  Paris_Saint-Germain_F.C.
# 183             Uttar_Pradesh
#
# [184 rows x 4 columns]

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This Must Be the Place (film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.5
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# ```
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix movie: <http://example.org/movies/> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
#
# movie:This_Must_Be_the_Place
#     rdf:type movie:Film ;
#     dc:title "This Must Be the Place" ;
#     dc:date "2011" ;
#     movie:directedBy "Paolo Sorrentino" ;
#     movie:writtenBy "Paolo Sorrentino" ;
#     movie:stars "Sean Penn" , "Frances McDormand" ;
#     movie:dealsWith "middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States" ;
#     movie:hasCoProducers "France" , "Ireland" ;
#     movie:hasPrincipalPhotographyLocation "Ireland" , "Italy" , "Michigan" , "New Mexico" , "New York" ;
#     movie:wasInCompetitionAt "2011 Cannes Film Festival" .
# ```

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This Must Be the Place (film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.5
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# ```
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix movie: <http://example.org/movie/> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
#
# movie:This_Must_Be_the_Place
#     rdf:type movie:Film ;
#     dc:title "This Must Be the Place" ;
#     dc:date "2011" ;
#     movie:director "Paolo Sorrentino" ;
#     movie:writer "Paolo Sorrentino" ;
#     movie:writer "it" ;
#     movie:actor "Sean Penn" ;
#     movie:actor "Frances McDormand" ;
#     movie:plot "The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States." ;
#     movie:country "Italy" ;
#     movie:country "France" ;
#     movie:country "Ireland" ;
#     movie:producer "Italy" ;
#     movie:producer "France" ;
#     movie:producer "Ireland" ;
#     movie:producer "USA" ;
#     movie:filming_location "Ireland" ;
#     movie:filming_location "Italy" ;
#     movie:filming_location "Michigan" ;
#     movie:filming_location "New Mexico" ;
#     movie:filming_location "New York" ;
#     movie:festival "2011 Cannes Film Festival" .
# ```

# %% [markdown]
# ## Best so far
#
# #### 0.3

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax and does not access DBpedia"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This Must Be the Place (film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.3
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# @prefix ex: <http://example.org/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# ex:This_Must_Be_the_Place_film rdf:type ex:Film ;
#     rdfs:label "This Must Be the Place (film)"@en ;
#     ex:directedBy "Paolo Sorrentino" ;
#     ex:writtenBy "Paolo Sorrentino" ;
#     ex:releasedIn "United States" ;
#     ex:releaseYear "2012" ;
#     ex:stars "Sean Penn" , "Frances McDormand" ;
#     ex:hasPlot "The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States."@en ;
#     ex:hasCoProducers "France" , "Ireland" ;
#     ex:hasMajorityProducer "Italy" ;
#     ex:hasPrincipalPhotographyDate "August, 2010" ;
#     ex:hasFilmingLocation "Ireland" , "Italy" , "Michigan" , "New Mexico" , "New York" ;
#     ex:wasInCompetitionAt "2011 Cannes Film Festival" .

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax and does not access DBpedia"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This Must Be the Place (film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.3
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# ```
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix movie: <http://example.org/movie/> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
#
# movie:This_Must_Be_the_Place
#     rdf:type movie:Film ;
#     dc:title "This Must Be the Place" ;
#     dc:date "2011" ;
#     movie:directedBy "Paolo Sorrentino" ;
#     movie:writtenBy "Paolo Sorrentino" ;
#     movie:stars "Sean Penn" , "Frances McDormand" ;
#     movie:hasPlot "The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States." ;
#     movie:hasProductionCountry "Italy" , "France" , "Ireland" ;
#     movie:hasProductionState "Michigan" , "New Mexico" , "New York" ;
#     movie:wasInCompetitionAt "2011 Cannes Film Festival" .
# ```

# %% [markdown]
# #### 0.5

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax and does not access DBpedia"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This Must Be the Place (film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.5
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# ```
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix movie: <http://example.org/movie/> .
# @prefix dbpedia: <http://dbpedia.org/ontology/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# movie:This_Must_Be_the_Place rdf:type dbpedia:Film ;
#     dbpedia:director "Paolo Sorrentino" ;
#     dbpedia:writer "Paolo Sorrentino" ;
#     dbpedia:writer "it" ;
#     dbpedia:releaseYear "2012"^^xsd:gYear ;
#     dbpedia:starring "Sean Penn" ;
#     dbpedia:starring "Frances McDormand" ;
#     dbpedia:plot "The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States." ;
#     dbpedia:country "Italy" ;
#     dbpedia:country "France" ;
#     dbpedia:country "Ireland" ;
#     dbpedia:language "English" ;
#     dbpedia:producer "Nicola Giuliano" ;
#     dbpedia:producer "Francesca Cima" ;
#     dbpedia:producer "Andrea Occhipinti" ;
#     dbpedia:producer "Mario Spedaletti" ;
#     dbpedia:producer "Jean Labadie" ;
#     dbpedia:producer "Simon Arnal" ;
#     dbpedia:producer "Ed Guiney" ;
#     dbpedia:producer "Andrew Lowe" ;
#     dbpedia:hasLocation "Ireland" ;
#     dbpedia:hasLocation "Italy" ;
#     dbpedia:hasLocation "Michigan" ;
#     dbpedia:hasLocation "New Mexico" ;
#     dbpedia:hasLocation "New York" ;
#     dbpedia:isInCompetition "true" ;
#     dbpedia:festival "Cannes Film Festival" ;
#     dbpedia:award "Prix Vulcain de l'artiste technicien" .
# ```

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax and does not access DBpedia"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This Must Be the Place (film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.5
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)

# %%
#### 0.8

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax and does not access DBpedia"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This_Must_Be_the_Place_(film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.8
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# ```
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix movie: <http://example.org/movie/> .
# @prefix dc: <http://purl.org/dc/terms/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# movie:This_Must_Be_the_Place_(film)
#   rdf:type movie:Film ;
#   dc:title "This Must Be the Place" ;
#   dc:date "2011"^^xsd:gYear ;
#   movie:directed_by "Paolo Sorrentino" ;
#   movie:written_by "Paolo Sorrentino" ;
#   movie:stars "Sean Penn", "Frances McDormand" ;
#   movie:deals_with "middle-aged wealthy rock star" ;
#   movie:has_co-producers "France", "Ireland" ;
#   movie:has_country "Italy", "Ireland", "United States" ;
#   movie:has_state "Michigan", "New Mexico", "New York" ;
#   movie:was_in_competition_at "2011 Cannes Film Festival" .
#
# movie:This_Must_Be_the_Place_(film)_trailer
#   rdf:type movie:Trailer ;
#   movie:for_film movie:This_Must_Be_the_Place_(film) .
#
# ```
# Note: I added a trailer resource and inferred some properties based on the text.

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax and does not access DBpedia"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This_Must_Be_the_Place_(film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.4
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# ```
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix movie: <http://example.com/movies/> .
# @prefix dbpedia: <http://dbpedia.org/resource/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# movie:This_Must_Be_the_Place_(film) rdf:type movie:Film ;
#     movie:directedBy "Paolo Sorrentino" ;
#     movie:writtenBy "Paolo Sorrentino" ;
#     movie:starring dbpedia:Sean_Penn , dbpedia:Frances_McDormand ;
#     movie:releasedIn "2012-12-14"^^xsd:date ;
#     movie:hasProductionCountry dbpedia:Italy , dbpedia:France , dbpedia:Ireland ;
#     movie:hasProductionState dbpedia:Michigan , dbpedia:New_Mexico , dbpedia:New_York ;
#     movie:hasPlot "The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States." ;
#     movie:wasInCompetitionAt dbpedia:2011_Cannes_Film_Festival ;
#     movie:hasPrincipalPhotographyStartDate "2010-08"^^xsd:gYearMonth .
# ```

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from a peice of text, that uses ttl syntax and does not access DBpedia"},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity 'This_Must_Be_the_Place_(film)' from the text:
"This Must Be the Place is a 2011 Italian-French-Irish drama film directed by Paolo Sorrentino, written by Sorrentino and (it) and released in the United States in late 2012. It stars Sean Penn and Frances McDormand. The film deals with a middle-aged wealthy rock star who becomes bored in his retirement and takes on the quest of finding his father's tormentor, a Nazi war criminal who is a refugee in the United States. The film was an Italian-majority production with co-producers in France and Ireland. Principal photography began in August, 2010. Filming took place in Ireland and Italy, as well as the states of Michigan, New Mexico, and New York. The film was in competition at the 2011 Cannes Film Festival." """},
        ],
    temperature = 0.4
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# ```
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix movie: <http://example.com/movies/> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# movie:This_Must_Be_the_Place_(film)
#     rdf:type movie:Film ;
#     dc:title "This Must Be the Place" ;
#     dc:date "2011"^^xsd:gYear ;
#     movie:hasDirector "Paolo Sorrentino" ;
#     movie:hasWriter "Paolo Sorrentino" ;
#     movie:hasActor "Sean Penn" ;
#     movie:hasActor "Frances McDormand" ;
#     movie:hasProducer "Italy" ;
#     movie:hasCoProducer "France" ;
#     movie:hasCoProducer "Ireland" ;
#     movie:hasLocation "Ireland" ;
#     movie:hasLocation "Italy" ;
#     movie:hasLocation "Michigan" ;
#     movie:hasLocation "New Mexico" ;
#     movie:hasLocation "New York" ;
#     movie:hasCompetition "2011 Cannes Film Festival" .
# ```

# %%
#for e,p,o,s in data.values:
    #print(s,p,o)
    #break
sub = data['Subjects'][100]
ab = data['Abstract'][100]
ab
# Out:
# 'Macaulay Macaulay Culkin Culkin (born Macaulay Carson Culkin; August 26, 1980) is an American actor. Often regarded as one of the most successful child actors of the 1990s, he was placed 2nd on VH1\'s list of the "100 Greatest Kid-Stars". Culkin rose to prominence as a child actor starring as Kevin McCallister in the first two films of the Home Alone film series (1990 and 1992), for which he was nominated for the Golden Globe Award for Best Actor – Motion Picture Musical or Comedy. He also starred in the films My Girl (1991), The Good Son (1993), The Nutcracker (1993), Getting Even with Dad (1994), The Pagemaster (1994), and Richie Rich (1994). Culkin took a break from acting in 1994. He returned in 2003 with a guest appearance on the television show Will & Grace and a role in the film Party Monster. He wrote an autobiography, Junior, which was published in 2006. In 2021, he starred in American Horror Story: Double Feature, the tenth season of the anthology series American Horror Story. In 2013, Culkin co-founded the New York comedy rock band the Pizza Underground, of which he was the vocalist; in 2016, Culkin stated that the Pizza Underground was splitting up and their next album would be their last. He is currently the publisher and CEO of Bunny Ears, a satirical pop culture website and podcast. He has also received an MTV Movie Award from three nominations, and a Young Artist Award.'

# %%
import openai

openai.api_key = "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"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a Information extraction model that produces rdf triples from the text given, that uses ttl syntax, does not access dbpedia, uses ex prefix, and gives data values to literals."},
            {"role": "user", "content": """output just rdf triples, in ttl format, for the entity '%s' from the text:
"%s" without using dbo or dbpedia """ %(sub,ab)},
        ],
    temperature = 0.4
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)
# Out:
# ```
# @prefix ex: <http://example.com/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:Macaulay_Culkin rdf:type ex:Actor ;
#     ex:name "Macaulay Macaulay Culkin Culkin" ;
#     ex:birthDate "1980-08-26"^^xsd:date ;
#     ex:isKnownFor "Home Alone film series" ;
#     ex:rankedOnVH1 "2" ;
#     ex:nominatedFor "Golden Globe Award for Best Actor – Motion Picture Musical or Comedy" ;
#     ex:appearedIn "My Girl", "The Good Son", "The Nutcracker", "Getting Even with Dad", "The Pagemaster", "Richie Rich", "Party Monster", "American Horror Story: Double Feature" ;
#     ex:coFounded "the Pizza Underground" ;
#     ex:receivedAward "MTV Movie Award", "Young Artist Award" ;
#     ex:owns "Bunny Ears" .
#
# ```

# %%
for i in result.split('\n'):
    if i == '```' or i is None:
        continue
    else: 
        print(i)
# Out:
# @prefix ex: <http://example.com/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:Macaulay_Culkin rdf:type ex:Actor ;
#     ex:name "Macaulay Macaulay Culkin Culkin" ;
#     ex:birthDate "1980-08-26"^^xsd:date ;
#     ex:isKnownFor "Home Alone film series" ;
#     ex:rankedOnVH1 "2" ;
#     ex:nominatedFor "Golden Globe Award for Best Actor – Motion Picture Musical or Comedy" ;
#     ex:appearedIn "My Girl", "The Good Son", "The Nutcracker", "Getting Even with Dad", "The Pagemaster", "Richie Rich", "Party Monster", "American Horror Story: Double Feature" ;
#     ex:coFounded "the Pizza Underground" ;
#     ex:receivedAward "MTV Movie Award", "Young Artist Award" ;
#     ex:owns "Bunny Ears" .

# %%
with open('turt.ttl', 'w') as f:
    for i in result.split('\n'):
        if i == '```' or i is None:
            continue
        else:
            f.write(i)
            f.write('\n')
            #print(i)
    #for line in lines:
        #f.write(line)
        #f.write('\n')
